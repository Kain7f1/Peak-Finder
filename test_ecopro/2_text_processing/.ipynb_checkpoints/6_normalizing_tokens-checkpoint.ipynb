# %% [markdown]
# # 6. 토큰 정규화 Normalizing tokens
# - 토큰 분포를 확인한다
# - 정규화해야할 리스트를 작성한다
# - 정규화 진행

# %% [markdown]
# ## 6-a. 토큰 분포 확인

# %% [markdown]
# ### 6-a-1. 파일 불러오기

# %%
import pandas as pd
fpath = "5_tokenized_ecopro_text.csv"
df = pd.read_csv(fpath, encoding="utf-8")
df.head(30)
# Out:
#    community gall_id search_keyword  number date_created time_created  \
# 0   dcinside  snp500             에코  832014   2023-10-27     15:50:34
# 1   dcinside  snp500             에코  831598   2023-10-26     21:13:32
# 2   dcinside  snp500             에코  831598   2023-10-26     21:14:04
# 3   dcinside  snp500             에코  831598   2023-10-26     21:15:57
# 4   dcinside  snp500             에코  831598   2023-10-26     21:22:49
# 5   dcinside  snp500             에코  831560   2023-10-26     20:17:39
# 6   dcinside  snp500             에코  831560   2023-10-26     20:20:36
# 7   dcinside  snp500             에코  831459   2023-10-26     17:04:31
# 8   dcinside  snp500             에코  831459   2023-10-26     17:05:41
# 9   dcinside  snp500             에코  831459   2023-10-26     17:06:29
# 10  dcinside  snp500             에코  831459   2023-10-26     17:08:32
# 11  dcinside  snp500             에코  831457   2023-10-26     16:50:40
# 12  dcinside  snp500             에코  831457   2023-10-26     17:25:21
# 13  dcinside  snp500             에코  831453   2023-10-26     16:46:13
# 14  dcinside  snp500             에코  831453   2023-10-26     16:48:08
# 15  dcinside  snp500             에코  831453   2023-10-26     16:49:12
# 16  dcinside  snp500             에코  831450   2023-10-26     16:41:41
# 17  dcinside  snp500             에코  831450   2023-10-26     16:42:14
# 18  dcinside  snp500             에코  831450   2023-10-26     16:42:17
# 19  dcinside  snp500             에코  831450   2023-10-26     16:49:32
# 20  dcinside  snp500             에코  831450   2023-10-26     16:52:20
# 21  dcinside  snp500             에코  831450   2023-10-26     16:42:21
# 22  dcinside  snp500             에코  831361   2023-10-26     14:23:39
# 23  dcinside  snp500             에코  831172   2023-10-26     09:06:24
# 24  dcinside  snp500             에코  831172   2023-10-26     09:06:48
# 25  dcinside  snp500             에코  829909   2023-10-23     21:12:13
# 26  dcinside  snp500             에코  829909   2023-10-23     21:14:38
# 27  dcinside  snp500             에코  829909   2023-10-23     21:25:37
# 28  dcinside  snp500             에코  829909   2023-10-23     21:31:33
# 29  dcinside  snp500             에코  829909   2023-10-23     21:27:16
#
#            author  is_reply  text_length  \
# 0       ㅇㅇ(58.78)         0           56
# 1    슨붕이(106.101)         0           11
# 2       모든주식을소유하라         1            9
# 3              ㅇㅇ         1           23
# 4              ㅇㅇ         1           20
# 5              ㅇㅇ         0           20
# 6           슨피한접시         1            6
# 7      원화=휴지/달러=신         0          117
# 8       ㅇㅇ(58.78)         1           40
# 9         돌려돌려돌림판         1           23
# 10  슨붕이1(106.246)         1            7
# 11         TTKiso         0           39
# 12     말하기전에생각했나요         1           25
# 13      ㅇㅇ(58.78)         0           90
# 14          Erika         1           12
# 15  슨붕이1(118.235)         1           16
# 16             터보         0           25
# 17     ㅇㅇ(118.32)         1           10
# 18          푸른수국화         1           31
# 19             터보         1            2
# 20             ㅇㅇ         1            4
# 21          Erika         1            9
# 22     말하기전에생각했나요         0           34
# 23     ㅇㅇ(223.62)         0           19
# 24     ㅇㅇ(118.32)         1            3
# 25     원화=휴지/달러=신         0           57
# 26        아빠말좀들어라         1           33
# 27             ミク         1           21
# 28          3줄증권사         1           15
# 29          슨피한접시         1            6
#
#                                           spaced_text  \
# 0   국연 에코프로 퍼이상 투자해야한다 전국민 자산증발에 앞서야 추후 글로벌 시장에 조선...
# 1                                         에코푸로 손절 ㄷㄷㄷ
# 2                                           알빠노? 캬ㅋㅋㅋ
# 3                             그냥업황나빠진건데사ㅇㅈㄹ잘못ㅇㅈㅈㅓ대안ㅋㅋ
# 4                               오근디돈 억넘게 에코프로에박앗네상남ㅇㅂ
# 5                                에코프로 마십쩌둥 머임 먼일이 난거임
# 6                                              평범한 국장
# 7   에코프로는 진지하게 주당 만원이 적정가임 현재 모든 지표와 기대감까지 종합해봤을때 ...
# 8            코리안 디스카운트 반영해서 원정도가 적정가다 만원이면 나스닥 상장해야한다
# 9                             원이 적정가임 내가 보유하지 않았기 때문에
# 10                                            per 레전드
# 11            토스 에코비엠 게시판 ㅈㄴ 얄밉게 놀리네 한두번 해본 솜씨가 아냐 ㅋㅋ
# 12                          네이버에만 쓰다가 토스까지 쓰는거지 뭐 ㅋㅋㅋ
# 13  에코프로 매수를 독려해야함 전국민 자체적 자산증발을 위해 국장 바카라 주식매수를 권...
# 14                                       이미 부동산으로 삭제중
# 15                                  전국민거지만들기프로젝트임? ㅋㅋ
# 16                          에코프로 아직도 과대평가누 ? 이면 혜잔데 ?
# 17                                         나중에 햇제 해주셈
# 18                    수치로만 보면 선이 적정선 신도들은 그러면 ㅈㄹㅈㄹ겠지만
# 19                                                 캬캬
# 20                                               ㅇㄱㄹㅇ
# 21                                          쫄보라 못삼 ㅎㅎ
# 22                 에코프로 언제 만 초반을 찍었냐 에코프로 퐁퐁이들 피눈물 ㅠㅠ
# 23                               에코호로의 몰락 개관공매놈들때문에 !
# 24                                                ㅋㅋㅋ
# 25  목표 주가 공유 리얼리인컴 단기 불 장기 불테슬라 불티큐 단기 불 장기 불에코프로 ...
# 26                  테슬라 불도 씹거품인듯차 년에 만대 파는 회사가 시총이 ㅋㅋ
# 27                              아주 그냥 세상이 씹창나길 기도하는구나
# 28                                   ㄹㅇ 숏충이가 아니라 사탄인ㅋ
# 29                                             에코는 동의
#
#                                                tokens
# 0   ['국연', '에코프로', '이상', '투자', '국민', '자산', '증발', '...
# 1                               ['에코푸로', '손절', 'ㄷㄷㄷ']
# 2                                ['알빠노', '?', '캬ㅋㅋㅋ']
# 3               ['그냥', '황나', '빠진', '건데', 'ㅇㅈㄹ', '잘못']
# 4                                ['근디', '에코프로', '상남']
# 5                                      ['에코프로', '마십']
# 6                                              ['국장']
# 7   ['에코프로', '적정', '가임', '현재', '모든', '지표', '기대감', ...
# 8   ['코리안', '디스카운트', '반영', '정도', '적정', '만원', '나스닥'...
# 9                            ['적정', '가임', '보유', '때문']
# 10                                            ['레전드']
# 11  ['토스', '에코비엠', '게시판', 'ㅈㄴ', '얄밉', '놀리', '한두', ...
# 12                               ['네이버', '토스', 'ㅋㅋㅋ']
# 13  ['에코프로', '매수', '독려', '국민', '자체', '자산', '증발', '...
# 14                                ['이미', '부동산', '삭제']
# 15             ['전국', '민거지', '만들', '프로젝트', '?', 'ㅋㅋ']
# 16             ['에코프로', '아직', '과대평가', '?', '이면', '?']
# 17                                       ['나중', '해주']
# 18                   ['수치', '적정선', '신도', '그러면', 'ㅈㄹ']
# 19                                                 []
# 20                                                 []
# 21                                       ['보라', 'ㅎㅎ']
# 22    ['에코프로', '언제', '초반', '에코프로', '퐁퐁', '피눈물', 'ㅠㅠ']
# 23              ['에코호로', '몰락', '개관', '공매', '때문', '!']
# 24                                            ['ㅋㅋㅋ']
# 25  ['목표', '주가', '공유', '얼리', '인컴', '단기', '장기', '테슬...
# 26        ['테슬라', '불도', '거품', '파는', '회사', '시총', 'ㅋㅋ']
# 27                           ['아주', '그냥', '세상', '기도']
# 28                                ['ㄹㅇ', '숏충이', '사탄']
# 29                                       ['에코', '동의']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108945 entries, 0 to 108944
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   community       108945 non-null  object
#  1   gall_id         108945 non-null  object
#  2   search_keyword  108945 non-null  object
#  3   number          108945 non-null  int64
#  4   date_created    108945 non-null  object
#  5   time_created    108945 non-null  object
#  6   author          108945 non-null  object
#  7   is_reply        108945 non-null  int64
#  8   text_length     108945 non-null  int64
#  9   spaced_text     108945 non-null  object
#  10  tokens          108945 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 9.1+ MB

# %% [markdown]
# ### 6-a-2. 'tokens' 열의 문자열을 실제 리스트로 변환

# %%
import ast
# 'tokens' 열의 문자열을 실제 리스트로 변환
df['tokens'] = df['tokens'].apply(ast.literal_eval)

# %% [markdown]
# ### 6-a-3. 토큰 분포를 딕셔너리로 만들기

# %% [markdown]
# #### 함수 제작

# %%
"""
주어진 데이터프레임의 지정된 열에 대해 토큰의 등장 빈도를 계산하고, 
빈도가 높은 순으로 정렬된 전체 토큰과 그 빈도를 딕셔너리로 반환하는 함수입니다. 

:param dataframe: pandas 데이터프레임
:param column_name: 토큰이 포함된 열의 이름
:return: 토큰과 그 빈도를 포함하는 딕셔너리
"""

from collections import Counter

def make_tokens_count_dict(dataframe, column_name):

    # 토큰별로 각 행에서의 출현 여부를 체크
    token_presence = dataframe[column_name].apply(lambda tokens: set(tokens))

    # 모든 행에 대해 토큰의 출현 횟수를 세기
    token_count = Counter()
    for tokens in token_presence:
        token_count.update(tokens)

    # 빈도가 높은 순으로 토큰 정렬
    sorted_tokens = dict(sorted(token_count.items(), key=lambda item: item[1], reverse=True))

    return sorted_tokens

# %% [markdown]
# #### 함수 실행

# %%
# 함수를 사용하여 딕셔너리를 생성
sorted_tokens_dict = make_tokens_count_dict(df, 'tokens')

# %% [markdown]
# #### 결과 딕셔너리 출력

# %%
sorted_tokens_dict
# Out:
# {'에코프로': 31113,
#  '?': 19667,
#  'ㅋㅋㅋ': 16522,
#  '에코': 10603,
#  '에코호로': 8497,
#  'ㅋㅋ': 7732,
#  '지금': 5041,
#  '주식': 4943,
#  '오늘': 4214,
#  '만원': 3980,
#  '에코프로비엠': 3794,
#  '진짜': 3659,
#  '새끼': 3543,
#  '오르': 2753,
#  '차전지': 2681,
#  '!': 2639,
#  '매수': 2477,
#  '생각': 2439,
#  '존나': 2435,
#  '사람': 2422,
#  '그냥': 2406,
#  'ㄹㅇ': 2322,
#  '개미': 2288,
#  '근데': 2285,
#  'ㅇㅇ': 2271,
#  '종목': 2189,
#  '시발': 2102,
#  '공매도': 2007,
#  'ㄷㄷ': 1979,
#  '캬ㅋㅋㅋ': 1927,
#  '병신': 1918,
#  '아직': 1882,
#  '이제': 1864,
#  '수익': 1834,
#  '코스닥': 1788,
#  '내일': 1772,
#  '신성': 1764,
#  '정도': 1645,
#  '다시': 1618,
#  'ㄷㄷㄷ': 1600,
#  '시총': 1578,
#  '고점': 1576,
#  '프로': 1535,
#  '나오': 1500,
#  '씨발': 1452,
#  '모르': 1451,
#  '가능': 1450,
#  '이유': 1436,
#  '회사': 1428,
#  '이상': 1402,
#  '매도': 1394,
#  '국장': 1375,
#  '너무': 1344,
#  '테슬라': 1343,
#  '주주': 1310,
#  '이런': 1307,
#  'ㅅㅂ': 1306,
#  '계속': 1293,
#  '포스코': 1274,
#  '많이': 1266,
#  '시작': 1220,
#  '주가': 1208,
#  '상승': 1201,
#  '실적': 1201,
#  '어제': 1181,
#  '투자': 1180,
#  '다른': 1163,
#  '비엠': 1163,
#  '금양': 1163,
#  '들어가': 1123,
#  '간다': 1122,
#  '차트': 1107,
#  '이미': 1048,
#  '시장': 1030,
#  '배터리': 1021,
#  '하락': 1011,
#  '떨어지': 997,
#  '세력': 991,
#  '기업': 981,
#  '운지': 981,
#  '때문': 976,
#  '가격': 970,
#  '그런': 941,
#  '공매': 934,
#  '거품': 925,
#  '조정': 902,
#  '초전도체': 902,
#  '광기': 898,
#  '평단': 894,
#  '삼전': 891,
#  'ㅠㅠ': 840,
#  '건데': 837,
#  '지수': 836,
#  '보이': 836,
#  '단타': 828,
#  '기관': 825,
#  '미국': 815,
#  '한국': 811,
#  '수급': 807,
#  'ㅡㅡ': 803,
#  '코스피': 791,
#  '손절': 788,
#  '얼마': 785,
#  '그럼': 782,
#  '올리': 778,
#  '에코비엠': 777,
#  '같이': 771,
#  '포홀': 771,
#  '폭락': 770,
#  '아니': 766,
#  '올랐': 762,
#  '다음': 735,
#  '그때': 735,
#  '미친': 735,
#  '오를': 710,
#  '사라': 702,
#  '그래서': 702,
#  '미래': 687,
#  '오른': 674,
#  '물린': 670,
#  '물량': 669,
#  '빠지': 668,
#  '그리고': 662,
#  '결국': 660,
#  '언제': 654,
#  '해서': 651,
#  '무슨': 644,
#  '올해': 637,
#  '나스닥': 628,
#  '이번': 626,
#  '아저씨': 622,
#  '상장': 619,
#  '빨리': 617,
#  '이렇게': 614,
#  '개인': 611,
#  '그렇': 604,
#  '해도': 602,
#  '뒤지': 602,
#  '바로': 601,
#  '고수': 600,
#  '매매': 599,
#  '절대': 592,
#  '어떻게': 590,
#  '가치': 589,
#  '계좌': 587,
#  '반도체': 587,
#  '텐데': 587,
#  '그러': 586,
#  '소리': 584,
#  'ㅈㄴ': 583,
#  '시간': 583,
#  '무조건': 572,
#  '하루': 562,
#  '예상': 552,
#  '형제': 549,
#  '양극재': 548,
#  '미장': 547,
#  '거래': 547,
#  '기회': 546,
#  '추천': 545,
#  '만들': 544,
#  '어케': 543,
#  '제발': 539,
#  '그래도': 533,
#  '인생': 530,
#  '얘기': 525,
#  '몰빵': 525,
#  '호로': 523,
#  '인증': 517,
#  '느낌': 515,
#  '솔직히': 514,
#  '에코후로': 513,
#  '일단': 512,
#  '사실': 510,
#  '저점': 510,
#  '어차피': 507,
#  '외인': 507,
#  '익절': 502,
#  '올라가': 500,
#  '나올': 497,
#  '전기차': 495,
#  '개추': 493,
#  '인버스': 493,
#  '봐도': 493,
#  '가즈아': 488,
#  '거의': 485,
#  '그렇게': 484,
#  '코인': 483,
#  '호재': 481,
#  '버티': 478,
#  '자리': 477,
#  '나락': 475,
#  '원래': 470,
#  '코갤': 469,
#  '풀매수': 468,
#  '바이오': 467,
#  '뉴스': 465,
#  '에코호로비엠': 463,
#  '삼성': 460,
#  '설거지': 456,
#  '카카오': 456,
#  '문제': 452,
#  '닥버스': 452,
#  '매출': 448,
#  '엘앤에프': 448,
#  '현재': 443,
#  '선물': 443,
#  '하한가': 441,
#  '신용': 441,
#  '기술': 440,
#  '지랄': 436,
#  '자체': 434,
#  '개잡주': 433,
#  '돌파': 432,
#  '테마': 430,
#  '작년': 427,
#  '동안': 426,
#  '마지막': 425,
#  '없이': 424,
#  '오름': 422,
#  '사면': 421,
#  '얼마나': 421,
#  '내리': 419,
#  '종토방': 417,
#  '해라': 415,
#  '가지': 415,
#  '조금': 413,
#  '반등': 411,
#  '만원대': 411,
#  '그만': 407,
#  '이러': 407,
#  '맞음': 407,
#  '시외': 407,
#  '된다': 405,
#  '상황': 401,
#  '기분': 401,
#  '성장': 400,
#  '공장': 400,
#  '떡상': 399,
#  '저런': 397,
#  '다들': 396,
#  '종가': 396,
#  '요즘': 392,
#  '시드': 391,
#  '엔비디아': 391,
#  '수준': 390,
#  '편입': 390,
#  '떡락': 387,
#  '이차전지': 386,
#  '나라': 386,
#  '역시': 385,
#  '이해': 384,
#  '양전': 381,
#  'ㄱㄱ': 381,
#  '부자': 381,
#  '소재': 381,
#  '분위기': 380,
#  '자금': 378,
#  '예정': 378,
#  '정보': 375,
#  '바닥': 375,
#  '똑같': 373,
#  '엔솔': 373,
#  '발표': 372,
#  '진입': 368,
#  '나왔': 368,
#  '건가': 367,
#  '급등': 364,
#  '전부': 362,
#  '세계': 360,
#  '작전': 360,
#  '틀딱': 359,
#  '중국': 358,
#  '들어오': 358,
#  '기준': 354,
#  '외국인': 354,
#  '셀트리온': 348,
#  '존버': 348,
#  '장투': 346,
#  '회장': 345,
#  '이후': 344,
#  '분할': 343,
#  '탈출': 343,
#  '떨어질': 343,
#  '섹터': 342,
#  '비싸': 340,
#  '제일': 338,
#  'ㅎㅎ': 335,
#  'ㅇㅈㄹ': 334,
#  '괜찮': 334,
#  '에코형제': 334,
#  '분석': 333,
#  '모든': 332,
#  '해야': 331,
#  '터지': 331,
#  '좆같': 331,
#  '악재': 331,
#  '정신': 330,
#  '비교': 330,
#  '상한가': 330,
#  '목표': 329,
#  '본인': 326,
#  '최소': 325,
#  '거래량': 325,
#  '대비': 323,
#  '봐라': 323,
#  '올라': 322,
#  '친구': 321,
#  '손실': 321,
#  '대체': 321,
#  '관련': 321,
#  '물렸': 320,
#  '정상': 318,
#  '기대': 317,
#  '물리': 317,
#  '지주사': 317,
#  '혼자': 314,
#  '단기': 313,
#  '본다': 312,
#  '테마주': 311,
#  '비중': 309,
#  '저렇게': 308,
#  '순간': 306,
#  '필요': 305,
#  '뒤져': 305,
#  'ㅜㅜ': 305,
#  '네이버': 303,
#  '이기': 303,
#  '추매': 303,
#  '슬슬': 303,
#  '홀딩': 300,
#  '사기': 299,
#  '물론': 298,
#  '모두': 297,
#  '무섭': 297,
#  '에코프로에이치엔': 297,
#  '감사': 295,
#  '대가리': 295,
#  '분기': 292,
#  '조선': 291,
#  '관심': 290,
#  '월요일': 290,
#  '내려가': 289,
#  '기사': 289,
#  '애플': 289,
#  '사고': 289,
#  '아무리': 289,
#  '갑자기': 288,
#  '오히려': 287,
#  '그래': 287,
#  '이야기': 287,
#  '공시': 286,
#  '대부분': 286,
#  '보유': 285,
#  '주린이': 285,
#  '벼락거지': 283,
#  '신고': 281,
#  '비트코인': 281,
#  '벌써': 281,
#  '장기': 280,
#  '들어갔': 280,
#  'ㄹㅇㅋㅋ': 280,
#  '와서': 278,
#  '전자': 278,
#  '대장': 278,
#  '한다': 278,
#  '나중': 277,
#  '국내': 277,
#  '힘들': 277,
#  '중요': 277,
#  '출발': 276,
#  '리튬': 276,
#  '신풍': 275,
#  '나온': 275,
#  '폭등': 274,
#  '쌍봉': 274,
#  '공부': 273,
#  '산업': 273,
#  '거지': 272,
#  '새기': 272,
#  '재료': 272,
#  '최근': 271,
#  '아줌마': 271,
#  '나옴': 271,
#  '그룹': 270,
#  '숏스퀴즈': 270,
#  '확정': 270,
#  'ㅂㅅ': 269,
#  '타이밍': 269,
#  '준비': 268,
#  '아침': 268,
#  '삼성전자': 267,
#  '올려': 265,
#  '아님?': 265,
#  '의미': 264,
#  '세상': 263,
#  '평가': 263,
#  '지옥': 262,
#  '가장': 262,
#  '망하': 262,
#  '포스코홀딩스': 262,
#  '븅신': 261,
#  '투자자': 261,
#  '엄마': 261,
#  '만드': 261,
#  '어쩌': 258,
#  '서남': 256,
#  '주도': 256,
#  '탑승': 255,
#  '사업': 255,
#  '도박': 253,
#  '인간': 253,
#  '샀으면': 252,
#  '애초': 252,
#  '저거': 252,
#  '상태': 250,
#  '코로나': 250,
#  '예전': 248,
#  'ㅠㅠㅠ': 248,
#  '처음': 248,
#  '미주갤': 248,
#  '버블': 247,
#  '미쳤': 247,
#  '들어간': 247,
#  '항상': 247,
#  'ㅎㄷㄷ': 247,
#  '맨날': 246,
#  '어느': 245,
#  '설마': 244,
#  '신호': 244,
#  '관련주': 244,
#  '전지': 244,
#  '잘못': 243,
#  '관망': 242,
#  '무지성': 242,
#  '부럽': 241,
#  '화학': 240,
#  '지분': 240,
#  '만주': 239,
#  '호가': 239,
#  '횡보': 239,
#  '산다': 239,
#  '선동': 239,
#  '어떤': 239,
#  '양봉': 239,
#  '올린': 238,
#  '아래': 238,
#  '나머지': 238,
#  '온다': 238,
#  '사도': 238,
#  '걸로': 237,
#  '반토막': 236,
#  '저평가': 236,
#  '정리': 235,
#  '별로': 235,
#  '다르': 233,
#  '코프': 233,
#  '아빠': 232,
#  '당장': 232,
#  '적정': 231,
#  '모름': 231,
#  '유튜브': 231,
#  '따라': 230,
#  '엄청': 230,
#  '금리': 229,
#  '살려': 228,
#  '스캠': 228,
#  '흑우': 227,
#  '고민': 227,
#  '전고점': 227,
#  '대장주': 226,
#  '구경': 226,
#  '이익': 226,
#  '이지랄': 226,
#  '구간': 226,
#  '참고': 226,
#  '인정': 225,
#  '예측': 225,
#  '됨?': 225,
#  '증권사': 225,
#  '간다고': 225,
#  '시대': 225,
#  '역사': 225,
#  '최고': 224,
#  '걱정': 224,
#  '슈카': 224,
#  '보여': 222,
#  '경제': 222,
#  '차이': 222,
#  '게임': 222,
#  '버스': 222,
#  '나가': 222,
#  '지표': 221,
#  '오른다': 221,
#  '구라': 221,
#  '저러': 221,
#  '던지': 220,
#  '성공': 220,
#  '사서': 219,
#  'ㄴㄴ': 219,
#  '아프': 218,
#  '둘다': 218,
#  '올라서': 218,
#  '재밌': 217,
#  '매일': 217,
#  '증권': 217,
#  '음봉': 217,
#  '음전': 215,
#  '뒤질': 215,
#  '자살': 214,
#  '댓글': 213,
#  '드가': 212,
#  '머리': 212,
#  '상환': 212,
#  '웃기': 211,
#  '머티': 211,
#  '유지': 210,
#  '없제?': 210,
#  '제대로': 210,
#  '추가': 210,
#  '이름': 208,
#  '할때': 208,
#  '자회사': 208,
#  '대한': 206,
#  'ㅅㄱ': 205,
#  '사이': 205,
#  '현대차': 205,
#  '시기': 205,
#  '애미': 205,
#  '그럴': 203,
#  '실현': 202,
#  '입갤': 202,
#  '올라갈': 202,
#  '일본': 201,
#  '로봇': 200,
#  '까지': 200,
#  '대주': 200,
#  '업체': 200,
#  '추세': 200,
#  '물려': 200,
#  '대출': 199,
#  '강남': 199,
#  '실체': 199,
#  '일선': 198,
#  '먼저': 198,
#  '잡주': 197,
#  '휫자': 197,
#  '드디어': 197,
#  '아재': 197,
#  '확률': 197,
#  '초전도치': 196,
#  '급등주': 196,
#  '내년': 196,
#  '속보': 196,
#  '오래': 195,
#  '섹스': 195,
#  '위험': 195,
#  '현실': 194,
#  '돌아가': 194,
#  '영업이익': 193,
#  '이젠': 192,
#  '논리': 192,
#  '리포트': 191,
#  '에코바이오': 191,
#  '테크': 190,
#  '밧데리': 190,
#  '달러': 190,
#  '개꿀': 189,
#  '보임': 189,
#  '결과': 188,
#  '알려': 187,
#  '쳐먹': 187,
#  '시초': 187,
#  '자꾸': 186,
#  '갈듯': 186,
#  '기다리': 185,
#  '잔고': 185,
#  '전기': 185,
#  '영익': 185,
#  '숏충이': 184,
#  '깨지': 184,
#  '무적': 184,
#  '방법': 184,
#  '금융': 184,
#  '프로그램': 184,
#  '국민': 183,
#  '경우': 183,
#  '마이너스': 183,
#  '때리': 183,
#  '따리': 183,
#  '흐름': 182,
#  '죄다': 182,
#  '급락': 182,
#  '미리': 182,
#  '회복': 181,
#  '한강': 181,
#  '한번': 181,
#  '빠떼리': 181,
#  '에스': 181,
#  '보통': 179,
#  '보소': 179,
#  '자산': 178,
#  '아주': 178,
#  '복사': 178,
#  '최대': 178,
#  '당연히': 178,
#  '언급': 178,
#  '무빙': 178,
#  '못사': 178,
#  '그랬': 178,
#  '등등': 178,
#  '신성델타테크': 178,
#  '이딴': 177,
#  '대충': 177,
#  '배아파': 177,
#  '완전': 177,
#  '밸류': 177,
#  '무증': 177,
#  '작전주': 176,
#  '계약': 176,
#  '개발': 176,
#  '이번주': 175,
#  '직전': 175,
#  '난리': 175,
#  '엘지': 175,
#  '있음?': 174,
#  '정말': 174,
#  '지지': 174,
#  '반영': 173,
#  '점마': 173,
#  '존나게': 173,
#  '떨구': 173,
#  'ㅇㅇㅇ': 173,
#  '혹시': 172,
#  '유동': 172,
#  '마감': 172,
#  '팩트': 172,
#  '많음': 171,
#  '보내': 171,
#  '시점': 171,
#  '조심': 171,
#  '공유': 170,
#  '분명': 170,
#  '전재산': 170,
#  '하방': 170,
#  '조롱': 169,
#  '리얼': 169,
#  '금요일': 169,
#  '졸업': 168,
#  '희망': 168,
#  '달리': 168,
#  '생산': 168,
#  '말고': 168,
#  '적정가': 167,
#  '전체': 167,
#  '놈들': 167,
#  '포지션': 167,
#  '도대체': 167,
#  '실력': 167,
#  '보합': 167,
#  '부동산': 166,
#  '조만간': 166,
#  '천억': 166,
#  '이노': 166,
#  '개새끼': 166,
#  '에코캡': 166,
#  '호구': 165,
#  '현금': 165,
#  '며칠': 165,
#  '년전': 165,
#  '해야지': 165,
#  '은행': 164,
#  '리스크': 163,
#  '무너지': 163,
#  '진심': 163,
#  '시리즈': 163,
#  '내부자': 163,
#  '보다': 163,
#  '기억': 163,
#  '미붕이': 163,
#  '같음': 162,
#  '거래대금': 162,
#  '년도': 162,
#  '만원일때': 161,
#  '설명': 161,
#  '이득': 160,
#  '차라리': 160,
#  '내릴': 160,
#  '랠리': 160,
#  '대박': 160,
#  '새로운': 160,
#  '이전': 160,
#  '이틀': 159,
#  '손해': 159,
#  '계산': 159,
#  '좆차전지': 158,
#  '무시': 158,
#  '들어갈': 158,
#  '대신': 158,
#  '움직이': 158,
#  '외궈': 157,
#  '당하': 157,
#  '오후': 157,
#  '마음': 157,
#  '끝물': 157,
#  '승리': 157,
#  '올릴': 157,
#  '홀딩스': 157,
#  '그나마': 156,
#  '파워': 156,
#  '대한민국': 156,
#  '개같이': 156,
#  '아마': 156,
#  '돌리': 156,
#  '자신': 156,
#  '최고점': 156,
#  '나온다': 156,
#  '확인': 155,
#  '개미털기': 155,
#  '아까': 155,
#  '살껄': 155,
#  '청산': 155,
#  '셀트': 155,
#  '욕심': 155,
#  '현대': 155,
#  '달성': 155,
#  '타점': 154,
#  '에서': 154,
#  '큐ㅠㅠㅠ': 154,
#  '망했': 154,
#  '유증': 154,
#  '초반': 153,
#  '생각함': 153,
#  '만큼': 153,
#  '조선장': 153,
#  '그대로': 152,
#  '판단': 152,
#  '배당': 151,
#  '심리': 151,
#  '평생': 150,
#  '레버리지': 150,
#  '쏜다': 150,
#  '훨씬': 150,
#  '고평가': 150,
#  '에너지': 150,
#  '씹스캠': 150,
#  '규모': 150,
#  '증시': 150,
#  '펀드': 150,
#  '주당': 149,
#  '주변': 149,
#  '쓰레기': 149,
#  '하락장': 149,
#  '뒤졌': 149,
#  '하이닉스': 149,
#  '가노': 149,
#  '쳐서': 148,
#  '금지': 148,
#  '선반영': 148,
#  '올렸': 148,
#  '충이': 148,
#  '나와서': 148,
#  '비율': 147,
#  '돈복사': 147,
#  '갤러리': 147,
#  '몰라': 147,
#  '중임': 147,
#  '평균': 147,
#  '갤러': 147,
#  '물려서': 147,
#  '부럽다': 147,
#  '엘엔에프': 147,
#  '기간': 146,
#  '심지어': 146,
#  '개씹': 146,
#  '부활': 146,
#  '지리': 146,
#  '후회': 146,
#  '전환': 146,
#  '뭐냐': 146,
#  '수주': 146,
#  '기본': 145,
#  '아이': 145,
#  '오를때': 145,
#  '축하': 145,
#  '빠졌': 144,
#  '살걸': 144,
#  '죽이': 144,
#  '특히': 144,
#  '떨어졌': 143,
#  'ㅁㅊ': 143,
#  '뭐임?': 143,
#  '치킨': 143,
#  '장대': 143,
#  '이슈': 143,
#  '공급': 143,
#  '개소리': 143,
#  '재미': 142,
#  '적당히': 142,
#  'ㅇㅅㅇ': 142,
#  '인데': 142,
#  '대기': 141,
#  '무한': 141,
#  '슈팅': 140,
#  '전고': 140,
#  '그동안': 140,
#  '주포': 140,
#  '과연': 139,
#  '떨어진': 139,
#  '야수': 139,
#  '옵션': 139,
#  '무서워서': 139,
#  '바라': 139,
#  '갈때': 138,
#  '실시간': 138,
#  '어ㅋㅋㅋ': 138,
#  '신풍제약': 138,
#  '뒤진': 138,
#  '부정': 138,
#  '방어': 138,
#  '만약': 138,
#  '지나': 137,
#  '한다고': 137,
#  '반복': 137,
#  '전망': 137,
#  '코붕이': 137,
#  '세금': 136,
#  '의심': 136,
#  '사놓': 136,
#  '게이': 136,
#  '이노베이션': 136,
#  '건지': 136,
#  '반대': 136,
#  '확신': 136,
#  '퓨처': 136,
#  '어렵': 136,
#  '확실히': 135,
#  '유입': 135,
#  '자동차': 135,
#  '영역': 135,
#  '드립니다': 135,
#  '바보': 134,
#  'ㄹㅇㅋㅋㅋ': 134,
#  '동시': 134,
#  '된다고': 134,
#  '살까': 134,
#  '한방': 134,
#  '에프': 134,
#  '시절': 134,
#  '다행': 133,
#  '떨어짐': 133,
#  '근본': 133,
#  '완료': 133,
#  '숏커버': 133,
#  '근처': 133,
#  '구조': 133,
#  '우상향': 132,
#  '높음': 132,
#  '역대급': 132,
#  'lg화학': 132,
#  '복구': 132,
#  '가네': 132,
#  '곱버스': 131,
#  '실제로': 131,
#  '있음': 131,
#  '시즌': 131,
#  '이말올': 131,
#  '공포': 131,
#  '듯이': 131,
#  '씨발년': 131,
#  '나락가': 130,
#  '신라젠': 130,
#  '포스코케미칼': 130,
#  '삼스디': 130,
#  '레전드': 129,
#  '저번주': 129,
#  '가진': 129,
#  '년뒤': 129,
#  '안산': 128,
#  '쥐좆': 128,
#  '상한': 128,
#  '아무': 128,
#  '저번': 128,
#  '대표': 128,
#  '코비': 128,
#  '아가리': 127,
#  '미안': 127,
#  '기존': 127,
#  '금액': 127,
#  '달달': 127,
#  '이수': 127,
#  '개별주': 126,
#  '폭탄': 126,
#  '허허': 126,
#  '년에': 126,
#  '아예': 126,
#  '레인보우': 126,
#  '코반꿀': 126,
#  '보고': 125,
#  '왤케': 125,
#  '검색': 125,
#  '결정': 125,
#  '오지': 125,
#  '안티': 125,
#  '개관': 124,
#  '이래': 124,
#  '빠질': 124,
#  '파산': 124,
#  '심장': 124,
#  '전쟁': 124,
#  'ㅉㅉ': 124,
#  '솔루션': 124,
#  '몰리': 123,
#  '연상': 123,
#  '따라가': 123,
#  '아쉽': 123,
#  '그런데': 123,
#  '행복': 123,
#  '괜히': 123,
#  '올라도': 123,
#  '천보': 123,
#  '사야지': 123,
#  '멸망': 122,
#  '꼬라박': 122,
#  '전세계': 122,
#  '몰라도': 122,
#  '미수': 122,
#  '매집': 121,
#  '과거': 121,
#  '영향': 121,
#  '씨젠': 121,
#  '봐야': 121,
#  '대주주': 120,
#  '남자': 120,
#  '단위': 120,
#  '알빠노': 119,
#  '상관없': 119,
#  '장난': 119,
#  '그러니까': 119,
#  '정지': 119,
#  '사장': 119,
#  '기대감': 118,
#  '고맙': 118,
#  '여자': 118,
#  '다니': 118,
#  '차전지주': 118,
#  '터치': 118,
#  '나와': 118,
#  '두산': 117,
#  '사지': 117,
#  '광신도': 117,
#  '국가': 117,
#  '만원때': 117,
#  '안정': 117,
#  '겨우': 117,
#  '얼즈': 117,
#  '열심히': 116,
#  '사야': 116,
#  'ㅆㅂ': 116,
#  '실패': 116,
#  '상관': 116,
#  '근거': 116,
#  '방금': 116,
#  '방송': 116,
#  '상대': 115,
#  '경험': 115,
#  '엔비': 115,
#  '어쩔': 115,
#  '꼬라지': 115,
#  '시세': 115,
#  '될지': 115,
#  '꾸준히': 115,
#  '인수': 115,
#  '실리': 115,
#  '수요': 115,
#  '증자': 115,
#  '에이치엔': 115,
#  '드가자': 114,
#  '해외': 114,
#  '신경': 114,
#  '숏친': 114,
#  '피자': 114,
#  '아파트': 114,
#  '마소': 114,
#  '서울': 114,
#  '올라오': 114,
#  '유럽': 114,
#  '내내': 114,
#  '대로': 114,
#  '신규': 114,
#  '빠진': 113,
#  '지능': 113,
#  '박스': 113,
#  '자랑': 113,
#  '주식시장': 113,
#  '와중': 113,
#  '누르': 113,
#  '주도주': 113,
#  '이하': 112,
#  '여러': 112,
#  ...}

# %% [markdown]
# ### 6-a-4. 토큰 분포 검색하여, 정규화 해야할 단어 리스트 만들기

# %% [markdown]
# #### 6-a-4-1. 토큰 분포 검색

# %%
    """
    주어진 딕셔너리에서 입력된 텍스트를 포함하는 모든 키를 찾아 리스트로 반환하는 함수입니다.

    :param input_dict: 검색할 딕셔너리
    :param search_text: 찾고자 하는 텍스트
    :return: 입력된 텍스트를 포함하는 키들의 리스트
    """

def find_keys_containing_text(input_dict, search_text):
  # 입력된 텍스트를 포함하는 키를 찾기
  keys_with_text = [key for key in input_dict if search_text in key]

  return keys_with_text

# %%
search_text = "모르"
keys_with_text = find_keys_containing_text(sorted_tokens_dict, search_text)
keys_with_text
# Out:
# ['모르', '모르노', '멋모르', '모르쇠', '모르나', '모르자나', '아모르파티']

# %% [markdown]
# #### 6-a-4-2. df 에서 특정 token 을 포함하는 row 찾아서 출력

# %%
    """
    주어진 데이터프레임에서 특정 열에 입력된 토큰을 포함하는 모든 행을 찾아 반환하는 함수입니다.

    :param dataframe: 검색할 데이터프레임
    :param column_name: 토큰이 포함된 열의 이름
    :param search_token: 찾고자 하는 토큰
    :return: 입력된 토큰을 포함하는 모든 행
    """

def find_rows_containing_token(dataframe, column_name, search_token):
  # 입력된 토큰을 포함하는 행을 필터링
  filtered_rows = dataframe[dataframe[column_name].apply(lambda tokens: search_token in tokens)]

  return filtered_rows

# %%
# 특정 token 을 포함하는 row 출력
search_token = "멋모르"
result_df = find_rows_containing_token(df, "tokens", search_token)
print(result_df)
# Out:
#      community gall_id search_keyword   number date_created time_created  \
# 8428  dcinside  dow100             에코  1011019   2023-04-07     13:48:54
#
#           author  is_reply  text_length  \
# 8428  ㅇㅇ(223.39)         0          155
#
#                                             spaced_text  \
# 8428  수많은 주식갤 경험상 에코프로같은건 디시 투자갤러리에서 뛰어들면 고점임요즘은 많이 ...
#
#                                                  tokens
# 8428  [수많, 주식, 경험, 에코프로, 디시, 투자, 갤러리, 뛰어들, 고점, 요즘, 많...

# %% [markdown]
# #### 6-a-4-3. 정규화 리스트
# - '주식':
#
#  '장주',
#  '이식',
#  '주식',
#  주식비',
# '신주식',
#  '입주식',
#  '민주식'
#  '성주식- '이차전지': '차전지', '좆차전지', '차전지주', '차전자', '전지', '전지용'
# - '지금': '지금껏', '지금이라도', '지금도'
# - '오늘':'오늘도', '나오늘'
# - '만원일때': '만원때'
# - '시총': '시가총액'
# ',
#  '주주식'
#
# - 매수 : '풀매수', '매수세', '순매수', '종가매수', '매수한', '공매수', '공개매수', '매수인'
# - 매도 : '순매도', '매도질'
# - 인버스 :  '닥버스',
#  '곱스',
#
# - 에코프로 : 에코호로, 에코프로비엠, 에코호로비엠, 에코비엠, 에코후로, 에코형제, 에코푸로, 에코호, 에코다
# - 시발 : ㅅㅂ, ㅆㅂ, ㅅㅂㅋㅋ, 씨발, 씨발년, 씨발련, 씨팔, 씨부리, 씨발놈, 씨부랄, 씨부럴, 씨이팔, 씨발씨발, 시벌, 개씹
# - 병신 : ㅂㅅ, 븅신, 개병, 빙신, 등신
# - 새끼 : 새끼들, 새기, 새낀, 새리, 새꺄, 애새끼, 이새끼, 저새끼, 세끼, 개새끼, 호로새끼, 십새끼, 씹새끼, 씹새끼들
# - 고점 : 전고점, 최고점
# - "오르": '오르네', '오르노', '오르면',
#  '오르냐'
#  '떠오르,
#  '날아오리',
#  '르고',
#  '르내리락',
#  '타오르',
#  '기어오르',
# 오르는거오르',
#  '오내릴',
#  차오르',
#  나오르',
#  뛰어오르',
#  '솟아오르'
#  '오르는
#
# - "올라" : '올리',
#  '올랐'
#
#  '올라'',
#  올라',
# '올려',
#  '올린',
#  '올라서',
#  '올라갈,
#  '올',
#  '이올',
#  '라도',
#  올라오',
#  '올라타',
#
#  '올인',
#  '들어',
#  '올간',
#  '라감',
#  올려서',
#  쳐올리',
# '올라갔',
#  '올라간다',
#
#  '올린다,
#  '끌어리',
#  '올으니',
#  '라온',
#  내려올',
# '들어올리',
#  '올린다고,
#  '올라라',
#  '올옴',
#  '라탄',
#  올려야',
# '나올까',
#  '끌어올린,
#  '올라올,
#  '쳐올',
#  '쳐릴',
#  '나올라갈지',
#  ',
#  '올까요',
#  '거',
#  '올간'올려놓',
#  '올꺼',
# '올라라',
#  '올려도',,
#  '돌아올',
#  '올라탄',
#  '올린'에탄올',
# '끌어올려'
#  '올매',
# ',
#    '들어올려',
#  '올른',
# '올라온다',
#  '올라고',
#
#  '올려놨'
#  '올려치,
#  '올린다까린다',
#   '올라와야',다는',
#  '올라',
#  '올다면',
#  나올까봐',
# '올려야지',
#  '다가올'면픽',
#  올게요',
#  '올걸',
#  '라갔으면',,
#  '올릴까 렸었',
#  올라가',
#  올'올러',
#   '올라갈까',
#
#  '올랐올데',
#  '라돌아올까',
#  따라올',
# '뛰어올랐',
#  '올려나', '올렸으, 라',
#  '어올려야',
#  '기어올라'
#  '올라봐라,
#  '올려붙',
#  '날아올,
#  '도올',,
#  '올라프'
#  '올루',
#  '올바른,
#
#  '올린다구'
# 올려줄',
#
#  '떠올라야'
#  '들어올라고 ,
#  '개올'리올려놔서',
#  '끌어올린다는'와어나올',
# '놀러올',
#  리올린다느니',
#
# - "내리": '내리',
#  '내려가'부자',
#
#  '내용'
#  '내려,
#  '내렸갈',
#  '내',
#   '내린',,
#  '끝내'내연',
#  '내재',
#  '내려갔',
#  '인터내널',
#  '
#  '박살내'
#  '내역'수',
#  '흘
#  '빚내'리',
#  '내',
#  '장',
#  '내외다',
#  '라',
#  '면',
#  '려와',
#  '인내심',
# 아들',
#   '내기',
# 다는',
#  '내리',
#  ',
#  '오르,
#  '뛰어내가',
#  '
#  '내려온내',
#  '안',
#  '처내'려치',
#  '찾
#  '내도',
# ',
#  '내다도려내',
#  곧내',
#  ' '내거'
#  '내놔라',
# 내봤',
#  '내내',
#  '떠 '내려찍',
# '내소',
#  '
#  '내세운',내려놓',
#  '내차',
#
#  '시내',야',
#  ''내음',
#  '내세워서',
#
#  '겁내',막무가내',
#   '내버리',
# ,
#  '끌어 '끌어내릴',어주',
#  '내
#  '내치',
# 만내',
#  '내버렸',
#
#  '내려갈까
#  '흘러내빼내',
#  '',
#  '빛내',
#  '내려
#  '전내',
#  '내준다는'내루',
#  '돌려보내',
#  '내려왔었',
#  '내후',
#  '내사랑',
#  '내려보',
#  '내예',
#  '돌려내',
#  '쳐내려갔',
#  '흘러내린',
#  '끄집어내리',
#  '봄내',
#  '내건',
#  '국내외',
#  '안내서',
#  '내려간다구',
#  '국내법',
#  '차내',
#  '흘러내렸',
#  '안내원',
#  '내쉬',
#  '흉내내',
#  '내리찍',
#  '내민',
#  '집내',
#  '잡아내',
#  '끌어내려',
#  '내려놨',
#  '내려처',
#  '내준',
#  '내궁',
#  '내장재',
#  '내이',
#  '다이내믹한',
#  '내립시다',
#  '뛰어내려',
#  '뿜어내',
#  '내려갈수록'뛰어올라',
#  '올가',
#  '올테니',
#  '올라와도',
#  '올려고',
#  '기어올라왔',
#  '끌어올려준',
#  '떠올렸',
#  '올라간다면',
#  '올하',
#  '올소',
#  '올까봐',
#  '끌어올렸으면',
#  '올라설',
#  '떠올라서',
#  '올러가',
#  '올릴수록',
#  '따라올라갔',
#  '올릭',
#  '올라간다니까'
# - ,
#  '오르길',
#  '달아오르']

# %% [markdown]
# ## 6-b. 토큰 정규화

# %% [markdown]
# ### 6-b-1. 토큰 정규화 함수

# %%
def normalize_tokens_with_dict(dataframe, column_name, normalization_dict):
    """
    데이터프레임 내에서 지정된 열의 토큰들을 주어진 정규화 딕셔너리에 따라 변경하는 함수입니다.

    :param dataframe: 정규화할 데이터프레임
    :param column_name: 토큰이 포함된 열의 이름
    :param normalization_dict: 정규화를 위한 딕셔너리. 예: {"에코프로": ["에코호로", ...], "시발": ["ㅅㅂ", ...]}
    :return: 정규화된 데이터프레임
    """
    # 토큰 정규화 함수
    def normalize(token_list):
        return [next((key for key, values in normalization_dict.items() if token in values), token) for token in token_list]

    # 정규화 적용
    dataframe[column_name] = dataframe[column_name].apply(normalize)

    return dataframe

# %% [markdown]
# ### 6-b-2. 정규화 목록 딕셔너리 만들기

# %%
# 정규화 목록 딕셔너리
normalization_dict = {
    "에코프로": ['에코호로', '에코프로비엠', '에코호로비엠', '에코비엠', '에코후로', '에코형제', '에코푸로', '에코호', '에코다']
    , "시발": ['ㅅㅂ', 'ㅆㅂ', 'ㅅㅂㅋㅋ', '씨발', '씨발년', '씨발련', '씨팔', '씨부리', '씨발놈', '씨부랄', '씨부럴', '씨이팔', '씨발씨발', '시벌', 
             '개씹']
    , "병신": ['ㅂㅅ', '븅신', '개병', '빙신', '등신']
    , "새끼": ['새끼들', '새기', '새낀', '새리', '새꺄', '애새끼', '이새끼', '저새끼', '세끼', '개새끼', '호로새끼', '십새끼', '씹새끼', '씹새끼들']
    , "고점" : ['전고점', '최고점']
    , "오르": ['오르네', '오르노', '오르면', '오르냐', '떠오르', '날아오르', '오르고', '오르는데', '타오르', '기어오르', '불타오르', '오르는거', 
              '차오르', '나오르', '뛰어오르', '솟아오르', '오르는', '오르길', '달아오르', '올리', '올랐', '올라가', '올라', '올려', '올린', '올라서', 
              '올라갈', '올릴', '올렸', '올라도', '올라오', '올라타', '올림', 
              '올라야', '올라간', '올라감', '올려서', '쳐올리', '올라갔', '올라간다', '올라왔', '올린다', '끌어올리', '올랐으니', '올라온', 
              '들어올리', '올린다고', '올라탈', '올려라', '올라옴', '올라탄', '올려야', '끌어올린', '올라올', '쳐올라', '쳐올릴', '나올지', 
              '올르', '올라갈지', '올라탔', '올랐었', '올라와서', '올라간다고', '올라라', '올려도', '끌어올렸', '올라탄다', '올린다는', 
              '올라와', '쳐올림', '끌어올려', '끌어올려서', '끌어올릴', '들어올려', '올른', '올라온다', '올름', '올린다니까', '끌어올린다', 
              '올립니다', '올라와야', '올라간다는', '올릴라', '올린다면', '올려야지', '올려준다', '올라갔으면', '올랐는데', '올릴까', '날아올라', 
              '올렸었', '퍼올려', '올라요', '기어올라가', '올렸으니', '올러', '올라갈까', '올랐으나', '뛰어올랐', '올라갈수록', '날아올랐', 
              '올렸으며', '올려요', '끌어올려야', '올라봐라', '올려붙이', '날아올', '올루', '올려둔', '올릴려면', '올라갔었', '올린다구', 
              '올려줘도', '끌어올려줄', '올라온다는', '밀어올리기', '올려놔서', '끌어올린는', '뛰어올라', '올라와도', '기어올라왔', '끌어올려준', 
              '올라간다면', '올까봐', '끌어올렸으면', '올릴수록', '따라올라갔', '올라간다니까']
    , "내리": ['내리', '내려가', '내릴', '내려', '내렸', '내려갈', '내려오', '내린', '내림', '내려감', '내려올', '내려갔', '내려야', '내려도', 
             '내려서', '흘러내리', '쳐내리', '끌어내리', '내린다', '내린다고', '내려간', '내려간다', '내려왔', '내려와', '내려온', '내려라', 
             '내릴지', '내려옴', '내린다는', '내려와', '내리막', '내려온다', '내려와라', '내릴까', '내려앉', '내려야지', '내려간다고', 
             '내려온다고', '내립니다', '내리막길', '흘러내릴', '내릴라고', '내려갑다', '녹아내리', '내려간다면', '내려와야', '흘러내린다', 
             '내려간다는', '내리락하', '내려줘야', '끌어내린', '내려줄', '내릴래', '끌어내려서', '끌어내릴', '내려버렸', '흘러내려도', 
             '내렸으니', '내려지', '내려졌었', '내려왔으니', '내려갈까', '흘러내려', '쳐내려가', '내려져', '내려졌', '내려왔었', '쳐내려갔',
             '내려다', '내려간다구', '흘러내렸', '끌어내려', '내려갈수록']
    , "매수": ['풀매수', '매수세', '순매수', '종가매수', '매수한', '공매수', '공개매수', '매수인']
    , "매도": ['순매도', '매도질']
    , "인버스": ['닥버스', '곱버스']
}

# %% [markdown]
# ### 6-b-3. df의 토큰 정규화시키기

# %%
# df에 적용하여 새로운 df 생성
normalized_df = normalize_tokens_with_dict(df, 'tokens', normalization_dict)
print(normalized_df)
# Out:
#        community    gall_id search_keyword  number date_created time_created  \
# 0       dcinside     snp500             에코  832014   2023-10-27     15:50:34
# 1       dcinside     snp500             에코  831598   2023-10-26     21:13:32
# 2       dcinside     snp500             에코  831598   2023-10-26     21:14:04
# 3       dcinside     snp500             에코  831598   2023-10-26     21:15:57
# 4       dcinside     snp500             에코  831598   2023-10-26     21:22:49
# ...          ...        ...            ...     ...          ...          ...
# 108940  dcinside  tenbagger             에코   32744   2020-04-13     19:22:20
# 108941  dcinside  tenbagger             에코   32744   2020-04-13     19:22:23
# 108942  dcinside  tenbagger             에코   32744   2020-04-13     19:22:48
# 108943  dcinside  tenbagger             에코   32744   2020-04-13     19:23:35
# 108944  dcinside  tenbagger             에코   32744   2020-04-13     19:24:25
#
#               author  is_reply  text_length  \
# 0          ㅇㅇ(58.78)         0           56
# 1       슨붕이(106.101)         0           11
# 2          모든주식을소유하라         1            9
# 3                 ㅇㅇ         1           23
# 4                 ㅇㅇ         1           20
# ...              ...       ...          ...
# 108940   ㅇㅇ(182.222)         1           12
# 108941   ㅂㅂ(117.111)         1           49
# 108942          네코펀드         1           42
# 108943   123(118.38)         1           25
# 108944   ㅇㅇ(211.225)         1           77
#
#                                               spaced_text  \
# 0       국연 에코프로 퍼이상 투자해야한다 전국민 자산증발에 앞서야 추후 글로벌 시장에 조선...
# 1                                             에코푸로 손절 ㄷㄷㄷ
# 2                                               알빠노? 캬ㅋㅋㅋ
# 3                                 그냥업황나빠진건데사ㅇㅈㄹ잘못ㅇㅈㅈㅓ대안ㅋㅋ
# 4                                   오근디돈 억넘게 에코프로에박앗네상남ㅇㅂ
# ...                                                   ...
# 108940                                     차 자체도 전기차가 좋을껄
# 108941  공공기관은 메리트 있음 미세먼지 심할떼 강제로 부제 시키는데 전기차 하이브리드차는 예외임
# 108942         무인 전기차로 갈려면 어쩔수 없이 전기가 유리함 휘발류 태워서는 충당이 힘듬
# 108943                         충전시간 인프라 생각하면 지금 기술력으로 별로임
# 108944  운행 해보면 알 수 있음 전기차 타고 있는 입장에서 충전이 좀 번거로울 뿐이지승차감...
#
#                                                    tokens
# 0       [국연, 에코프로, 이상, 투자, 국민, 자산, 증발, 앞서, 추후, 글로벌, 시장...
# 1                                         [에코프로, 손절, ㄷㄷㄷ]
# 2                                          [알빠노, ?, 캬ㅋㅋㅋ]
# 3                               [그냥, 황나, 빠진, 건데, ㅇㅈㄹ, 잘못]
# 4                                          [근디, 에코프로, 상남]
# ...                                                   ...
# 108940                                           [자체, 전기]
# 108941  [공공, 기관, 메리트, 있음, 미세먼지, 심할, 강제, 부제, 시키, 전기차, 하...
# 108942         [무인, 전기, 갈려면, 어쩔, 없이, 전기, 유리, 휘발, 태워서, 충당]
# 108943                     [충전, 시간, 인프라, 생각, 지금, 기술력, 별로]
# 108944  [운행, 전기차, 입장, 충전, 승차감, 소음, 가속, 등등, 내연, 기관차, 다시...
#
# [108945 rows x 11 columns]

# %% [markdown]
# ### 6-b-4. 토큰 정규화 잘 되었는지 확인
# - 기존의 토큰들이 전부 대체된 것을 확인할 수 있다

# %%
normalized_tokens_dict = make_tokens_count_dict(normalized_df, 'tokens')

search_text = "매수"
keys_with_text = find_keys_containing_text(normalized_tokens_dict, search_text)
keys_with_text
# Out:
# ['매수']

# %%
# 정규화된 토큰 분포
normalized_tokens_dict
# Out:
# {'에코프로': 44575,
#  '?': 19667,
#  'ㅋㅋㅋ': 16522,
#  '에코': 10603,
#  'ㅋㅋ': 7732,
#  '시발': 5311,
#  '지금': 5041,
#  '주식': 4943,
#  '오늘': 4214,
#  '새끼': 4185,
#  '만원': 3980,
#  '진짜': 3659,
#  '오르': 2753,
#  '차전지': 2681,
#  '!': 2639,
#  '병신': 2540,
#  '매수': 2477,
#  '생각': 2439,
#  '존나': 2435,
#  '사람': 2422,
#  '그냥': 2406,
#  'ㄹㅇ': 2322,
#  '개미': 2288,
#  '근데': 2285,
#  'ㅇㅇ': 2271,
#  '종목': 2189,
#  '공매도': 2007,
#  'ㄷㄷ': 1979,
#  '캬ㅋㅋㅋ': 1927,
#  '아직': 1882,
#  '이제': 1864,
#  '수익': 1834,
#  '코스닥': 1788,
#  '내일': 1772,
#  '신성': 1764,
#  '정도': 1645,
#  '다시': 1618,
#  'ㄷㄷㄷ': 1600,
#  '시총': 1578,
#  '고점': 1576,
#  '프로': 1535,
#  '나오': 1500,
#  '모르': 1451,
#  '가능': 1450,
#  '이유': 1436,
#  '회사': 1428,
#  '이상': 1402,
#  '매도': 1394,
#  '국장': 1375,
#  '너무': 1344,
#  '테슬라': 1343,
#  '주주': 1310,
#  '이런': 1307,
#  '계속': 1293,
#  '포스코': 1274,
#  '많이': 1266,
#  '시작': 1220,
#  '주가': 1208,
#  '상승': 1201,
#  '실적': 1201,
#  '어제': 1181,
#  '투자': 1180,
#  '다른': 1163,
#  '비엠': 1163,
#  '금양': 1163,
#  '들어가': 1123,
#  '간다': 1122,
#  '차트': 1107,
#  '이미': 1048,
#  '시장': 1030,
#  '배터리': 1021,
#  '하락': 1011,
#  '떨어지': 997,
#  '세력': 991,
#  '기업': 981,
#  '운지': 981,
#  '때문': 976,
#  '가격': 970,
#  '그런': 941,
#  '공매': 934,
#  '거품': 925,
#  '조정': 902,
#  '초전도체': 902,
#  '광기': 898,
#  '평단': 894,
#  '삼전': 891,
#  'ㅠㅠ': 840,
#  '건데': 837,
#  '지수': 836,
#  '보이': 836,
#  '단타': 828,
#  '기관': 825,
#  '미국': 815,
#  '한국': 811,
#  '수급': 807,
#  'ㅡㅡ': 803,
#  '코스피': 791,
#  '손절': 788,
#  '얼마': 785,
#  '그럼': 782,
#  '올리': 778,
#  '같이': 771,
#  '포홀': 771,
#  '폭락': 770,
#  '아니': 766,
#  '올랐': 762,
#  '다음': 735,
#  '그때': 735,
#  '미친': 735,
#  '오를': 710,
#  '사라': 702,
#  '그래서': 702,
#  '미래': 687,
#  '오른': 674,
#  '물린': 670,
#  '물량': 669,
#  '빠지': 668,
#  '그리고': 662,
#  '결국': 660,
#  '언제': 654,
#  '해서': 651,
#  '무슨': 644,
#  '올해': 637,
#  '나스닥': 628,
#  '이번': 626,
#  '아저씨': 622,
#  '상장': 619,
#  '빨리': 617,
#  '이렇게': 614,
#  '개인': 611,
#  '그렇': 604,
#  '해도': 602,
#  '뒤지': 602,
#  '바로': 601,
#  '고수': 600,
#  '매매': 599,
#  '절대': 592,
#  '어떻게': 590,
#  '가치': 589,
#  '계좌': 587,
#  '반도체': 587,
#  '텐데': 587,
#  '그러': 586,
#  '소리': 584,
#  'ㅈㄴ': 583,
#  '시간': 583,
#  '무조건': 572,
#  '하루': 562,
#  '예상': 552,
#  '형제': 549,
#  '양극재': 548,
#  '미장': 547,
#  '거래': 547,
#  '기회': 546,
#  '추천': 545,
#  '만들': 544,
#  '어케': 543,
#  '제발': 539,
#  '그래도': 533,
#  '인생': 530,
#  '얘기': 525,
#  '몰빵': 525,
#  '호로': 523,
#  '인증': 517,
#  '느낌': 515,
#  '솔직히': 514,
#  '일단': 512,
#  '사실': 510,
#  '저점': 510,
#  '어차피': 507,
#  '외인': 507,
#  '익절': 502,
#  '올라가': 500,
#  '나올': 497,
#  '전기차': 495,
#  '개추': 493,
#  '인버스': 493,
#  '봐도': 493,
#  '가즈아': 488,
#  '거의': 485,
#  '그렇게': 484,
#  '코인': 483,
#  '호재': 481,
#  '버티': 478,
#  '자리': 477,
#  '나락': 475,
#  '원래': 470,
#  '코갤': 469,
#  '풀매수': 468,
#  '바이오': 467,
#  '뉴스': 465,
#  '삼성': 460,
#  '설거지': 456,
#  '카카오': 456,
#  '문제': 452,
#  '닥버스': 452,
#  '매출': 448,
#  '엘앤에프': 448,
#  '현재': 443,
#  '선물': 443,
#  '하한가': 441,
#  '신용': 441,
#  '기술': 440,
#  '지랄': 436,
#  '자체': 434,
#  '개잡주': 433,
#  '돌파': 432,
#  '테마': 430,
#  '작년': 427,
#  '동안': 426,
#  '마지막': 425,
#  '없이': 424,
#  '오름': 422,
#  '사면': 421,
#  '얼마나': 421,
#  '내리': 419,
#  '종토방': 417,
#  '해라': 415,
#  '가지': 415,
#  '조금': 413,
#  '반등': 411,
#  '만원대': 411,
#  '그만': 407,
#  '이러': 407,
#  '맞음': 407,
#  '시외': 407,
#  '된다': 405,
#  '상황': 401,
#  '기분': 401,
#  '성장': 400,
#  '공장': 400,
#  '떡상': 399,
#  '저런': 397,
#  '다들': 396,
#  '종가': 396,
#  '요즘': 392,
#  '시드': 391,
#  '엔비디아': 391,
#  '수준': 390,
#  '편입': 390,
#  '떡락': 387,
#  '이차전지': 386,
#  '나라': 386,
#  '역시': 385,
#  '이해': 384,
#  '양전': 381,
#  'ㄱㄱ': 381,
#  '부자': 381,
#  '소재': 381,
#  '분위기': 380,
#  '자금': 378,
#  '예정': 378,
#  '정보': 375,
#  '바닥': 375,
#  '똑같': 373,
#  '엔솔': 373,
#  '발표': 372,
#  '진입': 368,
#  '나왔': 368,
#  '건가': 367,
#  '급등': 364,
#  '전부': 362,
#  '세계': 360,
#  '작전': 360,
#  '틀딱': 359,
#  '중국': 358,
#  '들어오': 358,
#  '기준': 354,
#  '외국인': 354,
#  '셀트리온': 348,
#  '존버': 348,
#  '장투': 346,
#  '회장': 345,
#  '이후': 344,
#  '분할': 343,
#  '탈출': 343,
#  '떨어질': 343,
#  '섹터': 342,
#  '비싸': 340,
#  '제일': 338,
#  'ㅎㅎ': 335,
#  'ㅇㅈㄹ': 334,
#  '괜찮': 334,
#  '분석': 333,
#  '모든': 332,
#  '해야': 331,
#  '터지': 331,
#  '좆같': 331,
#  '악재': 331,
#  '정신': 330,
#  '비교': 330,
#  '상한가': 330,
#  '목표': 329,
#  '본인': 326,
#  '최소': 325,
#  '거래량': 325,
#  '대비': 323,
#  '봐라': 323,
#  '올라': 322,
#  '친구': 321,
#  '손실': 321,
#  '대체': 321,
#  '관련': 321,
#  '물렸': 320,
#  '정상': 318,
#  '기대': 317,
#  '물리': 317,
#  '지주사': 317,
#  '혼자': 314,
#  '단기': 313,
#  '본다': 312,
#  '테마주': 311,
#  '비중': 309,
#  '저렇게': 308,
#  '순간': 306,
#  '필요': 305,
#  '뒤져': 305,
#  'ㅜㅜ': 305,
#  '네이버': 303,
#  '이기': 303,
#  '추매': 303,
#  '슬슬': 303,
#  '홀딩': 300,
#  '사기': 299,
#  '물론': 298,
#  '모두': 297,
#  '무섭': 297,
#  '에코프로에이치엔': 297,
#  '감사': 295,
#  '대가리': 295,
#  '분기': 292,
#  '조선': 291,
#  '관심': 290,
#  '월요일': 290,
#  '내려가': 289,
#  '기사': 289,
#  '애플': 289,
#  '사고': 289,
#  '아무리': 289,
#  '갑자기': 288,
#  '오히려': 287,
#  '그래': 287,
#  '이야기': 287,
#  '공시': 286,
#  '대부분': 286,
#  '보유': 285,
#  '주린이': 285,
#  '벼락거지': 283,
#  '신고': 281,
#  '비트코인': 281,
#  '벌써': 281,
#  '장기': 280,
#  '들어갔': 280,
#  'ㄹㅇㅋㅋ': 280,
#  '와서': 278,
#  '전자': 278,
#  '대장': 278,
#  '한다': 278,
#  '나중': 277,
#  '국내': 277,
#  '힘들': 277,
#  '중요': 277,
#  '출발': 276,
#  '리튬': 276,
#  '신풍': 275,
#  '나온': 275,
#  '폭등': 274,
#  '쌍봉': 274,
#  '공부': 273,
#  '산업': 273,
#  '거지': 272,
#  '재료': 272,
#  '최근': 271,
#  '아줌마': 271,
#  '나옴': 271,
#  '그룹': 270,
#  '숏스퀴즈': 270,
#  '확정': 270,
#  '타이밍': 269,
#  '준비': 268,
#  '아침': 268,
#  '삼성전자': 267,
#  '올려': 265,
#  '아님?': 265,
#  '의미': 264,
#  '세상': 263,
#  '평가': 263,
#  '지옥': 262,
#  '가장': 262,
#  '망하': 262,
#  '포스코홀딩스': 262,
#  '투자자': 261,
#  '엄마': 261,
#  '만드': 261,
#  '어쩌': 258,
#  '서남': 256,
#  '주도': 256,
#  '탑승': 255,
#  '사업': 255,
#  '도박': 253,
#  '인간': 253,
#  '샀으면': 252,
#  '애초': 252,
#  '저거': 252,
#  '상태': 250,
#  '코로나': 250,
#  '예전': 248,
#  'ㅠㅠㅠ': 248,
#  '처음': 248,
#  '미주갤': 248,
#  '버블': 247,
#  '미쳤': 247,
#  '들어간': 247,
#  '항상': 247,
#  'ㅎㄷㄷ': 247,
#  '맨날': 246,
#  '어느': 245,
#  '설마': 244,
#  '신호': 244,
#  '관련주': 244,
#  '전지': 244,
#  '잘못': 243,
#  '관망': 242,
#  '무지성': 242,
#  '부럽': 241,
#  '화학': 240,
#  '지분': 240,
#  '만주': 239,
#  '호가': 239,
#  '횡보': 239,
#  '산다': 239,
#  '선동': 239,
#  '어떤': 239,
#  '양봉': 239,
#  '올린': 238,
#  '아래': 238,
#  '나머지': 238,
#  '온다': 238,
#  '사도': 238,
#  '걸로': 237,
#  '반토막': 236,
#  '저평가': 236,
#  '정리': 235,
#  '별로': 235,
#  '다르': 233,
#  '코프': 233,
#  '아빠': 232,
#  '당장': 232,
#  '적정': 231,
#  '모름': 231,
#  '유튜브': 231,
#  '따라': 230,
#  '엄청': 230,
#  '금리': 229,
#  '살려': 228,
#  '스캠': 228,
#  '흑우': 227,
#  '고민': 227,
#  '전고점': 227,
#  '대장주': 226,
#  '구경': 226,
#  '이익': 226,
#  '이지랄': 226,
#  '구간': 226,
#  '참고': 226,
#  '인정': 225,
#  '예측': 225,
#  '됨?': 225,
#  '증권사': 225,
#  '간다고': 225,
#  '시대': 225,
#  '역사': 225,
#  '최고': 224,
#  '걱정': 224,
#  '슈카': 224,
#  '보여': 222,
#  '경제': 222,
#  '차이': 222,
#  '게임': 222,
#  '버스': 222,
#  '나가': 222,
#  '지표': 221,
#  '오른다': 221,
#  '구라': 221,
#  '저러': 221,
#  '던지': 220,
#  '성공': 220,
#  '사서': 219,
#  'ㄴㄴ': 219,
#  '아프': 218,
#  '둘다': 218,
#  '올라서': 218,
#  '재밌': 217,
#  '매일': 217,
#  '증권': 217,
#  '음봉': 217,
#  '음전': 215,
#  '뒤질': 215,
#  '자살': 214,
#  '댓글': 213,
#  '드가': 212,
#  '머리': 212,
#  '상환': 212,
#  '웃기': 211,
#  '머티': 211,
#  '유지': 210,
#  '없제?': 210,
#  '제대로': 210,
#  '추가': 210,
#  '이름': 208,
#  '할때': 208,
#  '자회사': 208,
#  '대한': 206,
#  'ㅅㄱ': 205,
#  '사이': 205,
#  '현대차': 205,
#  '시기': 205,
#  '애미': 205,
#  '그럴': 203,
#  '실현': 202,
#  '입갤': 202,
#  '올라갈': 202,
#  '일본': 201,
#  '로봇': 200,
#  '까지': 200,
#  '대주': 200,
#  '업체': 200,
#  '추세': 200,
#  '물려': 200,
#  '대출': 199,
#  '강남': 199,
#  '실체': 199,
#  '일선': 198,
#  '먼저': 198,
#  '잡주': 197,
#  '휫자': 197,
#  '드디어': 197,
#  '아재': 197,
#  '확률': 197,
#  '초전도치': 196,
#  '급등주': 196,
#  '내년': 196,
#  '속보': 196,
#  '오래': 195,
#  '섹스': 195,
#  '위험': 195,
#  '현실': 194,
#  '돌아가': 194,
#  '영업이익': 193,
#  '이젠': 192,
#  '논리': 192,
#  '리포트': 191,
#  '에코바이오': 191,
#  '테크': 190,
#  '밧데리': 190,
#  '달러': 190,
#  '개꿀': 189,
#  '보임': 189,
#  '결과': 188,
#  '알려': 187,
#  '쳐먹': 187,
#  '시초': 187,
#  '자꾸': 186,
#  '갈듯': 186,
#  '기다리': 185,
#  '잔고': 185,
#  '전기': 185,
#  '영익': 185,
#  '숏충이': 184,
#  '깨지': 184,
#  '무적': 184,
#  '방법': 184,
#  '금융': 184,
#  '프로그램': 184,
#  '국민': 183,
#  '경우': 183,
#  '마이너스': 183,
#  '때리': 183,
#  '따리': 183,
#  '흐름': 182,
#  '죄다': 182,
#  '급락': 182,
#  '미리': 182,
#  '회복': 181,
#  '한강': 181,
#  '한번': 181,
#  '빠떼리': 181,
#  '에스': 181,
#  '보통': 179,
#  '보소': 179,
#  '자산': 178,
#  '아주': 178,
#  '복사': 178,
#  '최대': 178,
#  '당연히': 178,
#  '언급': 178,
#  '무빙': 178,
#  '못사': 178,
#  '그랬': 178,
#  '등등': 178,
#  '신성델타테크': 178,
#  '이딴': 177,
#  '대충': 177,
#  '배아파': 177,
#  '완전': 177,
#  '밸류': 177,
#  '무증': 177,
#  '작전주': 176,
#  '계약': 176,
#  '개발': 176,
#  '이번주': 175,
#  '직전': 175,
#  '난리': 175,
#  '엘지': 175,
#  '있음?': 174,
#  '정말': 174,
#  '지지': 174,
#  '반영': 173,
#  '점마': 173,
#  '존나게': 173,
#  '떨구': 173,
#  'ㅇㅇㅇ': 173,
#  '혹시': 172,
#  '유동': 172,
#  '마감': 172,
#  '팩트': 172,
#  '많음': 171,
#  '보내': 171,
#  '시점': 171,
#  '조심': 171,
#  '공유': 170,
#  '분명': 170,
#  '전재산': 170,
#  '하방': 170,
#  '조롱': 169,
#  '리얼': 169,
#  '금요일': 169,
#  '졸업': 168,
#  '희망': 168,
#  '달리': 168,
#  '생산': 168,
#  '말고': 168,
#  '적정가': 167,
#  '전체': 167,
#  '놈들': 167,
#  '포지션': 167,
#  '도대체': 167,
#  '실력': 167,
#  '보합': 167,
#  '부동산': 166,
#  '조만간': 166,
#  '천억': 166,
#  '이노': 166,
#  '에코캡': 166,
#  '호구': 165,
#  '현금': 165,
#  '며칠': 165,
#  '년전': 165,
#  '해야지': 165,
#  '은행': 164,
#  '리스크': 163,
#  '무너지': 163,
#  '진심': 163,
#  '시리즈': 163,
#  '내부자': 163,
#  '보다': 163,
#  '기억': 163,
#  '미붕이': 163,
#  '같음': 162,
#  '거래대금': 162,
#  '년도': 162,
#  '만원일때': 161,
#  '설명': 161,
#  '이득': 160,
#  '차라리': 160,
#  '내릴': 160,
#  '랠리': 160,
#  '대박': 160,
#  '새로운': 160,
#  '이전': 160,
#  '이틀': 159,
#  '손해': 159,
#  '계산': 159,
#  '좆차전지': 158,
#  '무시': 158,
#  '들어갈': 158,
#  '대신': 158,
#  '움직이': 158,
#  '외궈': 157,
#  '당하': 157,
#  '오후': 157,
#  '마음': 157,
#  '끝물': 157,
#  '승리': 157,
#  '올릴': 157,
#  '홀딩스': 157,
#  '그나마': 156,
#  '파워': 156,
#  '대한민국': 156,
#  '개같이': 156,
#  '아마': 156,
#  '돌리': 156,
#  '자신': 156,
#  '최고점': 156,
#  '나온다': 156,
#  '확인': 155,
#  '개미털기': 155,
#  '아까': 155,
#  '살껄': 155,
#  '청산': 155,
#  '셀트': 155,
#  '욕심': 155,
#  '현대': 155,
#  '달성': 155,
#  '타점': 154,
#  '에서': 154,
#  '큐ㅠㅠㅠ': 154,
#  '망했': 154,
#  '유증': 154,
#  '초반': 153,
#  '생각함': 153,
#  '만큼': 153,
#  '조선장': 153,
#  '그대로': 152,
#  '판단': 152,
#  '배당': 151,
#  '심리': 151,
#  '평생': 150,
#  '레버리지': 150,
#  '쏜다': 150,
#  '훨씬': 150,
#  '고평가': 150,
#  '에너지': 150,
#  '씹스캠': 150,
#  '규모': 150,
#  '증시': 150,
#  '펀드': 150,
#  '주당': 149,
#  '주변': 149,
#  '쓰레기': 149,
#  '하락장': 149,
#  '뒤졌': 149,
#  '하이닉스': 149,
#  '가노': 149,
#  '쳐서': 148,
#  '금지': 148,
#  '선반영': 148,
#  '올렸': 148,
#  '충이': 148,
#  '나와서': 148,
#  '비율': 147,
#  '돈복사': 147,
#  '갤러리': 147,
#  '몰라': 147,
#  '중임': 147,
#  '평균': 147,
#  '갤러': 147,
#  '물려서': 147,
#  '부럽다': 147,
#  '엘엔에프': 147,
#  '기간': 146,
#  '심지어': 146,
#  '부활': 146,
#  '지리': 146,
#  '후회': 146,
#  '전환': 146,
#  '뭐냐': 146,
#  '수주': 146,
#  '기본': 145,
#  '아이': 145,
#  '오를때': 145,
#  '축하': 145,
#  '빠졌': 144,
#  '살걸': 144,
#  '죽이': 144,
#  '특히': 144,
#  '떨어졌': 143,
#  'ㅁㅊ': 143,
#  '뭐임?': 143,
#  '치킨': 143,
#  '장대': 143,
#  '이슈': 143,
#  '공급': 143,
#  '개소리': 143,
#  '재미': 142,
#  '적당히': 142,
#  'ㅇㅅㅇ': 142,
#  '인데': 142,
#  '대기': 141,
#  '무한': 141,
#  '슈팅': 140,
#  '전고': 140,
#  '그동안': 140,
#  '주포': 140,
#  '과연': 139,
#  '떨어진': 139,
#  '야수': 139,
#  '옵션': 139,
#  '무서워서': 139,
#  '바라': 139,
#  '갈때': 138,
#  '실시간': 138,
#  '어ㅋㅋㅋ': 138,
#  '신풍제약': 138,
#  '뒤진': 138,
#  '부정': 138,
#  '방어': 138,
#  '만약': 138,
#  '지나': 137,
#  '한다고': 137,
#  '반복': 137,
#  '전망': 137,
#  '코붕이': 137,
#  '세금': 136,
#  '의심': 136,
#  '사놓': 136,
#  '게이': 136,
#  '이노베이션': 136,
#  '건지': 136,
#  '반대': 136,
#  '확신': 136,
#  '퓨처': 136,
#  '어렵': 136,
#  '확실히': 135,
#  '유입': 135,
#  '자동차': 135,
#  '영역': 135,
#  '드립니다': 135,
#  '바보': 134,
#  'ㄹㅇㅋㅋㅋ': 134,
#  '동시': 134,
#  '된다고': 134,
#  '살까': 134,
#  '한방': 134,
#  '에프': 134,
#  '시절': 134,
#  '다행': 133,
#  '떨어짐': 133,
#  '근본': 133,
#  '완료': 133,
#  '숏커버': 133,
#  '근처': 133,
#  '구조': 133,
#  '우상향': 132,
#  '높음': 132,
#  '역대급': 132,
#  'lg화학': 132,
#  '복구': 132,
#  '가네': 132,
#  '곱버스': 131,
#  '실제로': 131,
#  '있음': 131,
#  '시즌': 131,
#  '이말올': 131,
#  '공포': 131,
#  '듯이': 131,
#  '나락가': 130,
#  '신라젠': 130,
#  '포스코케미칼': 130,
#  '삼스디': 130,
#  '레전드': 129,
#  '저번주': 129,
#  '가진': 129,
#  '년뒤': 129,
#  '안산': 128,
#  '쥐좆': 128,
#  '상한': 128,
#  '아무': 128,
#  '저번': 128,
#  '대표': 128,
#  '코비': 128,
#  '아가리': 127,
#  '미안': 127,
#  '기존': 127,
#  '금액': 127,
#  '달달': 127,
#  '이수': 127,
#  '개별주': 126,
#  '폭탄': 126,
#  '허허': 126,
#  '년에': 126,
#  '아예': 126,
#  '레인보우': 126,
#  '코반꿀': 126,
#  '보고': 125,
#  '왤케': 125,
#  '검색': 125,
#  '결정': 125,
#  '오지': 125,
#  '안티': 125,
#  '개관': 124,
#  '이래': 124,
#  '빠질': 124,
#  '파산': 124,
#  '심장': 124,
#  '전쟁': 124,
#  'ㅉㅉ': 124,
#  '솔루션': 124,
#  '몰리': 123,
#  '연상': 123,
#  '따라가': 123,
#  '아쉽': 123,
#  '그런데': 123,
#  '행복': 123,
#  '괜히': 123,
#  '올라도': 123,
#  '천보': 123,
#  '사야지': 123,
#  '멸망': 122,
#  '꼬라박': 122,
#  '전세계': 122,
#  '몰라도': 122,
#  '미수': 122,
#  '매집': 121,
#  '과거': 121,
#  '영향': 121,
#  '씨젠': 121,
#  '봐야': 121,
#  '대주주': 120,
#  '남자': 120,
#  '단위': 120,
#  '알빠노': 119,
#  '상관없': 119,
#  '장난': 119,
#  '그러니까': 119,
#  '정지': 119,
#  '사장': 119,
#  '기대감': 118,
#  '고맙': 118,
#  '여자': 118,
#  '다니': 118,
#  '차전지주': 118,
#  '터치': 118,
#  '나와': 118,
#  '두산': 117,
#  '사지': 117,
#  '광신도': 117,
#  '국가': 117,
#  '만원때': 117,
#  '안정': 117,
#  '겨우': 117,
#  '얼즈': 117,
#  '열심히': 116,
#  '사야': 116,
#  '실패': 116,
#  '상관': 116,
#  '근거': 116,
#  '방금': 116,
#  '방송': 116,
#  '상대': 115,
#  '경험': 115,
#  '엔비': 115,
#  '어쩔': 115,
#  '꼬라지': 115,
#  '시세': 115,
#  '될지': 115,
#  '꾸준히': 115,
#  '인수': 115,
#  '실리': 115,
#  '수요': 115,
#  '증자': 115,
#  '에이치엔': 115,
#  '드가자': 114,
#  '해외': 114,
#  '신경': 114,
#  '숏친': 114,
#  '피자': 114,
#  '아파트': 114,
#  '마소': 114,
#  '서울': 114,
#  '올라오': 114,
#  '유럽': 114,
#  '내내': 114,
#  '대로': 114,
#  '신규': 114,
#  '빠진': 113,
#  '지능': 113,
#  '박스': 113,
#  '자랑': 113,
#  '주식시장': 113,
#  '와중': 113,
#  '누르': 113,
#  '주도주': 113,
#  '이하': 112,
#  '여러': 112,
#  '의견': 112,
#  '당분간': 112,
#  '발라': 112,
#  '사망': 112,
#  '코스모': 112,
#  '처박': 111,
#  '루타': 111,
#  '사랑': 111,
#  '몰랐': 111,
#  '증가': 111,
#  '안함': 111,
#  '심하': 111,
#  '납품': 111,
#  '꼬리': 111,
#  '비싼': 111,
#  ...}

# %%
# 정규화된 토큰 분포
normalized_tokens_dict
# Out:
# {'에코프로': 44575,
#  '?': 19667,
#  'ㅋㅋㅋ': 16522,
#  '에코': 10603,
#  'ㅋㅋ': 7732,
#  '시발': 5311,
#  '지금': 5041,
#  '주식': 4943,
#  '올라': 4702,
#  '오늘': 4214,
#  '새끼': 4185,
#  '만원': 3980,
#  '진짜': 3659,
#  '오르': 3009,
#  '차전지': 2681,
#  '!': 2639,
#  '병신': 2540,
#  '매수': 2477,
#  '생각': 2439,
#  '존나': 2435,
#  '사람': 2422,
#  '그냥': 2406,
#  'ㄹㅇ': 2322,
#  '개미': 2288,
#  '근데': 2285,
#  'ㅇㅇ': 2271,
#  '종목': 2189,
#  '공매도': 2007,
#  'ㄷㄷ': 1979,
#  '캬ㅋㅋㅋ': 1927,
#  '아직': 1882,
#  '이제': 1864,
#  '수익': 1834,
#  '코스닥': 1788,
#  '내일': 1772,
#  '신성': 1764,
#  '내리': 1679,
#  '정도': 1645,
#  '다시': 1618,
#  'ㄷㄷㄷ': 1600,
#  '시총': 1578,
#  '고점': 1576,
#  '프로': 1535,
#  '나오': 1500,
#  '모르': 1451,
#  '가능': 1450,
#  '이유': 1436,
#  '회사': 1428,
#  '이상': 1402,
#  '매도': 1394,
#  '국장': 1375,
#  '너무': 1344,
#  '테슬라': 1343,
#  '주주': 1310,
#  '이런': 1307,
#  '계속': 1293,
#  '포스코': 1274,
#  '많이': 1266,
#  '시작': 1220,
#  '주가': 1208,
#  '상승': 1201,
#  '실적': 1201,
#  '어제': 1181,
#  '투자': 1180,
#  '다른': 1163,
#  '비엠': 1163,
#  '금양': 1163,
#  '들어가': 1123,
#  '간다': 1122,
#  '차트': 1107,
#  '이미': 1048,
#  '시장': 1030,
#  '배터리': 1021,
#  '하락': 1011,
#  '떨어지': 997,
#  '세력': 991,
#  '기업': 981,
#  '운지': 981,
#  '때문': 976,
#  '가격': 970,
#  '그런': 941,
#  '공매': 934,
#  '거품': 925,
#  '조정': 902,
#  '초전도체': 902,
#  '광기': 898,
#  '평단': 894,
#  '삼전': 891,
#  'ㅠㅠ': 840,
#  '건데': 837,
#  '지수': 836,
#  '보이': 836,
#  '단타': 828,
#  '기관': 825,
#  '미국': 815,
#  '한국': 811,
#  '수급': 807,
#  'ㅡㅡ': 803,
#  '코스피': 791,
#  '손절': 788,
#  '얼마': 785,
#  '그럼': 782,
#  '같이': 771,
#  '포홀': 771,
#  '폭락': 770,
#  '아니': 766,
#  '다음': 735,
#  '그때': 735,
#  '미친': 735,
#  '오를': 710,
#  '사라': 702,
#  '그래서': 702,
#  '미래': 687,
#  '오른': 674,
#  '물린': 670,
#  '물량': 669,
#  '빠지': 668,
#  '그리고': 662,
#  '결국': 660,
#  '언제': 654,
#  '해서': 651,
#  '무슨': 644,
#  '올해': 637,
#  '나스닥': 628,
#  '이번': 626,
#  '아저씨': 622,
#  '상장': 619,
#  '빨리': 617,
#  '이렇게': 614,
#  '개인': 611,
#  '그렇': 604,
#  '해도': 602,
#  '뒤지': 602,
#  '바로': 601,
#  '고수': 600,
#  '매매': 599,
#  '절대': 592,
#  '어떻게': 590,
#  '가치': 589,
#  '계좌': 587,
#  '반도체': 587,
#  '텐데': 587,
#  '그러': 586,
#  '소리': 584,
#  'ㅈㄴ': 583,
#  '시간': 583,
#  '무조건': 572,
#  '하루': 562,
#  '예상': 552,
#  '형제': 549,
#  '양극재': 548,
#  '미장': 547,
#  '거래': 547,
#  '기회': 546,
#  '추천': 545,
#  '만들': 544,
#  '어케': 543,
#  '제발': 539,
#  '그래도': 533,
#  '인생': 530,
#  '얘기': 525,
#  '몰빵': 525,
#  '호로': 523,
#  '인증': 517,
#  '느낌': 515,
#  '솔직히': 514,
#  '일단': 512,
#  '사실': 510,
#  '저점': 510,
#  '어차피': 507,
#  '외인': 507,
#  '익절': 502,
#  '나올': 497,
#  '전기차': 495,
#  '개추': 493,
#  '인버스': 493,
#  '봐도': 493,
#  '가즈아': 488,
#  '거의': 485,
#  '그렇게': 484,
#  '코인': 483,
#  '호재': 481,
#  '버티': 478,
#  '자리': 477,
#  '나락': 475,
#  '원래': 470,
#  '코갤': 469,
#  '풀매수': 468,
#  '바이오': 467,
#  '뉴스': 465,
#  '삼성': 460,
#  '설거지': 456,
#  '카카오': 456,
#  '문제': 452,
#  '닥버스': 452,
#  '매출': 448,
#  '엘앤에프': 448,
#  '현재': 443,
#  '선물': 443,
#  '하한가': 441,
#  '신용': 441,
#  '기술': 440,
#  '지랄': 436,
#  '자체': 434,
#  '개잡주': 433,
#  '돌파': 432,
#  '테마': 430,
#  '작년': 427,
#  '동안': 426,
#  '마지막': 425,
#  '없이': 424,
#  '오름': 422,
#  '사면': 421,
#  '얼마나': 421,
#  '종토방': 417,
#  '해라': 415,
#  '가지': 415,
#  '조금': 413,
#  '반등': 411,
#  '만원대': 411,
#  '그만': 407,
#  '이러': 407,
#  '맞음': 407,
#  '시외': 407,
#  '된다': 405,
#  '상황': 401,
#  '기분': 401,
#  '성장': 400,
#  '공장': 400,
#  '떡상': 399,
#  '저런': 397,
#  '다들': 396,
#  '종가': 396,
#  '요즘': 392,
#  '시드': 391,
#  '엔비디아': 391,
#  '수준': 390,
#  '편입': 390,
#  '떡락': 387,
#  '이차전지': 386,
#  '나라': 386,
#  '역시': 385,
#  '이해': 384,
#  '양전': 381,
#  'ㄱㄱ': 381,
#  '부자': 381,
#  '소재': 381,
#  '분위기': 380,
#  '자금': 378,
#  '예정': 378,
#  '정보': 375,
#  '바닥': 375,
#  '똑같': 373,
#  '엔솔': 373,
#  '발표': 372,
#  '진입': 368,
#  '나왔': 368,
#  '건가': 367,
#  '급등': 364,
#  '전부': 362,
#  '세계': 360,
#  '작전': 360,
#  '틀딱': 359,
#  '중국': 358,
#  '들어오': 358,
#  '기준': 354,
#  '외국인': 354,
#  '셀트리온': 348,
#  '존버': 348,
#  '장투': 346,
#  '회장': 345,
#  '이후': 344,
#  '분할': 343,
#  '탈출': 343,
#  '떨어질': 343,
#  '섹터': 342,
#  '비싸': 340,
#  '제일': 338,
#  'ㅎㅎ': 335,
#  'ㅇㅈㄹ': 334,
#  '괜찮': 334,
#  '분석': 333,
#  '모든': 332,
#  '해야': 331,
#  '터지': 331,
#  '좆같': 331,
#  '악재': 331,
#  '정신': 330,
#  '비교': 330,
#  '상한가': 330,
#  '목표': 329,
#  '본인': 326,
#  '최소': 325,
#  '거래량': 325,
#  '대비': 323,
#  '봐라': 323,
#  '친구': 321,
#  '손실': 321,
#  '대체': 321,
#  '관련': 321,
#  '물렸': 320,
#  '정상': 318,
#  '기대': 317,
#  '물리': 317,
#  '지주사': 317,
#  '혼자': 314,
#  '단기': 313,
#  '본다': 312,
#  '테마주': 311,
#  '비중': 309,
#  '저렇게': 308,
#  '순간': 306,
#  '필요': 305,
#  '뒤져': 305,
#  'ㅜㅜ': 305,
#  '네이버': 303,
#  '이기': 303,
#  '추매': 303,
#  '슬슬': 303,
#  '홀딩': 300,
#  '사기': 299,
#  '물론': 298,
#  '모두': 297,
#  '무섭': 297,
#  '에코프로에이치엔': 297,
#  '감사': 295,
#  '대가리': 295,
#  '분기': 292,
#  '조선': 291,
#  '관심': 290,
#  '월요일': 290,
#  '기사': 289,
#  '애플': 289,
#  '사고': 289,
#  '아무리': 289,
#  '갑자기': 288,
#  '오히려': 287,
#  '그래': 287,
#  '이야기': 287,
#  '공시': 286,
#  '대부분': 286,
#  '보유': 285,
#  '주린이': 285,
#  '벼락거지': 283,
#  '신고': 281,
#  '비트코인': 281,
#  '벌써': 281,
#  '장기': 280,
#  '들어갔': 280,
#  'ㄹㅇㅋㅋ': 280,
#  '와서': 278,
#  '전자': 278,
#  '대장': 278,
#  '한다': 278,
#  '나중': 277,
#  '국내': 277,
#  '힘들': 277,
#  '중요': 277,
#  '출발': 276,
#  '리튬': 276,
#  '신풍': 275,
#  '나온': 275,
#  '폭등': 274,
#  '쌍봉': 274,
#  '공부': 273,
#  '산업': 273,
#  '거지': 272,
#  '재료': 272,
#  '최근': 271,
#  '아줌마': 271,
#  '나옴': 271,
#  '그룹': 270,
#  '숏스퀴즈': 270,
#  '확정': 270,
#  '타이밍': 269,
#  '준비': 268,
#  '아침': 268,
#  '삼성전자': 267,
#  '아님?': 265,
#  '의미': 264,
#  '세상': 263,
#  '평가': 263,
#  '지옥': 262,
#  '가장': 262,
#  '망하': 262,
#  '포스코홀딩스': 262,
#  '투자자': 261,
#  '엄마': 261,
#  '만드': 261,
#  '어쩌': 258,
#  '서남': 256,
#  '주도': 256,
#  '탑승': 255,
#  '사업': 255,
#  '도박': 253,
#  '인간': 253,
#  '샀으면': 252,
#  '애초': 252,
#  '저거': 252,
#  '상태': 250,
#  '코로나': 250,
#  '예전': 248,
#  'ㅠㅠㅠ': 248,
#  '처음': 248,
#  '미주갤': 248,
#  '버블': 247,
#  '미쳤': 247,
#  '들어간': 247,
#  '항상': 247,
#  'ㅎㄷㄷ': 247,
#  '맨날': 246,
#  '어느': 245,
#  '설마': 244,
#  '신호': 244,
#  '관련주': 244,
#  '전지': 244,
#  '잘못': 243,
#  '관망': 242,
#  '무지성': 242,
#  '부럽': 241,
#  '화학': 240,
#  '지분': 240,
#  '만주': 239,
#  '호가': 239,
#  '횡보': 239,
#  '산다': 239,
#  '선동': 239,
#  '어떤': 239,
#  '양봉': 239,
#  '아래': 238,
#  '나머지': 238,
#  '온다': 238,
#  '사도': 238,
#  '걸로': 237,
#  '반토막': 236,
#  '저평가': 236,
#  '정리': 235,
#  '별로': 235,
#  '다르': 233,
#  '코프': 233,
#  '아빠': 232,
#  '당장': 232,
#  '적정': 231,
#  '모름': 231,
#  '유튜브': 231,
#  '따라': 230,
#  '엄청': 230,
#  '금리': 229,
#  '살려': 228,
#  '스캠': 228,
#  '흑우': 227,
#  '고민': 227,
#  '전고점': 227,
#  '대장주': 226,
#  '구경': 226,
#  '이익': 226,
#  '이지랄': 226,
#  '구간': 226,
#  '참고': 226,
#  '인정': 225,
#  '예측': 225,
#  '됨?': 225,
#  '증권사': 225,
#  '간다고': 225,
#  '시대': 225,
#  '역사': 225,
#  '최고': 224,
#  '걱정': 224,
#  '슈카': 224,
#  '보여': 222,
#  '경제': 222,
#  '차이': 222,
#  '게임': 222,
#  '버스': 222,
#  '나가': 222,
#  '지표': 221,
#  '오른다': 221,
#  '구라': 221,
#  '저러': 221,
#  '던지': 220,
#  '성공': 220,
#  '사서': 219,
#  'ㄴㄴ': 219,
#  '아프': 218,
#  '둘다': 218,
#  '재밌': 217,
#  '매일': 217,
#  '증권': 217,
#  '음봉': 217,
#  '음전': 215,
#  '뒤질': 215,
#  '자살': 214,
#  '댓글': 213,
#  '드가': 212,
#  '머리': 212,
#  '상환': 212,
#  '웃기': 211,
#  '머티': 211,
#  '유지': 210,
#  '없제?': 210,
#  '제대로': 210,
#  '추가': 210,
#  '이름': 208,
#  '할때': 208,
#  '자회사': 208,
#  '대한': 206,
#  'ㅅㄱ': 205,
#  '사이': 205,
#  '현대차': 205,
#  '시기': 205,
#  '애미': 205,
#  '그럴': 203,
#  '실현': 202,
#  '입갤': 202,
#  '일본': 201,
#  '로봇': 200,
#  '까지': 200,
#  '대주': 200,
#  '업체': 200,
#  '추세': 200,
#  '물려': 200,
#  '대출': 199,
#  '강남': 199,
#  '실체': 199,
#  '일선': 198,
#  '먼저': 198,
#  '잡주': 197,
#  '휫자': 197,
#  '드디어': 197,
#  '아재': 197,
#  '확률': 197,
#  '초전도치': 196,
#  '급등주': 196,
#  '내년': 196,
#  '속보': 196,
#  '오래': 195,
#  '섹스': 195,
#  '위험': 195,
#  '현실': 194,
#  '돌아가': 194,
#  '영업이익': 193,
#  '이젠': 192,
#  '논리': 192,
#  '리포트': 191,
#  '에코바이오': 191,
#  '테크': 190,
#  '밧데리': 190,
#  '달러': 190,
#  '개꿀': 189,
#  '보임': 189,
#  '결과': 188,
#  '알려': 187,
#  '쳐먹': 187,
#  '시초': 187,
#  '자꾸': 186,
#  '갈듯': 186,
#  '기다리': 185,
#  '잔고': 185,
#  '전기': 185,
#  '영익': 185,
#  '숏충이': 184,
#  '깨지': 184,
#  '무적': 184,
#  '방법': 184,
#  '금융': 184,
#  '프로그램': 184,
#  '국민': 183,
#  '경우': 183,
#  '마이너스': 183,
#  '때리': 183,
#  '따리': 183,
#  '흐름': 182,
#  '죄다': 182,
#  '급락': 182,
#  '미리': 182,
#  '회복': 181,
#  '한강': 181,
#  '한번': 181,
#  '빠떼리': 181,
#  '에스': 181,
#  '보통': 179,
#  '보소': 179,
#  '자산': 178,
#  '아주': 178,
#  '복사': 178,
#  '최대': 178,
#  '당연히': 178,
#  '언급': 178,
#  '무빙': 178,
#  '못사': 178,
#  '그랬': 178,
#  '등등': 178,
#  '신성델타테크': 178,
#  '이딴': 177,
#  '대충': 177,
#  '배아파': 177,
#  '완전': 177,
#  '밸류': 177,
#  '무증': 177,
#  '작전주': 176,
#  '계약': 176,
#  '개발': 176,
#  '이번주': 175,
#  '직전': 175,
#  '난리': 175,
#  '엘지': 175,
#  '있음?': 174,
#  '정말': 174,
#  '지지': 174,
#  '반영': 173,
#  '점마': 173,
#  '존나게': 173,
#  '떨구': 173,
#  'ㅇㅇㅇ': 173,
#  '혹시': 172,
#  '유동': 172,
#  '마감': 172,
#  '팩트': 172,
#  '많음': 171,
#  '보내': 171,
#  '시점': 171,
#  '조심': 171,
#  '공유': 170,
#  '분명': 170,
#  '전재산': 170,
#  '하방': 170,
#  '조롱': 169,
#  '리얼': 169,
#  '금요일': 169,
#  '졸업': 168,
#  '희망': 168,
#  '달리': 168,
#  '생산': 168,
#  '말고': 168,
#  '적정가': 167,
#  '전체': 167,
#  '놈들': 167,
#  '포지션': 167,
#  '도대체': 167,
#  '실력': 167,
#  '보합': 167,
#  '부동산': 166,
#  '조만간': 166,
#  '천억': 166,
#  '이노': 166,
#  '에코캡': 166,
#  '호구': 165,
#  '현금': 165,
#  '며칠': 165,
#  '년전': 165,
#  '해야지': 165,
#  '은행': 164,
#  '리스크': 163,
#  '무너지': 163,
#  '진심': 163,
#  '시리즈': 163,
#  '내부자': 163,
#  '보다': 163,
#  '기억': 163,
#  '미붕이': 163,
#  '같음': 162,
#  '거래대금': 162,
#  '년도': 162,
#  '만원일때': 161,
#  '설명': 161,
#  '이득': 160,
#  '차라리': 160,
#  '랠리': 160,
#  '대박': 160,
#  '새로운': 160,
#  '이전': 160,
#  '이틀': 159,
#  '손해': 159,
#  '계산': 159,
#  '좆차전지': 158,
#  '무시': 158,
#  '들어갈': 158,
#  '대신': 158,
#  '움직이': 158,
#  '외궈': 157,
#  '당하': 157,
#  '오후': 157,
#  '마음': 157,
#  '끝물': 157,
#  '승리': 157,
#  '홀딩스': 157,
#  '그나마': 156,
#  '파워': 156,
#  '대한민국': 156,
#  '개같이': 156,
#  '아마': 156,
#  '돌리': 156,
#  '자신': 156,
#  '최고점': 156,
#  '나온다': 156,
#  '확인': 155,
#  '개미털기': 155,
#  '아까': 155,
#  '살껄': 155,
#  '청산': 155,
#  '셀트': 155,
#  '욕심': 155,
#  '현대': 155,
#  '달성': 155,
#  '타점': 154,
#  '에서': 154,
#  '큐ㅠㅠㅠ': 154,
#  '망했': 154,
#  '유증': 154,
#  '초반': 153,
#  '생각함': 153,
#  '만큼': 153,
#  '조선장': 153,
#  '그대로': 152,
#  '판단': 152,
#  '배당': 151,
#  '심리': 151,
#  '평생': 150,
#  '레버리지': 150,
#  '쏜다': 150,
#  '훨씬': 150,
#  '고평가': 150,
#  '에너지': 150,
#  '씹스캠': 150,
#  '규모': 150,
#  '증시': 150,
#  '펀드': 150,
#  '주당': 149,
#  '주변': 149,
#  '쓰레기': 149,
#  '하락장': 149,
#  '뒤졌': 149,
#  '하이닉스': 149,
#  '가노': 149,
#  '쳐서': 148,
#  '금지': 148,
#  '선반영': 148,
#  '충이': 148,
#  '나와서': 148,
#  '비율': 147,
#  '돈복사': 147,
#  '갤러리': 147,
#  '몰라': 147,
#  '중임': 147,
#  '평균': 147,
#  '갤러': 147,
#  '물려서': 147,
#  '부럽다': 147,
#  '엘엔에프': 147,
#  '기간': 146,
#  '심지어': 146,
#  '부활': 146,
#  '지리': 146,
#  '후회': 146,
#  '전환': 146,
#  '뭐냐': 146,
#  '수주': 146,
#  '기본': 145,
#  '아이': 145,
#  '오를때': 145,
#  '축하': 145,
#  '빠졌': 144,
#  '살걸': 144,
#  '죽이': 144,
#  '특히': 144,
#  '떨어졌': 143,
#  'ㅁㅊ': 143,
#  '뭐임?': 143,
#  '치킨': 143,
#  '장대': 143,
#  '이슈': 143,
#  '공급': 143,
#  '개소리': 143,
#  '재미': 142,
#  '적당히': 142,
#  'ㅇㅅㅇ': 142,
#  '인데': 142,
#  '대기': 141,
#  '무한': 141,
#  '슈팅': 140,
#  '전고': 140,
#  '그동안': 140,
#  '주포': 140,
#  '과연': 139,
#  '떨어진': 139,
#  '야수': 139,
#  '옵션': 139,
#  '무서워서': 139,
#  '바라': 139,
#  '갈때': 138,
#  '실시간': 138,
#  '어ㅋㅋㅋ': 138,
#  '신풍제약': 138,
#  '뒤진': 138,
#  '부정': 138,
#  '방어': 138,
#  '만약': 138,
#  '지나': 137,
#  '한다고': 137,
#  '반복': 137,
#  '전망': 137,
#  '코붕이': 137,
#  '세금': 136,
#  '의심': 136,
#  '사놓': 136,
#  '게이': 136,
#  '이노베이션': 136,
#  '건지': 136,
#  '반대': 136,
#  '확신': 136,
#  '퓨처': 136,
#  '어렵': 136,
#  '확실히': 135,
#  '유입': 135,
#  '자동차': 135,
#  '영역': 135,
#  '드립니다': 135,
#  '바보': 134,
#  'ㄹㅇㅋㅋㅋ': 134,
#  '동시': 134,
#  '된다고': 134,
#  '살까': 134,
#  '한방': 134,
#  '에프': 134,
#  '시절': 134,
#  '다행': 133,
#  '떨어짐': 133,
#  '근본': 133,
#  '완료': 133,
#  '숏커버': 133,
#  '근처': 133,
#  '구조': 133,
#  '우상향': 132,
#  '높음': 132,
#  '역대급': 132,
#  'lg화학': 132,
#  '복구': 132,
#  '가네': 132,
#  '곱버스': 131,
#  '실제로': 131,
#  '있음': 131,
#  '시즌': 131,
#  '이말올': 131,
#  '공포': 131,
#  '듯이': 131,
#  '나락가': 130,
#  '신라젠': 130,
#  '포스코케미칼': 130,
#  '삼스디': 130,
#  '레전드': 129,
#  '저번주': 129,
#  '가진': 129,
#  '년뒤': 129,
#  '안산': 128,
#  '쥐좆': 128,
#  '상한': 128,
#  '아무': 128,
#  '저번': 128,
#  '대표': 128,
#  '코비': 128,
#  '아가리': 127,
#  '미안': 127,
#  '기존': 127,
#  '금액': 127,
#  '달달': 127,
#  '이수': 127,
#  '개별주': 126,
#  '폭탄': 126,
#  '허허': 126,
#  '년에': 126,
#  '아예': 126,
#  '레인보우': 126,
#  '코반꿀': 126,
#  '보고': 125,
#  '왤케': 125,
#  '검색': 125,
#  '결정': 125,
#  '오지': 125,
#  '안티': 125,
#  '개관': 124,
#  '이래': 124,
#  '빠질': 124,
#  '파산': 124,
#  '심장': 124,
#  '전쟁': 124,
#  'ㅉㅉ': 124,
#  '솔루션': 124,
#  '몰리': 123,
#  '연상': 123,
#  '따라가': 123,
#  '아쉽': 123,
#  '그런데': 123,
#  '행복': 123,
#  '괜히': 123,
#  '천보': 123,
#  '사야지': 123,
#  '멸망': 122,
#  '꼬라박': 122,
#  '전세계': 122,
#  '몰라도': 122,
#  '미수': 122,
#  '매집': 121,
#  '과거': 121,
#  '영향': 121,
#  '씨젠': 121,
#  '봐야': 121,
#  '대주주': 120,
#  '남자': 120,
#  '단위': 120,
#  '알빠노': 119,
#  '상관없': 119,
#  '장난': 119,
#  '그러니까': 119,
#  '정지': 119,
#  '사장': 119,
#  '기대감': 118,
#  '고맙': 118,
#  '여자': 118,
#  '다니': 118,
#  '차전지주': 118,
#  '터치': 118,
#  '나와': 118,
#  '두산': 117,
#  '사지': 117,
#  '광신도': 117,
#  '국가': 117,
#  '만원때': 117,
#  '안정': 117,
#  '겨우': 117,
#  '얼즈': 117,
#  '열심히': 116,
#  '사야': 116,
#  '실패': 116,
#  '상관': 116,
#  '근거': 116,
#  '방금': 116,
#  '방송': 116,
#  '상대': 115,
#  '경험': 115,
#  '엔비': 115,
#  '어쩔': 115,
#  '꼬라지': 115,
#  '시세': 115,
#  '될지': 115,
#  '꾸준히': 115,
#  '인수': 115,
#  '실리': 115,
#  '수요': 115,
#  '증자': 115,
#  '에이치엔': 115,
#  '드가자': 114,
#  '해외': 114,
#  '신경': 114,
#  '숏친': 114,
#  '피자': 114,
#  '아파트': 114,
#  '마소': 114,
#  '서울': 114,
#  '유럽': 114,
#  '내내': 114,
#  '대로': 114,
#  '신규': 114,
#  '빠진': 113,
#  '지능': 113,
#  '박스': 113,
#  '자랑': 113,
#  '주식시장': 113,
#  '와중': 113,
#  '누르': 113,
#  '주도주': 113,
#  '이하': 112,
#  '여러': 112,
#  '의견': 112,
#  '당분간': 112,
#  '발라': 112,
#  '사망': 112,
#  '코스모': 112,
#  '처박': 111,
#  '루타': 111,
#  '사랑': 111,
#  '몰랐': 111,
#  '증가': 111,
#  '안함': 111,
#  '심하': 111,
#  '납품': 111,
#  '꼬리': 111,
#  '비싼': 111,
#  '패닉셀': 111,
#  '숏커버링': 111,
#  '저리': 111,
#  '영업': 111,
#  '포케': 111,
#  '난다': 110,
#  '아님': 110,
#  '전혀': 110,
#  '흐르': 110,
#  '버핏': 110,
#  '한참': 110,
#  '넘어가': 110,
#  '세대': 110,
#  ...}

# %%
# 정규화된 토큰 분포
normalized_tokens_dict
# Out:
# {'에코프로': 44575,
#  '?': 19667,
#  'ㅋㅋㅋ': 16522,
#  '에코': 10603,
#  'ㅋㅋ': 7732,
#  '오르': 7397,
#  '시발': 5311,
#  '지금': 5041,
#  '주식': 4943,
#  '오늘': 4214,
#  '새끼': 4185,
#  '만원': 3980,
#  '진짜': 3659,
#  '차전지': 2681,
#  '!': 2639,
#  '병신': 2540,
#  '매수': 2477,
#  '생각': 2439,
#  '존나': 2435,
#  '사람': 2422,
#  '그냥': 2406,
#  'ㄹㅇ': 2322,
#  '개미': 2288,
#  '근데': 2285,
#  'ㅇㅇ': 2271,
#  '종목': 2189,
#  '공매도': 2007,
#  'ㄷㄷ': 1979,
#  '캬ㅋㅋㅋ': 1927,
#  '아직': 1882,
#  '이제': 1864,
#  '수익': 1834,
#  '코스닥': 1788,
#  '내일': 1772,
#  '신성': 1764,
#  '내리': 1679,
#  '정도': 1645,
#  '다시': 1618,
#  'ㄷㄷㄷ': 1600,
#  '시총': 1578,
#  '고점': 1576,
#  '프로': 1535,
#  '나오': 1500,
#  '모르': 1451,
#  '가능': 1450,
#  '이유': 1436,
#  '회사': 1428,
#  '이상': 1402,
#  '매도': 1394,
#  '국장': 1375,
#  '너무': 1344,
#  '테슬라': 1343,
#  '주주': 1310,
#  '이런': 1307,
#  '계속': 1293,
#  '포스코': 1274,
#  '많이': 1266,
#  '시작': 1220,
#  '주가': 1208,
#  '상승': 1201,
#  '실적': 1201,
#  '어제': 1181,
#  '투자': 1180,
#  '다른': 1163,
#  '비엠': 1163,
#  '금양': 1163,
#  '들어가': 1123,
#  '간다': 1122,
#  '차트': 1107,
#  '이미': 1048,
#  '시장': 1030,
#  '배터리': 1021,
#  '하락': 1011,
#  '떨어지': 997,
#  '세력': 991,
#  '기업': 981,
#  '운지': 981,
#  '때문': 976,
#  '가격': 970,
#  '그런': 941,
#  '공매': 934,
#  '거품': 925,
#  '조정': 902,
#  '초전도체': 902,
#  '광기': 898,
#  '평단': 894,
#  '삼전': 891,
#  'ㅠㅠ': 840,
#  '건데': 837,
#  '지수': 836,
#  '보이': 836,
#  '단타': 828,
#  '기관': 825,
#  '미국': 815,
#  '한국': 811,
#  '수급': 807,
#  'ㅡㅡ': 803,
#  '코스피': 791,
#  '손절': 788,
#  '얼마': 785,
#  '그럼': 782,
#  '같이': 771,
#  '포홀': 771,
#  '폭락': 770,
#  '아니': 766,
#  '다음': 735,
#  '그때': 735,
#  '미친': 735,
#  '오를': 710,
#  '사라': 702,
#  '그래서': 702,
#  '미래': 687,
#  '오른': 674,
#  '물린': 670,
#  '물량': 669,
#  '빠지': 668,
#  '그리고': 662,
#  '결국': 660,
#  '언제': 654,
#  '해서': 651,
#  '무슨': 644,
#  '올해': 637,
#  '나스닥': 628,
#  '이번': 626,
#  '아저씨': 622,
#  '상장': 619,
#  '빨리': 617,
#  '이렇게': 614,
#  '개인': 611,
#  '그렇': 604,
#  '해도': 602,
#  '뒤지': 602,
#  '바로': 601,
#  '고수': 600,
#  '매매': 599,
#  '절대': 592,
#  '어떻게': 590,
#  '가치': 589,
#  '계좌': 587,
#  '반도체': 587,
#  '텐데': 587,
#  '그러': 586,
#  '소리': 584,
#  'ㅈㄴ': 583,
#  '시간': 583,
#  '무조건': 572,
#  '하루': 562,
#  '예상': 552,
#  '형제': 549,
#  '양극재': 548,
#  '미장': 547,
#  '거래': 547,
#  '기회': 546,
#  '추천': 545,
#  '만들': 544,
#  '어케': 543,
#  '제발': 539,
#  '그래도': 533,
#  '인생': 530,
#  '얘기': 525,
#  '몰빵': 525,
#  '호로': 523,
#  '인증': 517,
#  '느낌': 515,
#  '솔직히': 514,
#  '일단': 512,
#  '사실': 510,
#  '저점': 510,
#  '어차피': 507,
#  '외인': 507,
#  '익절': 502,
#  '나올': 497,
#  '전기차': 495,
#  '개추': 493,
#  '인버스': 493,
#  '봐도': 493,
#  '가즈아': 488,
#  '거의': 485,
#  '그렇게': 484,
#  '코인': 483,
#  '호재': 481,
#  '버티': 478,
#  '자리': 477,
#  '나락': 475,
#  '원래': 470,
#  '코갤': 469,
#  '풀매수': 468,
#  '바이오': 467,
#  '뉴스': 465,
#  '삼성': 460,
#  '설거지': 456,
#  '카카오': 456,
#  '문제': 452,
#  '닥버스': 452,
#  '매출': 448,
#  '엘앤에프': 448,
#  '현재': 443,
#  '선물': 443,
#  '하한가': 441,
#  '신용': 441,
#  '기술': 440,
#  '지랄': 436,
#  '자체': 434,
#  '개잡주': 433,
#  '돌파': 432,
#  '테마': 430,
#  '작년': 427,
#  '동안': 426,
#  '마지막': 425,
#  '없이': 424,
#  '오름': 422,
#  '사면': 421,
#  '얼마나': 421,
#  '종토방': 417,
#  '해라': 415,
#  '가지': 415,
#  '조금': 413,
#  '반등': 411,
#  '만원대': 411,
#  '그만': 407,
#  '이러': 407,
#  '맞음': 407,
#  '시외': 407,
#  '된다': 405,
#  '상황': 401,
#  '기분': 401,
#  '성장': 400,
#  '공장': 400,
#  '떡상': 399,
#  '저런': 397,
#  '다들': 396,
#  '종가': 396,
#  '요즘': 392,
#  '시드': 391,
#  '엔비디아': 391,
#  '수준': 390,
#  '편입': 390,
#  '떡락': 387,
#  '이차전지': 386,
#  '나라': 386,
#  '역시': 385,
#  '이해': 384,
#  '양전': 381,
#  'ㄱㄱ': 381,
#  '부자': 381,
#  '소재': 381,
#  '분위기': 380,
#  '자금': 378,
#  '예정': 378,
#  '정보': 375,
#  '바닥': 375,
#  '똑같': 373,
#  '엔솔': 373,
#  '발표': 372,
#  '진입': 368,
#  '나왔': 368,
#  '건가': 367,
#  '급등': 364,
#  '전부': 362,
#  '세계': 360,
#  '작전': 360,
#  '틀딱': 359,
#  '중국': 358,
#  '들어오': 358,
#  '기준': 354,
#  '외국인': 354,
#  '셀트리온': 348,
#  '존버': 348,
#  '장투': 346,
#  '회장': 345,
#  '이후': 344,
#  '분할': 343,
#  '탈출': 343,
#  '떨어질': 343,
#  '섹터': 342,
#  '비싸': 340,
#  '제일': 338,
#  'ㅎㅎ': 335,
#  'ㅇㅈㄹ': 334,
#  '괜찮': 334,
#  '분석': 333,
#  '모든': 332,
#  '해야': 331,
#  '터지': 331,
#  '좆같': 331,
#  '악재': 331,
#  '정신': 330,
#  '비교': 330,
#  '상한가': 330,
#  '목표': 329,
#  '본인': 326,
#  '최소': 325,
#  '거래량': 325,
#  '대비': 323,
#  '봐라': 323,
#  '친구': 321,
#  '손실': 321,
#  '대체': 321,
#  '관련': 321,
#  '물렸': 320,
#  '정상': 318,
#  '기대': 317,
#  '물리': 317,
#  '지주사': 317,
#  '혼자': 314,
#  '단기': 313,
#  '본다': 312,
#  '테마주': 311,
#  '비중': 309,
#  '저렇게': 308,
#  '순간': 306,
#  '필요': 305,
#  '뒤져': 305,
#  'ㅜㅜ': 305,
#  '네이버': 303,
#  '이기': 303,
#  '추매': 303,
#  '슬슬': 303,
#  '홀딩': 300,
#  '사기': 299,
#  '물론': 298,
#  '모두': 297,
#  '무섭': 297,
#  '에코프로에이치엔': 297,
#  '감사': 295,
#  '대가리': 295,
#  '분기': 292,
#  '조선': 291,
#  '관심': 290,
#  '월요일': 290,
#  '기사': 289,
#  '애플': 289,
#  '사고': 289,
#  '아무리': 289,
#  '갑자기': 288,
#  '오히려': 287,
#  '그래': 287,
#  '이야기': 287,
#  '공시': 286,
#  '대부분': 286,
#  '보유': 285,
#  '주린이': 285,
#  '벼락거지': 283,
#  '신고': 281,
#  '비트코인': 281,
#  '벌써': 281,
#  '장기': 280,
#  '들어갔': 280,
#  'ㄹㅇㅋㅋ': 280,
#  '와서': 278,
#  '전자': 278,
#  '대장': 278,
#  '한다': 278,
#  '나중': 277,
#  '국내': 277,
#  '힘들': 277,
#  '중요': 277,
#  '출발': 276,
#  '리튬': 276,
#  '신풍': 275,
#  '나온': 275,
#  '폭등': 274,
#  '쌍봉': 274,
#  '공부': 273,
#  '산업': 273,
#  '거지': 272,
#  '재료': 272,
#  '최근': 271,
#  '아줌마': 271,
#  '나옴': 271,
#  '그룹': 270,
#  '숏스퀴즈': 270,
#  '확정': 270,
#  '타이밍': 269,
#  '준비': 268,
#  '아침': 268,
#  '삼성전자': 267,
#  '아님?': 265,
#  '의미': 264,
#  '세상': 263,
#  '평가': 263,
#  '지옥': 262,
#  '가장': 262,
#  '망하': 262,
#  '포스코홀딩스': 262,
#  '투자자': 261,
#  '엄마': 261,
#  '만드': 261,
#  '어쩌': 258,
#  '서남': 256,
#  '주도': 256,
#  '탑승': 255,
#  '사업': 255,
#  '도박': 253,
#  '인간': 253,
#  '샀으면': 252,
#  '애초': 252,
#  '저거': 252,
#  '상태': 250,
#  '코로나': 250,
#  '예전': 248,
#  'ㅠㅠㅠ': 248,
#  '처음': 248,
#  '미주갤': 248,
#  '버블': 247,
#  '미쳤': 247,
#  '들어간': 247,
#  '항상': 247,
#  'ㅎㄷㄷ': 247,
#  '맨날': 246,
#  '어느': 245,
#  '설마': 244,
#  '신호': 244,
#  '관련주': 244,
#  '전지': 244,
#  '잘못': 243,
#  '관망': 242,
#  '무지성': 242,
#  '부럽': 241,
#  '화학': 240,
#  '지분': 240,
#  '만주': 239,
#  '호가': 239,
#  '횡보': 239,
#  '산다': 239,
#  '선동': 239,
#  '어떤': 239,
#  '양봉': 239,
#  '아래': 238,
#  '나머지': 238,
#  '온다': 238,
#  '사도': 238,
#  '걸로': 237,
#  '반토막': 236,
#  '저평가': 236,
#  '정리': 235,
#  '별로': 235,
#  '다르': 233,
#  '코프': 233,
#  '아빠': 232,
#  '당장': 232,
#  '적정': 231,
#  '모름': 231,
#  '유튜브': 231,
#  '따라': 230,
#  '엄청': 230,
#  '금리': 229,
#  '살려': 228,
#  '스캠': 228,
#  '흑우': 227,
#  '고민': 227,
#  '전고점': 227,
#  '대장주': 226,
#  '구경': 226,
#  '이익': 226,
#  '이지랄': 226,
#  '구간': 226,
#  '참고': 226,
#  '인정': 225,
#  '예측': 225,
#  '됨?': 225,
#  '증권사': 225,
#  '간다고': 225,
#  '시대': 225,
#  '역사': 225,
#  '최고': 224,
#  '걱정': 224,
#  '슈카': 224,
#  '보여': 222,
#  '경제': 222,
#  '차이': 222,
#  '게임': 222,
#  '버스': 222,
#  '나가': 222,
#  '지표': 221,
#  '오른다': 221,
#  '구라': 221,
#  '저러': 221,
#  '던지': 220,
#  '성공': 220,
#  '사서': 219,
#  'ㄴㄴ': 219,
#  '아프': 218,
#  '둘다': 218,
#  '재밌': 217,
#  '매일': 217,
#  '증권': 217,
#  '음봉': 217,
#  '음전': 215,
#  '뒤질': 215,
#  '자살': 214,
#  '댓글': 213,
#  '드가': 212,
#  '머리': 212,
#  '상환': 212,
#  '웃기': 211,
#  '머티': 211,
#  '유지': 210,
#  '없제?': 210,
#  '제대로': 210,
#  '추가': 210,
#  '이름': 208,
#  '할때': 208,
#  '자회사': 208,
#  '대한': 206,
#  'ㅅㄱ': 205,
#  '사이': 205,
#  '현대차': 205,
#  '시기': 205,
#  '애미': 205,
#  '그럴': 203,
#  '실현': 202,
#  '입갤': 202,
#  '일본': 201,
#  '로봇': 200,
#  '까지': 200,
#  '대주': 200,
#  '업체': 200,
#  '추세': 200,
#  '물려': 200,
#  '대출': 199,
#  '강남': 199,
#  '실체': 199,
#  '일선': 198,
#  '먼저': 198,
#  '잡주': 197,
#  '휫자': 197,
#  '드디어': 197,
#  '아재': 197,
#  '확률': 197,
#  '초전도치': 196,
#  '급등주': 196,
#  '내년': 196,
#  '속보': 196,
#  '오래': 195,
#  '섹스': 195,
#  '위험': 195,
#  '현실': 194,
#  '돌아가': 194,
#  '영업이익': 193,
#  '이젠': 192,
#  '논리': 192,
#  '리포트': 191,
#  '에코바이오': 191,
#  '테크': 190,
#  '밧데리': 190,
#  '달러': 190,
#  '개꿀': 189,
#  '보임': 189,
#  '결과': 188,
#  '알려': 187,
#  '쳐먹': 187,
#  '시초': 187,
#  '자꾸': 186,
#  '갈듯': 186,
#  '기다리': 185,
#  '잔고': 185,
#  '전기': 185,
#  '영익': 185,
#  '숏충이': 184,
#  '깨지': 184,
#  '무적': 184,
#  '방법': 184,
#  '금융': 184,
#  '프로그램': 184,
#  '국민': 183,
#  '경우': 183,
#  '마이너스': 183,
#  '때리': 183,
#  '따리': 183,
#  '흐름': 182,
#  '죄다': 182,
#  '급락': 182,
#  '미리': 182,
#  '회복': 181,
#  '한강': 181,
#  '한번': 181,
#  '빠떼리': 181,
#  '에스': 181,
#  '보통': 179,
#  '보소': 179,
#  '자산': 178,
#  '아주': 178,
#  '복사': 178,
#  '최대': 178,
#  '당연히': 178,
#  '언급': 178,
#  '무빙': 178,
#  '못사': 178,
#  '그랬': 178,
#  '등등': 178,
#  '신성델타테크': 178,
#  '이딴': 177,
#  '대충': 177,
#  '배아파': 177,
#  '완전': 177,
#  '밸류': 177,
#  '무증': 177,
#  '작전주': 176,
#  '계약': 176,
#  '개발': 176,
#  '이번주': 175,
#  '직전': 175,
#  '난리': 175,
#  '엘지': 175,
#  '있음?': 174,
#  '정말': 174,
#  '지지': 174,
#  '반영': 173,
#  '점마': 173,
#  '존나게': 173,
#  '떨구': 173,
#  'ㅇㅇㅇ': 173,
#  '혹시': 172,
#  '유동': 172,
#  '마감': 172,
#  '팩트': 172,
#  '많음': 171,
#  '보내': 171,
#  '시점': 171,
#  '조심': 171,
#  '공유': 170,
#  '분명': 170,
#  '전재산': 170,
#  '하방': 170,
#  '조롱': 169,
#  '리얼': 169,
#  '금요일': 169,
#  '졸업': 168,
#  '희망': 168,
#  '달리': 168,
#  '생산': 168,
#  '말고': 168,
#  '적정가': 167,
#  '전체': 167,
#  '놈들': 167,
#  '포지션': 167,
#  '도대체': 167,
#  '실력': 167,
#  '보합': 167,
#  '부동산': 166,
#  '조만간': 166,
#  '천억': 166,
#  '이노': 166,
#  '에코캡': 166,
#  '호구': 165,
#  '현금': 165,
#  '며칠': 165,
#  '년전': 165,
#  '해야지': 165,
#  '은행': 164,
#  '리스크': 163,
#  '무너지': 163,
#  '진심': 163,
#  '시리즈': 163,
#  '내부자': 163,
#  '보다': 163,
#  '기억': 163,
#  '미붕이': 163,
#  '같음': 162,
#  '거래대금': 162,
#  '년도': 162,
#  '만원일때': 161,
#  '설명': 161,
#  '이득': 160,
#  '차라리': 160,
#  '랠리': 160,
#  '대박': 160,
#  '새로운': 160,
#  '이전': 160,
#  '이틀': 159,
#  '손해': 159,
#  '계산': 159,
#  '좆차전지': 158,
#  '무시': 158,
#  '들어갈': 158,
#  '대신': 158,
#  '움직이': 158,
#  '외궈': 157,
#  '당하': 157,
#  '오후': 157,
#  '마음': 157,
#  '끝물': 157,
#  '승리': 157,
#  '홀딩스': 157,
#  '그나마': 156,
#  '파워': 156,
#  '대한민국': 156,
#  '개같이': 156,
#  '아마': 156,
#  '돌리': 156,
#  '자신': 156,
#  '최고점': 156,
#  '나온다': 156,
#  '확인': 155,
#  '개미털기': 155,
#  '아까': 155,
#  '살껄': 155,
#  '청산': 155,
#  '셀트': 155,
#  '욕심': 155,
#  '현대': 155,
#  '달성': 155,
#  '타점': 154,
#  '에서': 154,
#  '큐ㅠㅠㅠ': 154,
#  '망했': 154,
#  '유증': 154,
#  '초반': 153,
#  '생각함': 153,
#  '만큼': 153,
#  '조선장': 153,
#  '그대로': 152,
#  '판단': 152,
#  '배당': 151,
#  '심리': 151,
#  '평생': 150,
#  '레버리지': 150,
#  '쏜다': 150,
#  '훨씬': 150,
#  '고평가': 150,
#  '에너지': 150,
#  '씹스캠': 150,
#  '규모': 150,
#  '증시': 150,
#  '펀드': 150,
#  '주당': 149,
#  '주변': 149,
#  '쓰레기': 149,
#  '하락장': 149,
#  '뒤졌': 149,
#  '하이닉스': 149,
#  '가노': 149,
#  '쳐서': 148,
#  '금지': 148,
#  '선반영': 148,
#  '충이': 148,
#  '나와서': 148,
#  '비율': 147,
#  '돈복사': 147,
#  '갤러리': 147,
#  '몰라': 147,
#  '중임': 147,
#  '평균': 147,
#  '갤러': 147,
#  '물려서': 147,
#  '부럽다': 147,
#  '엘엔에프': 147,
#  '기간': 146,
#  '심지어': 146,
#  '부활': 146,
#  '지리': 146,
#  '후회': 146,
#  '전환': 146,
#  '뭐냐': 146,
#  '수주': 146,
#  '기본': 145,
#  '아이': 145,
#  '오를때': 145,
#  '축하': 145,
#  '빠졌': 144,
#  '살걸': 144,
#  '죽이': 144,
#  '특히': 144,
#  '떨어졌': 143,
#  'ㅁㅊ': 143,
#  '뭐임?': 143,
#  '치킨': 143,
#  '장대': 143,
#  '이슈': 143,
#  '공급': 143,
#  '개소리': 143,
#  '재미': 142,
#  '적당히': 142,
#  'ㅇㅅㅇ': 142,
#  '인데': 142,
#  '대기': 141,
#  '무한': 141,
#  '슈팅': 140,
#  '전고': 140,
#  '그동안': 140,
#  '주포': 140,
#  '과연': 139,
#  '떨어진': 139,
#  '야수': 139,
#  '옵션': 139,
#  '무서워서': 139,
#  '바라': 139,
#  '갈때': 138,
#  '실시간': 138,
#  '어ㅋㅋㅋ': 138,
#  '신풍제약': 138,
#  '뒤진': 138,
#  '부정': 138,
#  '방어': 138,
#  '만약': 138,
#  '지나': 137,
#  '한다고': 137,
#  '반복': 137,
#  '전망': 137,
#  '코붕이': 137,
#  '세금': 136,
#  '의심': 136,
#  '사놓': 136,
#  '게이': 136,
#  '이노베이션': 136,
#  '건지': 136,
#  '반대': 136,
#  '확신': 136,
#  '퓨처': 136,
#  '어렵': 136,
#  '확실히': 135,
#  '유입': 135,
#  '자동차': 135,
#  '영역': 135,
#  '드립니다': 135,
#  '바보': 134,
#  'ㄹㅇㅋㅋㅋ': 134,
#  '동시': 134,
#  '된다고': 134,
#  '살까': 134,
#  '한방': 134,
#  '에프': 134,
#  '시절': 134,
#  '다행': 133,
#  '떨어짐': 133,
#  '근본': 133,
#  '완료': 133,
#  '숏커버': 133,
#  '근처': 133,
#  '구조': 133,
#  '우상향': 132,
#  '높음': 132,
#  '역대급': 132,
#  'lg화학': 132,
#  '복구': 132,
#  '가네': 132,
#  '곱버스': 131,
#  '실제로': 131,
#  '있음': 131,
#  '시즌': 131,
#  '이말올': 131,
#  '공포': 131,
#  '듯이': 131,
#  '나락가': 130,
#  '신라젠': 130,
#  '포스코케미칼': 130,
#  '삼스디': 130,
#  '레전드': 129,
#  '저번주': 129,
#  '가진': 129,
#  '년뒤': 129,
#  '안산': 128,
#  '쥐좆': 128,
#  '상한': 128,
#  '아무': 128,
#  '저번': 128,
#  '대표': 128,
#  '코비': 128,
#  '아가리': 127,
#  '미안': 127,
#  '기존': 127,
#  '금액': 127,
#  '달달': 127,
#  '이수': 127,
#  '개별주': 126,
#  '폭탄': 126,
#  '허허': 126,
#  '년에': 126,
#  '아예': 126,
#  '레인보우': 126,
#  '코반꿀': 126,
#  '보고': 125,
#  '왤케': 125,
#  '검색': 125,
#  '결정': 125,
#  '오지': 125,
#  '안티': 125,
#  '개관': 124,
#  '이래': 124,
#  '빠질': 124,
#  '파산': 124,
#  '심장': 124,
#  '전쟁': 124,
#  'ㅉㅉ': 124,
#  '솔루션': 124,
#  '몰리': 123,
#  '연상': 123,
#  '따라가': 123,
#  '아쉽': 123,
#  '그런데': 123,
#  '행복': 123,
#  '괜히': 123,
#  '천보': 123,
#  '사야지': 123,
#  '멸망': 122,
#  '꼬라박': 122,
#  '전세계': 122,
#  '몰라도': 122,
#  '미수': 122,
#  '매집': 121,
#  '과거': 121,
#  '영향': 121,
#  '씨젠': 121,
#  '봐야': 121,
#  '대주주': 120,
#  '남자': 120,
#  '단위': 120,
#  '알빠노': 119,
#  '상관없': 119,
#  '장난': 119,
#  '그러니까': 119,
#  '정지': 119,
#  '사장': 119,
#  '기대감': 118,
#  '고맙': 118,
#  '여자': 118,
#  '다니': 118,
#  '차전지주': 118,
#  '터치': 118,
#  '나와': 118,
#  '두산': 117,
#  '사지': 117,
#  '광신도': 117,
#  '국가': 117,
#  '만원때': 117,
#  '안정': 117,
#  '겨우': 117,
#  '얼즈': 117,
#  '열심히': 116,
#  '사야': 116,
#  '실패': 116,
#  '상관': 116,
#  '근거': 116,
#  '방금': 116,
#  '방송': 116,
#  '상대': 115,
#  '경험': 115,
#  '엔비': 115,
#  '어쩔': 115,
#  '꼬라지': 115,
#  '시세': 115,
#  '될지': 115,
#  '꾸준히': 115,
#  '인수': 115,
#  '실리': 115,
#  '수요': 115,
#  '증자': 115,
#  '에이치엔': 115,
#  '드가자': 114,
#  '해외': 114,
#  '신경': 114,
#  '숏친': 114,
#  '피자': 114,
#  '아파트': 114,
#  '마소': 114,
#  '서울': 114,
#  '유럽': 114,
#  '내내': 114,
#  '대로': 114,
#  '신규': 114,
#  '빠진': 113,
#  '지능': 113,
#  '박스': 113,
#  '자랑': 113,
#  '주식시장': 113,
#  '와중': 113,
#  '누르': 113,
#  '주도주': 113,
#  '이하': 112,
#  '여러': 112,
#  '의견': 112,
#  '당분간': 112,
#  '발라': 112,
#  '사망': 112,
#  '코스모': 112,
#  '처박': 111,
#  '루타': 111,
#  '사랑': 111,
#  '몰랐': 111,
#  '증가': 111,
#  '안함': 111,
#  '심하': 111,
#  '납품': 111,
#  '꼬리': 111,
#  '비싼': 111,
#  '패닉셀': 111,
#  '숏커버링': 111,
#  '저리': 111,
#  '영업': 111,
#  '포케': 111,
#  '난다': 110,
#  '아님': 110,
#  '전혀': 110,
#  '흐르': 110,
#  '버핏': 110,
#  '한참': 110,
#  '넘어가': 110,
#  '세대': 110,
#  '오전': 110,
#  ...}

# %%
# 정규화된 토큰 분포
normalized_tokens_dict
# Out:
# {'에코프로': 44575,
#  '?': 19667,
#  'ㅋㅋㅋ': 16522,
#  '에코': 10603,
#  'ㅋㅋ': 7732,
#  '오르': 7397,
#  '시발': 5311,
#  '지금': 5041,
#  '주식': 4943,
#  '오늘': 4214,
#  '새끼': 4185,
#  '만원': 3980,
#  '진짜': 3659,
#  '매수': 3212,
#  '차전지': 2681,
#  '!': 2639,
#  '병신': 2540,
#  '생각': 2439,
#  '존나': 2435,
#  '사람': 2422,
#  '그냥': 2406,
#  'ㄹㅇ': 2322,
#  '개미': 2288,
#  '근데': 2285,
#  'ㅇㅇ': 2271,
#  '종목': 2189,
#  '공매도': 2007,
#  'ㄷㄷ': 1979,
#  '고점': 1936,
#  '캬ㅋㅋㅋ': 1927,
#  '아직': 1882,
#  '이제': 1864,
#  '수익': 1834,
#  '코스닥': 1788,
#  '내일': 1772,
#  '신성': 1764,
#  '내리': 1679,
#  '정도': 1645,
#  '다시': 1618,
#  'ㄷㄷㄷ': 1600,
#  '시총': 1578,
#  '프로': 1535,
#  '나오': 1500,
#  '모르': 1451,
#  '가능': 1450,
#  '이유': 1436,
#  '회사': 1428,
#  '매도': 1419,
#  '이상': 1402,
#  '국장': 1375,
#  '너무': 1344,
#  '테슬라': 1343,
#  '주주': 1310,
#  '이런': 1307,
#  '계속': 1293,
#  '포스코': 1274,
#  '많이': 1266,
#  '시작': 1220,
#  '주가': 1208,
#  '상승': 1201,
#  '실적': 1201,
#  '어제': 1181,
#  '투자': 1180,
#  '다른': 1163,
#  '비엠': 1163,
#  '금양': 1163,
#  '들어가': 1123,
#  '간다': 1122,
#  '차트': 1107,
#  '이미': 1048,
#  '시장': 1030,
#  '배터리': 1021,
#  '하락': 1011,
#  '떨어지': 997,
#  '세력': 991,
#  '기업': 981,
#  '운지': 981,
#  '때문': 976,
#  '가격': 970,
#  '그런': 941,
#  '공매': 934,
#  '거품': 925,
#  '조정': 902,
#  '초전도체': 902,
#  '광기': 898,
#  '평단': 894,
#  '삼전': 891,
#  'ㅠㅠ': 840,
#  '건데': 837,
#  '지수': 836,
#  '보이': 836,
#  '단타': 828,
#  '기관': 825,
#  '미국': 815,
#  '한국': 811,
#  '수급': 807,
#  'ㅡㅡ': 803,
#  '코스피': 791,
#  '손절': 788,
#  '얼마': 785,
#  '그럼': 782,
#  '같이': 771,
#  '포홀': 771,
#  '폭락': 770,
#  '아니': 766,
#  '다음': 735,
#  '그때': 735,
#  '미친': 735,
#  '오를': 710,
#  '사라': 702,
#  '그래서': 702,
#  '미래': 687,
#  '오른': 674,
#  '물린': 670,
#  '물량': 669,
#  '빠지': 668,
#  '그리고': 662,
#  '결국': 660,
#  '언제': 654,
#  '해서': 651,
#  '무슨': 644,
#  '올해': 637,
#  '나스닥': 628,
#  '이번': 626,
#  '아저씨': 622,
#  '상장': 619,
#  '빨리': 617,
#  '이렇게': 614,
#  '개인': 611,
#  '그렇': 604,
#  '해도': 602,
#  '뒤지': 602,
#  '바로': 601,
#  '고수': 600,
#  '매매': 599,
#  '절대': 592,
#  '어떻게': 590,
#  '가치': 589,
#  '계좌': 587,
#  '반도체': 587,
#  '텐데': 587,
#  '그러': 586,
#  '소리': 584,
#  'ㅈㄴ': 583,
#  '시간': 583,
#  '무조건': 572,
#  '하루': 562,
#  '예상': 552,
#  '형제': 549,
#  '양극재': 548,
#  '미장': 547,
#  '거래': 547,
#  '기회': 546,
#  '추천': 545,
#  '만들': 544,
#  '어케': 543,
#  '제발': 539,
#  '그래도': 533,
#  '인생': 530,
#  '얘기': 525,
#  '몰빵': 525,
#  '호로': 523,
#  '인증': 517,
#  '느낌': 515,
#  '솔직히': 514,
#  '일단': 512,
#  '사실': 510,
#  '저점': 510,
#  '어차피': 507,
#  '외인': 507,
#  '익절': 502,
#  '나올': 497,
#  '전기차': 495,
#  '개추': 493,
#  '인버스': 493,
#  '봐도': 493,
#  '가즈아': 488,
#  '거의': 485,
#  '그렇게': 484,
#  '코인': 483,
#  '호재': 481,
#  '버티': 478,
#  '자리': 477,
#  '나락': 475,
#  '원래': 470,
#  '코갤': 469,
#  '바이오': 467,
#  '뉴스': 465,
#  '삼성': 460,
#  '설거지': 456,
#  '카카오': 456,
#  '문제': 452,
#  '닥버스': 452,
#  '매출': 448,
#  '엘앤에프': 448,
#  '현재': 443,
#  '선물': 443,
#  '하한가': 441,
#  '신용': 441,
#  '기술': 440,
#  '지랄': 436,
#  '자체': 434,
#  '개잡주': 433,
#  '돌파': 432,
#  '테마': 430,
#  '작년': 427,
#  '동안': 426,
#  '마지막': 425,
#  '없이': 424,
#  '오름': 422,
#  '사면': 421,
#  '얼마나': 421,
#  '종토방': 417,
#  '해라': 415,
#  '가지': 415,
#  '조금': 413,
#  '반등': 411,
#  '만원대': 411,
#  '그만': 407,
#  '이러': 407,
#  '맞음': 407,
#  '시외': 407,
#  '된다': 405,
#  '상황': 401,
#  '기분': 401,
#  '성장': 400,
#  '공장': 400,
#  '떡상': 399,
#  '저런': 397,
#  '다들': 396,
#  '종가': 396,
#  '요즘': 392,
#  '시드': 391,
#  '엔비디아': 391,
#  '수준': 390,
#  '편입': 390,
#  '떡락': 387,
#  '이차전지': 386,
#  '나라': 386,
#  '역시': 385,
#  '이해': 384,
#  '양전': 381,
#  'ㄱㄱ': 381,
#  '부자': 381,
#  '소재': 381,
#  '분위기': 380,
#  '자금': 378,
#  '예정': 378,
#  '정보': 375,
#  '바닥': 375,
#  '똑같': 373,
#  '엔솔': 373,
#  '발표': 372,
#  '진입': 368,
#  '나왔': 368,
#  '건가': 367,
#  '급등': 364,
#  '전부': 362,
#  '세계': 360,
#  '작전': 360,
#  '틀딱': 359,
#  '중국': 358,
#  '들어오': 358,
#  '기준': 354,
#  '외국인': 354,
#  '셀트리온': 348,
#  '존버': 348,
#  '장투': 346,
#  '회장': 345,
#  '이후': 344,
#  '분할': 343,
#  '탈출': 343,
#  '떨어질': 343,
#  '섹터': 342,
#  '비싸': 340,
#  '제일': 338,
#  'ㅎㅎ': 335,
#  'ㅇㅈㄹ': 334,
#  '괜찮': 334,
#  '분석': 333,
#  '모든': 332,
#  '해야': 331,
#  '터지': 331,
#  '좆같': 331,
#  '악재': 331,
#  '정신': 330,
#  '비교': 330,
#  '상한가': 330,
#  '목표': 329,
#  '본인': 326,
#  '최소': 325,
#  '거래량': 325,
#  '대비': 323,
#  '봐라': 323,
#  '친구': 321,
#  '손실': 321,
#  '대체': 321,
#  '관련': 321,
#  '물렸': 320,
#  '정상': 318,
#  '기대': 317,
#  '물리': 317,
#  '지주사': 317,
#  '혼자': 314,
#  '단기': 313,
#  '본다': 312,
#  '테마주': 311,
#  '비중': 309,
#  '저렇게': 308,
#  '순간': 306,
#  '필요': 305,
#  '뒤져': 305,
#  'ㅜㅜ': 305,
#  '네이버': 303,
#  '이기': 303,
#  '추매': 303,
#  '슬슬': 303,
#  '홀딩': 300,
#  '사기': 299,
#  '물론': 298,
#  '모두': 297,
#  '무섭': 297,
#  '에코프로에이치엔': 297,
#  '감사': 295,
#  '대가리': 295,
#  '분기': 292,
#  '조선': 291,
#  '관심': 290,
#  '월요일': 290,
#  '기사': 289,
#  '애플': 289,
#  '사고': 289,
#  '아무리': 289,
#  '갑자기': 288,
#  '오히려': 287,
#  '그래': 287,
#  '이야기': 287,
#  '공시': 286,
#  '대부분': 286,
#  '보유': 285,
#  '주린이': 285,
#  '벼락거지': 283,
#  '신고': 281,
#  '비트코인': 281,
#  '벌써': 281,
#  '장기': 280,
#  '들어갔': 280,
#  'ㄹㅇㅋㅋ': 280,
#  '와서': 278,
#  '전자': 278,
#  '대장': 278,
#  '한다': 278,
#  '나중': 277,
#  '국내': 277,
#  '힘들': 277,
#  '중요': 277,
#  '출발': 276,
#  '리튬': 276,
#  '신풍': 275,
#  '나온': 275,
#  '폭등': 274,
#  '쌍봉': 274,
#  '공부': 273,
#  '산업': 273,
#  '거지': 272,
#  '재료': 272,
#  '최근': 271,
#  '아줌마': 271,
#  '나옴': 271,
#  '그룹': 270,
#  '숏스퀴즈': 270,
#  '확정': 270,
#  '타이밍': 269,
#  '준비': 268,
#  '아침': 268,
#  '삼성전자': 267,
#  '아님?': 265,
#  '의미': 264,
#  '세상': 263,
#  '평가': 263,
#  '지옥': 262,
#  '가장': 262,
#  '망하': 262,
#  '포스코홀딩스': 262,
#  '투자자': 261,
#  '엄마': 261,
#  '만드': 261,
#  '어쩌': 258,
#  '서남': 256,
#  '주도': 256,
#  '탑승': 255,
#  '사업': 255,
#  '도박': 253,
#  '인간': 253,
#  '샀으면': 252,
#  '애초': 252,
#  '저거': 252,
#  '상태': 250,
#  '코로나': 250,
#  '예전': 248,
#  'ㅠㅠㅠ': 248,
#  '처음': 248,
#  '미주갤': 248,
#  '버블': 247,
#  '미쳤': 247,
#  '들어간': 247,
#  '항상': 247,
#  'ㅎㄷㄷ': 247,
#  '맨날': 246,
#  '어느': 245,
#  '설마': 244,
#  '신호': 244,
#  '관련주': 244,
#  '전지': 244,
#  '잘못': 243,
#  '관망': 242,
#  '무지성': 242,
#  '부럽': 241,
#  '화학': 240,
#  '지분': 240,
#  '만주': 239,
#  '호가': 239,
#  '횡보': 239,
#  '산다': 239,
#  '선동': 239,
#  '어떤': 239,
#  '양봉': 239,
#  '아래': 238,
#  '나머지': 238,
#  '온다': 238,
#  '사도': 238,
#  '걸로': 237,
#  '반토막': 236,
#  '저평가': 236,
#  '정리': 235,
#  '별로': 235,
#  '다르': 233,
#  '코프': 233,
#  '아빠': 232,
#  '당장': 232,
#  '적정': 231,
#  '모름': 231,
#  '유튜브': 231,
#  '따라': 230,
#  '엄청': 230,
#  '금리': 229,
#  '살려': 228,
#  '스캠': 228,
#  '흑우': 227,
#  '고민': 227,
#  '대장주': 226,
#  '구경': 226,
#  '이익': 226,
#  '이지랄': 226,
#  '구간': 226,
#  '참고': 226,
#  '인정': 225,
#  '예측': 225,
#  '됨?': 225,
#  '증권사': 225,
#  '간다고': 225,
#  '시대': 225,
#  '역사': 225,
#  '최고': 224,
#  '걱정': 224,
#  '슈카': 224,
#  '보여': 222,
#  '경제': 222,
#  '차이': 222,
#  '게임': 222,
#  '버스': 222,
#  '나가': 222,
#  '지표': 221,
#  '오른다': 221,
#  '구라': 221,
#  '저러': 221,
#  '던지': 220,
#  '성공': 220,
#  '사서': 219,
#  'ㄴㄴ': 219,
#  '아프': 218,
#  '둘다': 218,
#  '재밌': 217,
#  '매일': 217,
#  '증권': 217,
#  '음봉': 217,
#  '음전': 215,
#  '뒤질': 215,
#  '자살': 214,
#  '댓글': 213,
#  '드가': 212,
#  '머리': 212,
#  '상환': 212,
#  '웃기': 211,
#  '머티': 211,
#  '유지': 210,
#  '없제?': 210,
#  '제대로': 210,
#  '추가': 210,
#  '이름': 208,
#  '할때': 208,
#  '자회사': 208,
#  '대한': 206,
#  'ㅅㄱ': 205,
#  '사이': 205,
#  '현대차': 205,
#  '시기': 205,
#  '애미': 205,
#  '그럴': 203,
#  '실현': 202,
#  '입갤': 202,
#  '일본': 201,
#  '로봇': 200,
#  '까지': 200,
#  '대주': 200,
#  '업체': 200,
#  '추세': 200,
#  '물려': 200,
#  '대출': 199,
#  '강남': 199,
#  '실체': 199,
#  '일선': 198,
#  '먼저': 198,
#  '잡주': 197,
#  '휫자': 197,
#  '드디어': 197,
#  '아재': 197,
#  '확률': 197,
#  '초전도치': 196,
#  '급등주': 196,
#  '내년': 196,
#  '속보': 196,
#  '오래': 195,
#  '섹스': 195,
#  '위험': 195,
#  '현실': 194,
#  '돌아가': 194,
#  '영업이익': 193,
#  '이젠': 192,
#  '논리': 192,
#  '리포트': 191,
#  '에코바이오': 191,
#  '테크': 190,
#  '밧데리': 190,
#  '달러': 190,
#  '개꿀': 189,
#  '보임': 189,
#  '결과': 188,
#  '알려': 187,
#  '쳐먹': 187,
#  '시초': 187,
#  '자꾸': 186,
#  '갈듯': 186,
#  '기다리': 185,
#  '잔고': 185,
#  '전기': 185,
#  '영익': 185,
#  '숏충이': 184,
#  '깨지': 184,
#  '무적': 184,
#  '방법': 184,
#  '금융': 184,
#  '프로그램': 184,
#  '국민': 183,
#  '경우': 183,
#  '마이너스': 183,
#  '때리': 183,
#  '따리': 183,
#  '흐름': 182,
#  '죄다': 182,
#  '급락': 182,
#  '미리': 182,
#  '회복': 181,
#  '한강': 181,
#  '한번': 181,
#  '빠떼리': 181,
#  '에스': 181,
#  '보통': 179,
#  '보소': 179,
#  '자산': 178,
#  '아주': 178,
#  '복사': 178,
#  '최대': 178,
#  '당연히': 178,
#  '언급': 178,
#  '무빙': 178,
#  '못사': 178,
#  '그랬': 178,
#  '등등': 178,
#  '신성델타테크': 178,
#  '이딴': 177,
#  '대충': 177,
#  '배아파': 177,
#  '완전': 177,
#  '밸류': 177,
#  '무증': 177,
#  '작전주': 176,
#  '계약': 176,
#  '개발': 176,
#  '이번주': 175,
#  '직전': 175,
#  '난리': 175,
#  '엘지': 175,
#  '있음?': 174,
#  '정말': 174,
#  '지지': 174,
#  '반영': 173,
#  '점마': 173,
#  '존나게': 173,
#  '떨구': 173,
#  'ㅇㅇㅇ': 173,
#  '혹시': 172,
#  '유동': 172,
#  '마감': 172,
#  '팩트': 172,
#  '많음': 171,
#  '보내': 171,
#  '시점': 171,
#  '조심': 171,
#  '공유': 170,
#  '분명': 170,
#  '전재산': 170,
#  '하방': 170,
#  '조롱': 169,
#  '리얼': 169,
#  '금요일': 169,
#  '졸업': 168,
#  '희망': 168,
#  '달리': 168,
#  '생산': 168,
#  '말고': 168,
#  '적정가': 167,
#  '전체': 167,
#  '놈들': 167,
#  '포지션': 167,
#  '도대체': 167,
#  '실력': 167,
#  '보합': 167,
#  '부동산': 166,
#  '조만간': 166,
#  '천억': 166,
#  '이노': 166,
#  '에코캡': 166,
#  '호구': 165,
#  '현금': 165,
#  '며칠': 165,
#  '년전': 165,
#  '해야지': 165,
#  '은행': 164,
#  '리스크': 163,
#  '무너지': 163,
#  '진심': 163,
#  '시리즈': 163,
#  '내부자': 163,
#  '보다': 163,
#  '기억': 163,
#  '미붕이': 163,
#  '같음': 162,
#  '거래대금': 162,
#  '년도': 162,
#  '만원일때': 161,
#  '설명': 161,
#  '이득': 160,
#  '차라리': 160,
#  '랠리': 160,
#  '대박': 160,
#  '새로운': 160,
#  '이전': 160,
#  '이틀': 159,
#  '손해': 159,
#  '계산': 159,
#  '좆차전지': 158,
#  '무시': 158,
#  '들어갈': 158,
#  '대신': 158,
#  '움직이': 158,
#  '외궈': 157,
#  '당하': 157,
#  '오후': 157,
#  '마음': 157,
#  '끝물': 157,
#  '승리': 157,
#  '홀딩스': 157,
#  '그나마': 156,
#  '파워': 156,
#  '대한민국': 156,
#  '개같이': 156,
#  '아마': 156,
#  '돌리': 156,
#  '자신': 156,
#  '나온다': 156,
#  '확인': 155,
#  '개미털기': 155,
#  '아까': 155,
#  '살껄': 155,
#  '청산': 155,
#  '셀트': 155,
#  '욕심': 155,
#  '현대': 155,
#  '달성': 155,
#  '타점': 154,
#  '에서': 154,
#  '큐ㅠㅠㅠ': 154,
#  '망했': 154,
#  '유증': 154,
#  '초반': 153,
#  '생각함': 153,
#  '만큼': 153,
#  '조선장': 153,
#  '그대로': 152,
#  '판단': 152,
#  '배당': 151,
#  '심리': 151,
#  '평생': 150,
#  '레버리지': 150,
#  '쏜다': 150,
#  '훨씬': 150,
#  '고평가': 150,
#  '에너지': 150,
#  '씹스캠': 150,
#  '규모': 150,
#  '증시': 150,
#  '펀드': 150,
#  '주당': 149,
#  '주변': 149,
#  '쓰레기': 149,
#  '하락장': 149,
#  '뒤졌': 149,
#  '하이닉스': 149,
#  '가노': 149,
#  '쳐서': 148,
#  '금지': 148,
#  '선반영': 148,
#  '충이': 148,
#  '나와서': 148,
#  '비율': 147,
#  '돈복사': 147,
#  '갤러리': 147,
#  '몰라': 147,
#  '중임': 147,
#  '평균': 147,
#  '갤러': 147,
#  '물려서': 147,
#  '부럽다': 147,
#  '엘엔에프': 147,
#  '기간': 146,
#  '심지어': 146,
#  '부활': 146,
#  '지리': 146,
#  '후회': 146,
#  '전환': 146,
#  '뭐냐': 146,
#  '수주': 146,
#  '기본': 145,
#  '아이': 145,
#  '오를때': 145,
#  '축하': 145,
#  '빠졌': 144,
#  '살걸': 144,
#  '죽이': 144,
#  '특히': 144,
#  '떨어졌': 143,
#  'ㅁㅊ': 143,
#  '뭐임?': 143,
#  '치킨': 143,
#  '장대': 143,
#  '이슈': 143,
#  '공급': 143,
#  '개소리': 143,
#  '재미': 142,
#  '적당히': 142,
#  'ㅇㅅㅇ': 142,
#  '인데': 142,
#  '대기': 141,
#  '무한': 141,
#  '슈팅': 140,
#  '전고': 140,
#  '그동안': 140,
#  '주포': 140,
#  '과연': 139,
#  '떨어진': 139,
#  '야수': 139,
#  '옵션': 139,
#  '무서워서': 139,
#  '바라': 139,
#  '갈때': 138,
#  '실시간': 138,
#  '어ㅋㅋㅋ': 138,
#  '신풍제약': 138,
#  '뒤진': 138,
#  '부정': 138,
#  '방어': 138,
#  '만약': 138,
#  '지나': 137,
#  '한다고': 137,
#  '반복': 137,
#  '전망': 137,
#  '코붕이': 137,
#  '세금': 136,
#  '의심': 136,
#  '사놓': 136,
#  '게이': 136,
#  '이노베이션': 136,
#  '건지': 136,
#  '반대': 136,
#  '확신': 136,
#  '퓨처': 136,
#  '어렵': 136,
#  '확실히': 135,
#  '유입': 135,
#  '자동차': 135,
#  '영역': 135,
#  '드립니다': 135,
#  '바보': 134,
#  'ㄹㅇㅋㅋㅋ': 134,
#  '동시': 134,
#  '된다고': 134,
#  '살까': 134,
#  '한방': 134,
#  '에프': 134,
#  '시절': 134,
#  '다행': 133,
#  '떨어짐': 133,
#  '근본': 133,
#  '완료': 133,
#  '숏커버': 133,
#  '근처': 133,
#  '구조': 133,
#  '우상향': 132,
#  '높음': 132,
#  '역대급': 132,
#  'lg화학': 132,
#  '복구': 132,
#  '가네': 132,
#  '곱버스': 131,
#  '실제로': 131,
#  '있음': 131,
#  '시즌': 131,
#  '이말올': 131,
#  '공포': 131,
#  '듯이': 131,
#  '나락가': 130,
#  '신라젠': 130,
#  '포스코케미칼': 130,
#  '삼스디': 130,
#  '레전드': 129,
#  '저번주': 129,
#  '가진': 129,
#  '년뒤': 129,
#  '안산': 128,
#  '쥐좆': 128,
#  '상한': 128,
#  '아무': 128,
#  '저번': 128,
#  '대표': 128,
#  '코비': 128,
#  '아가리': 127,
#  '미안': 127,
#  '기존': 127,
#  '금액': 127,
#  '달달': 127,
#  '이수': 127,
#  '개별주': 126,
#  '폭탄': 126,
#  '허허': 126,
#  '년에': 126,
#  '아예': 126,
#  '레인보우': 126,
#  '코반꿀': 126,
#  '보고': 125,
#  '왤케': 125,
#  '검색': 125,
#  '결정': 125,
#  '오지': 125,
#  '안티': 125,
#  '개관': 124,
#  '이래': 124,
#  '빠질': 124,
#  '파산': 124,
#  '심장': 124,
#  '전쟁': 124,
#  'ㅉㅉ': 124,
#  '솔루션': 124,
#  '몰리': 123,
#  '연상': 123,
#  '따라가': 123,
#  '아쉽': 123,
#  '그런데': 123,
#  '행복': 123,
#  '괜히': 123,
#  '천보': 123,
#  '사야지': 123,
#  '멸망': 122,
#  '꼬라박': 122,
#  '전세계': 122,
#  '몰라도': 122,
#  '미수': 122,
#  '매집': 121,
#  '과거': 121,
#  '영향': 121,
#  '씨젠': 121,
#  '봐야': 121,
#  '대주주': 120,
#  '남자': 120,
#  '단위': 120,
#  '알빠노': 119,
#  '상관없': 119,
#  '장난': 119,
#  '그러니까': 119,
#  '정지': 119,
#  '사장': 119,
#  '기대감': 118,
#  '고맙': 118,
#  '여자': 118,
#  '다니': 118,
#  '차전지주': 118,
#  '터치': 118,
#  '나와': 118,
#  '두산': 117,
#  '사지': 117,
#  '광신도': 117,
#  '국가': 117,
#  '만원때': 117,
#  '안정': 117,
#  '겨우': 117,
#  '얼즈': 117,
#  '열심히': 116,
#  '사야': 116,
#  '실패': 116,
#  '상관': 116,
#  '근거': 116,
#  '방금': 116,
#  '방송': 116,
#  '상대': 115,
#  '경험': 115,
#  '엔비': 115,
#  '어쩔': 115,
#  '꼬라지': 115,
#  '시세': 115,
#  '될지': 115,
#  '꾸준히': 115,
#  '인수': 115,
#  '실리': 115,
#  '수요': 115,
#  '증자': 115,
#  '에이치엔': 115,
#  '드가자': 114,
#  '해외': 114,
#  '신경': 114,
#  '숏친': 114,
#  '피자': 114,
#  '아파트': 114,
#  '마소': 114,
#  '서울': 114,
#  '유럽': 114,
#  '내내': 114,
#  '대로': 114,
#  '신규': 114,
#  '빠진': 113,
#  '지능': 113,
#  '박스': 113,
#  '자랑': 113,
#  '주식시장': 113,
#  '와중': 113,
#  '누르': 113,
#  '주도주': 113,
#  '이하': 112,
#  '여러': 112,
#  '의견': 112,
#  '당분간': 112,
#  '발라': 112,
#  '사망': 112,
#  '코스모': 112,
#  '처박': 111,
#  '루타': 111,
#  '사랑': 111,
#  '몰랐': 111,
#  '증가': 111,
#  '안함': 111,
#  '심하': 111,
#  '납품': 111,
#  '꼬리': 111,
#  '비싼': 111,
#  '패닉셀': 111,
#  '숏커버링': 111,
#  '저리': 111,
#  '영업': 111,
#  '포케': 111,
#  '난다': 110,
#  '아님': 110,
#  '전혀': 110,
#  '흐르': 110,
#  '버핏': 110,
#  '한참': 110,
#  '넘어가': 110,
#  '세대': 110,
#  '오전': 110,
#  '재무': 110,
#  '단계': 110,
#  '루닛': 110,
#  ...}

# %%
search_token = "프로"
result_df = find_rows_containing_token(normalized_df, "tokens", search_token)
print(result_df)
# Out:
#        community    gall_id search_keyword   number date_created time_created  \
# 172     dcinside     snp500             에코   779500   2023-08-01     14:19:29
# 272     dcinside     snp500             에코   775807   2023-07-28     09:08:43
# 304     dcinside     snp500             에코   775345   2023-07-27     18:48:22
# 321     dcinside     snp500             에코   775241   2023-07-27     16:57:39
# 475     dcinside     snp500             에코   774983   2023-07-27     10:59:15
# ...          ...        ...            ...      ...          ...          ...
# 108374  dcinside  tenbagger             에코  4458141   2022-05-19     18:13:04
# 108433  dcinside  tenbagger             에코  3977890   2021-10-06     03:15:26
# 108487  dcinside  tenbagger             에코  3715314   2021-07-08     08:45:27
# 108819  dcinside  tenbagger             에코   618736   2020-07-11     11:31:22
# 108903  dcinside  tenbagger             에코   282447   2020-05-25     11:12:34
#
#              author  is_reply  text_length  \
# 172              터보         0           40
# 272           슨피아저씨         1           18
# 304      ㅇㅇ(210.98)         0          143
# 321           레버리지박         1            9
# 475            찰스슈왑         0           44
# ...             ...       ...          ...
# 108374  ㅇㅇ(118.235)         0          462
# 108433    ㅇㅇ(59.20)         0          109
# 108487  ㅇㅇ(118.235)         0           57
# 108819         보잉주주         1           36
# 108903   ㅇㅇ(39.127)         1           20
#
#                                               spaced_text  \
# 172              아니 에코 프로를 겪고도 서남을 안 사?! 부의 추월차선 진입 안 했?!
# 272                                    다시 마이너스 프로네 도박판이다!
# 304     내일 에코프로 만원 찍는다 얼른사라 차전지는 무족꿘 오를수밖에 없다 차전지가 왜 전...
# 321                                             난 프로가 될거야
# 475          그런데 에코호로로 돈 못번 프로도 있냐? ㅋㅋㅋ 캬ㅋㅋ ㅋㅋㅋㅑ ㅋㅋㅑ 컄 ㅋㅋ
# ...                                                   ...
# 108374  국내주식 한장요약 시간외단일가 안녕하세요 홍익개미 챗봇이 시간외 단일가 특징주 전달...
# 108433  해주갤보다 망한애들 국장소스 던져주고간다 한농화성 우신시스템 바른손 대원화성 팜스토...
# 108487  천보 에코프로비엠 삼성sdi lg화학 포인트모바일 에이프로젠 kic 장외 온페이스게...
# 108819               카카오 신기하긴하더라 하루에 프로씩 오르는거보면 이유를 모르겠ㅋㅋ
# 108903                               마소 한달 존버했는데 프로밖에 못먿음
#
#                                                    tokens
# 172              [아니, 에코, 프로, 서남, ?, !, 추월, 차선, 진입, ?, !]
# 272                                [다시, 마이너스, 프로, 도박판, !]
# 304     [내일, 에코프로, 만원, 얼른, 사라, 차전지, 무족, 오를, 차전지, 전지, ?...
# 321                                                  [프로]
# 475             [그런데, 에코프로, 프로, ?, ㅋㅋㅋ, 캬ㅋㅋ, ㅋㅋㅋ, ㅋㅋ, ㅋㅋ]
# ...                                                   ...
# 108374  [국내, 주식, 요약, 시간외, 단일, 안녕, 홍익, 개미, 시간외, 단일, 특징,...
# 108433  [보다, 망한, 국장, 소스, 던져, 농화, 우신, 시스템, 바른손, 대원, 화성,...
# 108487  [천보, 에코프로, 삼성sdi, lg화학, 포인트, 모바일, 에이, 프로, 장외, ...
# 108819                      [카카오, 하루, 프로, 오르, 이유, 모르, ㅋㅋ]
# 108903                                       [마소, 존버, 프로]
#
# [1535 rows x 11 columns]
