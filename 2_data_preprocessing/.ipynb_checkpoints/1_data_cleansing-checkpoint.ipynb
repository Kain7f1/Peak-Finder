# %% [markdown]
# # 1. 데이터 정제 data cleansing

# %% [markdown]
# ## 1-a. 우리 프로젝트의 목적
#
# - 투자자의 “감정”을 읽는 것이 주 목적이다.
# - 그러므로 숫자와 대부분의 특수문자는 무의미하다
# - 한글 감정 표현을 잡아내는 것이 주 목적이다

# %% [markdown]
# ## 1-b. 정제 계획
#
# - 특수 :  - ! ? 를 제외하고 전부 공백 문자로 치환한다
#  :    - 공백 문한다자로 치환 :
#     - 소문자로 변경한다

# %% [markdown]
# ## 1-c. 정제 진행
# 1. 영어 소문자로 통일
# 2. . 한글, 영어, !? 만 남기고 전부 공백문자로 치환한다3. 2. 공백 문자가 연속적으로 있는 걸 1개로 줄4.
# 3. 연속되는 !, ? 를 최대 1개로5.
# 4. 연속되는 한글 자음, 모음을 최대 3개로 줄임줄인다

# %% [markdown]
# ### 1-c-1. 데이터 불러오기

# %%
# 데이터 읽어오기
import pandas as pd
df = pd.read_csv("1_id_text.csv", encoding="utf-8")
df.tail(3)
# Out:
#         search_keyword date_created time_created       writer  is_reply  \
# 1153471             휴젤   2020-04-29     11:55:10  ㅇㅇ(123.215)         0
# 1153472             휴젤   2020-04-29     11:56:16  ㅇㄷ(175.223)         1
# 1153473             휴젤   2020-04-29     11:56:38   ㅇㅇ(223.33)         1
#
#                                                       text            id
# 1153471  미국주식보다 한국꺼보면 ㄹㅇ 암걸릴 것 같음 특히 휴젤 저거 아는분이 임원진인데 회...  241400125127
# 1153472                          한국 상장회사들중에 ㅂㅅ같은곳이 넘 많음...  241400125127
# 1153473      신흥국 회사투자 망설여지는 게 이거 때문임. 주식시장에 대한 개념이 안 잡혀있음.  241400125127

# %% [markdown]
# ### 1-c-2. 영어 소문자로 통일

# %%
df['lowercase_text'] = df['text'].str.lower()
df.head(15)
# Out:
#    search_keyword date_created time_created        writer  is_reply  \
# 0             JYP   2023-06-13     12:50:42            ㅇㅇ         0
# 1             JYP   2023-05-16     17:52:40    ㅇㅇ(118.34)         0
# 2             JYP   2023-05-16     17:52:48    ㅇㅇ(118.34)         1
# 3             JYP   2023-05-16     18:04:04   ㅇㅇ(203.227)         1
# 4             JYP   2023-04-17     22:00:45           설묘.         0
# 5             JYP   2023-04-17     22:01:10   ㅇㅇ(175.116)         1
# 6             JYP   2023-04-17     22:01:17          영차추종         1
# 7             JYP   2023-04-17     22:01:32          영차추종         1
# 8             JYP   2023-04-17     22:01:42          새우고래         1
# 9             JYP   2023-04-17     22:01:43  부랄턱과500개의스캠들         1
# 10            JYP   2023-04-17     22:02:37        kvanto         1
# 11            JYP   2023-04-17     22:03:23           설묘.         1
# 12            JYP   2023-04-15     18:04:36    ㅇㅇ(218.55)         0
# 13            JYP   2023-04-15     18:07:21       이더리움2.0         1
# 14            JYP   2023-04-15     18:07:39          영차추종         1
#
#                                                  text           id  \
# 0      jyp가반년만에2배가올랏네 근디보니는인적자원위주로하는사업은먼가ㅂㄹ다걍제조업이조음..  10100746844
# 1   야 개보지년들아 JYP 주가 봤냐.. 미쳣다 지금... 개잡주 오르는건 그러려니 하...  10100730087
# 2                                                  ㅠㅠ  10100730087
# 3                                                  ㅠㅠ  10100730087
# 4                  니들 jyp 어케 생각해? ㄹㅇ 개미 너무 많이 붙는거 같은데  10100714904
# 5                                                 조용필  10100714904
# 6                                                신포도야  10100714904
# 7                                      난 뉴턴이 될 생각 없으야  10100714904
# 8                                              제왚ㅣ! -  10100714904
# 9                                에코프로를 보고도 급등주를 타려하느냐  10100714904
# 10                                                투자해  10100714904
# 11                                       반또가 사면 나도 산다  10100714904
# 12  JYP는 신 맞다 (300%인증) 컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...  10100713453
# 13                                   천만원 인생수업이면 나쁘지않아  10100713453
# 14                                                  오  10100713453
#
#                                        lowercase_text
# 0      jyp가반년만에2배가올랏네 근디보니는인적자원위주로하는사업은먼가ㅂㄹ다걍제조업이조음..
# 1   야 개보지년들아 jyp 주가 봤냐.. 미쳣다 지금... 개잡주 오르는건 그러려니 하...
# 2                                                  ㅠㅠ
# 3                                                  ㅠㅠ
# 4                  니들 jyp 어케 생각해? ㄹㅇ 개미 너무 많이 붙는거 같은데
# 5                                                 조용필
# 6                                                신포도야
# 7                                      난 뉴턴이 될 생각 없으야
# 8                                              제왚ㅣ! -
# 9                                에코프로를 보고도 급등주를 타려하느냐
# 10                                                투자해
# 11                                       반또가 사면 나도 산다
# 12  jyp는 신 맞다 (300%인증) 컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...
# 13                                   천만원 인생수업이면 나쁘지않아
# 14                                                  오

# %% [markdown]
# ### 1-c-3. 한글, 영어, !? 만 남기고 전부 공백문자로 치환한다.

# %%
import re

# 한글, 영어, !, ? 만 남기고 나머지를 공백으로 치환하는 함수 정의
def replace_chars(text):
    return re.sub('[^a-z가-힣ㄱ-ㅎㅏ-ㅣ!?]', ' ', text)

# 데이터프레임의 'text' 칼럼에 함수 적용
df['filtered_text'] = df['lowercase_text'].apply(replace_chars)
df.head(30)
# Out:
#    search_keyword date_created time_created        writer  is_reply  \
# 0             JYP   2023-06-13     12:50:42            ㅇㅇ         0
# 1             JYP   2023-05-16     17:52:40    ㅇㅇ(118.34)         0
# 2             JYP   2023-05-16     17:52:48    ㅇㅇ(118.34)         1
# 3             JYP   2023-05-16     18:04:04   ㅇㅇ(203.227)         1
# 4             JYP   2023-04-17     22:00:45           설묘.         0
# 5             JYP   2023-04-17     22:01:10   ㅇㅇ(175.116)         1
# 6             JYP   2023-04-17     22:01:17          영차추종         1
# 7             JYP   2023-04-17     22:01:32          영차추종         1
# 8             JYP   2023-04-17     22:01:42          새우고래         1
# 9             JYP   2023-04-17     22:01:43  부랄턱과500개의스캠들         1
# 10            JYP   2023-04-17     22:02:37        kvanto         1
# 11            JYP   2023-04-17     22:03:23           설묘.         1
# 12            JYP   2023-04-15     18:04:36    ㅇㅇ(218.55)         0
# 13            JYP   2023-04-15     18:07:21       이더리움2.0         1
# 14            JYP   2023-04-15     18:07:39          영차추종         1
# 15            JYP   2023-04-15     18:08:26     ㅇㅇ(58.77)         1
�ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...
# 13                                   천만원 인생수업이면 나쁘지않아
# 14                                                  오
# 15                                                  아
# 16                                베이비가 아장아장 걷는  jyp _
# 17           간만에 기만  jyp 쵸코파이와 컵라면만 먹는게 아니란말임슴둥   !!!
# 18                                       어디냐? 정돈은 아닌데
# 19                            난 저런 돈가스는 냄새 심해서 못 먹겠더라
# 20                   경향식말고 이 카츠는 내 인생 돈까스임육질이 쥑여줌;;;;
# 21                                                부럽다
# 22                                  그대도 만원의 행복을 느껴보세요
# 23                                             맛있겠다..
# 24                                  충분히 먹고도 남을 자산가시면서
# 25                                          와 앞에 여자네?
# 26                                        모든 상상을 소유하라
# 27                                                부럽다
# 28                                  그대도 가끔은 사치를 부려보세요
# 29                               부익부 빈익빈 억울하다 세상을 뒤엎자
#
#                                         filtered_text
# 0      jyp가반년만에 배가올랏네 근디보니는인적자원위주로하는사업은먼가ㅂㄹ다걍제조업이조음
# 1   야 개보지년들아 jyp 주가 봤냐   미쳣다 지금    개잡주 오르는건 그러려니 하...
# 2                                                  ㅠㅠ
# 3                                                  ㅠㅠ
# 4                  니들 jyp 어케 생각해? ㄹㅇ 개미 너무 많이 붙는거 같은데
# 5                                                 조용필
# 6                                                신포도야
# 7                                      난 뉴턴이 될 생각 없으야
# 8                                              제왚ㅣ!
# 9                                에코프로를 보고도 급등주를 타려하느냐
# 10                                                투자해
# 11                                       반또가 사면 나도 산다
# 12  jyp는 신 맞다      인증  컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...
# 13                                   천만원 인생수업이면 나쁘지않아
# 14                                                  오
# 15                                                  아
# 16                                베이비가 아장아장 걷는  jyp
# 17           간만에 기만  jyp 쵸코파이와 컵라면만 먹는게 아니란말임슴둥   !!!
# 18                                       어디냐? 정돈은 아닌데
# 19                            난 저런 돈가스는 냄새 심해서 못 먹겠더라
# 20                   경향식말고 이 카츠는 내 인생 돈까스임육질이 쥑여줌
# 21                                                부럽다
# 22                                  그대도 만원의 행복을 느껴보세요
# 23                                             맛있겠다
# 24                                  충분히 먹고도 남을 자산가시면서
# 25                                          와 앞에 여자네?
# 26                                        모든 상상을 소유하라
# 27                                                부럽다
# 28                                  그대도 가끔은 사치를 부려보세요
# 29                               부익부 빈익빈 억울하다 세상을 뒤엎자

# %% [markdown]
# ### 1-c-4. 연속되는 !, ? 를 최대 1개로 줄임

# %%
# 연속되는 !, ? 를 최대 1개로 줄이는 함수 정의
def reduce_excl_quest_marks(text):
    text = re.sub('[!]+', '!', text)
    return re.sub('[?]+', '?', text)

# 데이터프레임의 'cleaned_text' 칼럼에 함수 적용
df['reduced_punct_text'] = df['filtered_text'].apply(reduce_excl_quest_marks)
df.head(30)
# Out:
#    search_keyword date_created time_created        writer  is_reply  \
�ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...
# 13                                   천만원 인생수업이면 나쁘지않아
# 14                                                  오
# 15                                                  아
# 16                                베이비가 아장아장 걷는  jyp
# 17           간만에 기만  jyp 쵸코파이와 컵라면만 먹는게 아니란말임슴둥   !!!
# 18                                       어디냐? 정돈은 아닌데
# 19                            난 저런 돈가스는 냄새 심해서 못 먹겠더라
# 20                   경향식말고 이 카츠는 내 인생 돈까스임육질이 쥑여줌
# 21                                                부럽다
# 22                                  그대도 만원의 행복을 느껴보세요
# 23                                             맛있겠다
# 24                                  충분히 먹고도 남을 자산가시면서
# 25                                          와 앞에 여자네?
# 26                                        모든 상상을 소유하라
# 27                                                부럽다
# 28                                  그대도 가끔은 사치를 부려보세요
# 29                               부익부 빈익빈 억울하다 세상을 뒤엎자
#
#                                    reduced_punct_text
# 0      jyp가반년만에 배가올랏네 근디보니는인적자원위주로하는사업은먼가ㅂㄹ다걍제조업이조음
# 1   야 개보지년들아 jyp 주가 봤냐   미쳣다 지금    개잡주 오르는건 그러려니 하...
# 2                                                  ㅠㅠ
# 3                                                  ㅠㅠ
# 4                  니들 jyp 어케 생각해? ㄹㅇ 개미 너무 많이 붙는거 같은데
# 5                                                 조용필
# 6                                                신포도야
# 7                                      난 뉴턴이 될 생각 없으야
# 8                                              제왚ㅣ!
# 9                                에코프로를 보고도 급등주를 타려하느냐
# 10                                                투자해
# 11                                       반또가 사면 나도 산다
# 12  jyp는 신 맞다      인증  컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...
# 13                                   천만원 인생수업이면 나쁘지않아
# 14                                                  오
# 15                                                  아
# 16                                베이비가 아장아장 걷는  jyp
# 17             간만에 기만  jyp 쵸코파이와 컵라면만 먹는게 아니란말임슴둥   !
# 18                                       어디냐? 정돈은 아닌데
# 19                            난 저런 돈가스는 냄새 심해서 못 먹겠더라
# 20                   경향식말고 이 카츠는 내 인생 돈까스임육질이 쥑여줌
# 21                                                부럽다
# 22                                  그대도 만원의 행복을 느껴보세요
# 23                                             맛있겠다
# 24                                  충분히 먹고도 남을 자산가시면서
# 25                                          와 앞에 여자네?
# 26                                        모든 상상을 소유하라
# 27                                                부럽다
# 28                                  그대도 가끔은 사치를 부려보세요
# 29                               부익부 빈익빈 억울하다 세상을 뒤엎자

# %% [markdown]
# ### 1-c-5. 연속되는 한글 자음, 모음 최대 3개로 줄이기

# %%
from soynlp.normalizer import emoticon_normalize
def reduce_korean_text(input_text):
    normalized_text = emoticon_normalize(input_text, num_repeats=3)
    return normalized_text

df['reduced_korean_text'] = df['reduced_punct_text'].apply(reduce_korean_text)
df.head(30)
# Out:
#    search_keyword date_created time_created        writer  is_reply  \
# 0             JYP   2023-06-13     12:50:42            ㅇㅇ         0
# 1             JYP   2023-05-16     17:52:40    ㅇㅇ(118.34)         0
# 2             JYP   2023-05-16     17:52:48    ㅇㅇ(118.34)         1
# 3             JYP   2023-05-16     18:04:04   ㅇㅇ(203.227)         1
# 4             JYP   2023-04-17     22:00:45           설묘.         0
# 5             JYP   2023-04-17     22:01:10   ㅇㅇ(175.116)         1
# 6             JYP   2023-04-17     22:01:17          영차추종         1
# 7             JYP   2023-04-17     22:01:32          영차추종         1
# 8             JYP   2023-04-17     22:01:42          새우고래         1
#
#                                        lowercase_text  \
# 0      jyp가반년만에2배가올랏네 근디보니는인적자원위주로하는사업은먼가ㅂㄹ다걍제조업이조음..
# 1   야 개보지년들아 jyp 주가 봤냐.. 미쳣다 지금... 개잡주 오르는건 그러려니 하...
# 2                                                  ㅠㅠ
# 3                                                  ㅠㅠ
# 4                  니들 jyp 어케 생각해? ㄹㅇ 개미 너무 많이 붙는거 같은데
# 5                                                 조용필
# 6                                                신포도야
# 7                                      난 뉴턴이 될 생각 없으야
# 8                                              제왚ㅣ! -
# 9                                에코프로를 보고도 급등주를 타려하느냐
# 10                                                투자해
# 11                                       반또가 사면 나도 산다
# 12  jyp는 신 맞다 (300%인증) 컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...
# 13                                   천만원 인생수업이면 나쁘지않아
# 14                                                  오
# 15                                                  아
# 16                                베이비가 아장아장 걷는  jyp _
# 17           간만에 기만  jyp 쵸코파이와 컵라면만 먹는게 아니란말임슴둥   !!!
# 18                                       어디냐? 정돈은 아닌데
# 19                            난 저런 돈가스는 냄새 심해서 못 먹겠더라
# 20                   경향식말고 이 카츠는 내 인생 돈까스임육질이 쥑여줌;;;;
# 21                                                부럽다
# 22                                  그대도 만원의 행복을 느껴보세요
# 23                                             맛있겠다..
# 24                                  충분히 먹고도 남을 자산가시면서
# 25                                          와 앞에 여자네?
# 26                                        모든 상상을 소유하라
# 27                                                부럽다
# 28                                  그대도 가끔은 사치를 부려보세요
# 29                               부익부 빈익빈 억울하다 세상을 뒤엎자
#
#                                         filtered_text  \
# 0      jyp가반년만에 배가올랏네 근디보니는인적자원위주로하는사업은먼가ㅂㄹ다걍제조업이조음
# 1   야 개보지년들아 jyp 주가 봤냐   미쳣다 지금    개잡주 오르는건 그러려니 하...
# 2                                                  ㅠㅠ
# 3                                                  ㅠㅠ
# 4                  니들 jyp 어케 생각해? ㄹㅇ 개미 너무 많이 붙는거 같은데
# 5                                                 조용필
# 6                                                신포도야
# 7                                      난 뉴턴이 될 생각 없으야
# 8                                              제왚ㅣ!
# 9                                에코프로를 보고도 급등주를 타려하느냐
# 10                                                투자해
# 11                                       반또가 사면 나도 산다
# 12  jyp는 신 맞다      인증  컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...
# 13                                   천만원 인생수업이면 나쁘지않아
# 14                                                  오
# 15                                                  아
# 16                                베이비가 아장아장 걷는  jyp
# 17           간만에 기만  jyp 쵸코파이와 컵라면만 먹는게 아니란말임슴둥   !!!
# 18                                       어디냐? 정돈은 아닌데
# 19                            난 저런 돈가스는 냄새 심해서 못 먹겠더라
# 20                   경향식말고 이 카츠는 내 인생 돈까스임육질이 쥑여줌
# 21                                                부럽다
# 22                                  그대도 만원의 행복을 느껴보세요
# 23                                             맛있겠다
# 24                                  충분히 먹고도 남을 자산가시면서
# 25                                          와 앞에 여자네?
# 26                                        모든 상상을 소유하라
# 27                                                부럽다
# 28                                  그대도 가끔은 사치를 부려보세요
# 29                               부익부 빈익빈 억울하다 세상을 뒤엎자
#
#                                    reduced_punct_text  \
# 0      jyp가반년만에 배가올랏네 근디보니는인적자원위주로하는사업은먼가ㅂㄹ다걍제조업이조음
# 1   야 개보지년들아 jyp 주가 봤냐   미쳣다 지금    개잡주 오르는건 그러려니 하...
# 2                                                  ㅠㅠ
# 3                                                  ㅠㅠ
# 4                  니들 jyp 어케 생각해? ㄹㅇ 개미 너무 많이 붙는거 같은데
# 5                                                 조용필
# 6                                                신포도야
# 7                                      난 뉴턴이 될 생각 없으야
# 8                                              제왚ㅣ!
# 9                                에코프로를 보고도 급등주를 타려하느냐
# 10                                                투자해
# 11                                       반또가 사면 나도 산다
# 12  jyp는 신 맞다      인증  컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...
# 13                                   천만원 인생수업이면 나쁘지않아
# 14                                                  오
# 15                                                  아
# 16                                베이비가 아장아장 걷는  jyp
# 17             간만에 기만  jyp 쵸코파이와 컵라면만 먹는게 아니란말임슴둥   !
# 18                                       어디냐? 정돈은 아닌데
# 19                            난 저런 돈가스는 냄새 심해서 못 먹겠더라
# 20                   경향식말고 이 카츠는 내 인생 돈까스임육질이 쥑여줌
# 21                                                부럽다
# 22                                  그대도 만원의 행복을 느껴보세요
# 23                                             맛있겠다
# 24                                  충분히 먹고도 남을 자산가시면서
# 25                                          와 앞에 여자네?
# 26                                        모든 상상을 소유하라
# 27                                                부럽다
# 28                                  그대도 가끔은 사치를 부려보세요
# 29                               부익부 빈익빈 억울하다 세상을 뒤엎자
#
#                                   reduced_korean_text
# 0          jyp가반년만에 배가올랏네 근디보니는인적자원위주로하는사업은먼ㅂㄹ걍제조업이조음
# 1   야 개보지년들아 jyp 주가 봤냐 미쳣다 지금 개잡주 오르는건 그러려니 하는데와 진...
# 2                                                  ㅠㅠ
# 3                                                  ㅠㅠ
# 4                  니들 jyp 어케 생각해? ㄹㅇ 개미 너무 많이 붙는거 같은데
# 5                                                 조용필
# 6                                                신포도야
# 7                                      난 뉴턴이 될 생각 없으야
# 8                                                제왚ㅣ!
# 9                                에코프로를 보고도 급등주를 타려하느냐
# 10                                                투자해
# 11                                       반또가 사면 나도 산다
# 12  jyp는 신 맞다 인증 캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬...
# 13                                   천만원 인생수업이면 나쁘지않아
# 14                                                  오
# 15                                                  아
# 16                                   베이비가 아장아장 걷는 jyp
# 17                간만에 기만 jyp 쵸코파이와 컵라면만 먹는게 아니란말임슴둥 !
# 18                                       어디냐? 정돈은 아닌데
# 19                            난 저런 돈가스는 냄새 심해서 못 먹겠더라
# 20                       경향식말고 이 카츠는 내 인생 돈까스임육질이 쥑여줌
# 21                                                부럽다
# 22                                  그대도 만원의 행복을 느껴보세요
# 23                                               맛있겠다
# 24                                  충분히 먹고도 남을 자산가시면서
# 25                                          와 앞에 여자네?
# 26                                        모든 상상을 소유하라
# 27                                                부럽다
# 28                                  그대도 가끔은 사치를 부려보세요
# 29                               부익부 빈익빈 억울하다 세상을 뒤엎자

# %% [markdown]
# ### 1-c-6. 연속적인 공백 문자 최대 1개로 줄임

# %%
def reduce_spaces(text):
    # 연속되는 공백을 하나의 공백으로 치환
    return re.sub(' +', ' ', text)

df['cleansed_text'] = df['reduced_korean_text'].apply(reduce_spaces)
df.head(30)
# Out:
#    search_keyword date_created time_created        writer  is_reply  \
# 0             JYP   2023-06-13     12:50:42            ㅇㅇ         0
# 1             JYP   2023-05-16     17:52:40    ㅇㅇ(118.34)         0
# 2             JYP   2023-05-16     17:52:48    ㅇㅇ(118.34)         1
# 3             JYP   2023-05-16     18:04:04   ㅇㅇ(203.227)         1
# 4             JYP   2023-04-17     22:00:45           설묘.         0
# 5             JYP   2023-04-17     22:01:10   ㅇㅇ(175.116)         1
# 6             JYP   2023-04-17     22:01:17          영차추종         1
# 7             JYP   2023-04-17     22:01:32          영차추종         1
# 8             JYP   2023-04-17     22:01:42          새우고래         1
# 9             JYP   2023-04-17     22:01:43  부랄턱과500개의스캠들         1
# 10            JYP   2023-04-17     22:02:37        kvanto         1
# 11            JYP   2023-04-17     22:03:23           설묘.         1
# 12            JYP   2023-04-15     18:04:36    ㅇㅇ(218.55)         0
# 13            JYP   2023-04-15     18:07:21       이더리움2.0         1
# 14            JYP   2023-04-15     18:07:39          영차추종         1
# 15            JYP   2023-04-15     18:08:26     ㅇㅇ(58.77)         1
# 16            JYP   2023-01-12     23:04:36           voo         0
# 17            JYP   2023-01-08     22:05:58           voo         0
# 18            JYP   2023-01-08     22:07:18       나스닥에인생걺         1
# 19            JYP   2023-01-08     22:08:00  부랄턱과500개의스캠들         1
# 20            JYP   2023-01-08     22:10:59           voo         1
# 21            JYP   2023-01-08     22:08:00    ㅇㅇ(223.62)         1
# 22            JYP   2023-01-08     22:11:22           voo         1
# 23            JYP   2023-01-08     22:09:20        FODERA         1
# 24            JYP   2023-01-08     22:11:38           voo         1
# 25            JYP   2023-01-08     22:13:22     모든주식을소유하라         1
# 26            JYP   2023-01-08     22:18:06           voo         1
# 27            JYP   2023-01-08     22:17:40           마바리         1
# 28            JYP   2023-01-08     22:18:23           voo         1
# 29            JYP   2023-01-08     22:19:38       찰스슈왑ETF         1
#
#                                                  text           id  \
# 0      jyp가반년만에2배가올랏네 근디보니는인적자원위주로하는사업은먼가ㅂㄹ다걍제조업이조음..  10100746844
# 1   야 개보지년들아 JYP 주가 봤냐.. 미쳣다 지금... 개잡주 오르는건 그러려니 하...  10100730087
# 2                                                  ㅠㅠ  10100730087
# 3                                                  ㅠㅠ  10100730087
# 4                  니들 jyp 어케 생각해? ㄹㅇ 개미 너무 많이 붙는거 같은데  10100714904
# 5                                                 조용필  10100714904
# 6                                                신포도야  10100714904
# 7                                      난 뉴턴이 될 생각 없으야  10100714904
# 8                                              제왚ㅣ! -  10100714904
# 9                                에코프로를 보고도 급등주를 타려하느냐  10100714904
# 10                                                투자해  10100714904
# 11                                       반또가 사면 나도 산다  10100714904
# 12  JYP는 신 맞다 (300%인증) 컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
�ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...
# 13                                   천만원 인생수업이면 나쁘지않아
# 14                                                  오
# 15                                                  아
# 16                                베이비가 아장아장 걷는  jyp
# 17           간만에 기만  jyp 쵸코파이와 컵라면만 먹는게 아니란말임슴둥   !!!
# 18                                       어디냐? 정돈은 아닌데
# 19                            난 저런 돈가스는 냄새 심해서 못 먹겠더라
# 20                   경향식말고 이 카츠는 내 인생 돈까스임육질이 쥑여줌
# 21                                                부럽다
# 22                                  그대도 만원의 행복을 느껴보세요
# 23                                             맛있겠다
# 24                                  충분히 먹고도 남을 자산가시면서
# 25                                          와 앞에 여자네?
# 26                                        모든 상상을 소유하라
# 27                                                부럽다
# 28                                  그대도 가끔은 사치를 부려보세요
# 29                               부익부 빈익빈 억울하다 세상을 뒤엎자
#
#                                    reduced_punct_text  \
# 0      jyp가반년만에 배가올랏네 근디보니는인적자원위주로하는사업은먼가ㅂㄹ다걍제조업이조음
# 1   야 개보지년들아 jyp 주가 봤냐   미쳣다 지금    개잡주 오르는건 그러려니 하...
# 2                                                  ㅠㅠ
# 3                                                  ㅠㅠ
# 4                  니들 jyp 어케 생각해? ㄹㅇ 개미 너무 많이 붙는거 같은데
# 5                                                 조용필
# 6                                                신포도야
# 7                                      난 뉴턴이 될 생각 없으야
# 8                                              제왚ㅣ!
# 9                                에코프로를 보고도 급등주를 타려하느냐
# 10                                                투자해
# 11                                       반또가 사면 나도 산다
# 12  jyp는 신 맞다      인증  컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ컄ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...
# 13                                   천만원 인생수업이면 나쁘지않아
# 14                                                  오
# 15                                                  아
# 16                                베이비가 아장아장 걷는  jyp
# 17             간만에 기만  jyp 쵸코파이와 컵라면만 먹는게 아니란말임슴둥   !
# 18                                       어디냐? 정돈은 아닌데
# 19                            난 저런 돈가스는 냄새 심해서 못 먹겠더라
# 20                   경향식말고 이 카츠는 내 인생 돈까스임육질이 쥑여줌
# 21                                                부럽다
# 22                                  그대도 만원의 행복을 느껴보세요
# 23                                             맛있겠다
# 24                                  충분히 먹고도 남을 자산가시면서
# 25                                          와 앞에 여자네?
# 26                                        모든 상상을 소유하라
# 27                                                부럽다
# 28                                  그대도 가끔은 사치를 부려보세요
# 29                               부익부 빈익빈 억울하다 세상을 뒤엎자
#
#                                   reduced_korean_text  \
# 0          jyp가반년만에 배가올랏네 근디보니는인적자원위주로하는사업은먼ㅂㄹ걍제조업이조음
# 1   야 개보지년들아 jyp 주가 봤냐 미쳣다 지금 개잡주 오르는건 그러려니 하는데와 진...
# 2                                                  ㅠㅠ
# 3                                                  ㅠㅠ
# 4                  니들 jyp 어케 생각해? ㄹㅇ 개미 너무 많이 붙는거 같은데
# 5                                                 조용필
# 6                                                신포도야
# 7                                      난 뉴턴이 될 생각 없으야
# 8                                                제왚ㅣ!
# 9                                에코프로를 보고도 급등주를 타려하느냐
# 10                                                투자해
# 11                                       반또가 사면 나도 산다
# 12  jyp는 신 맞다 인증 캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬...
# 13                                   천만원 인생수업이면 나쁘지않아
# 14                                                  오
# 15                                                  아
# 16                                   베이비가 아장아장 걷는 jyp
# 17                간만에 기만 jyp 쵸코파이와 컵라면만 먹는게 아니란말임슴둥 !
# 18                                       어디냐? 정돈은 아닌데
# 19                            난 저런 돈가스는 냄새 심해서 못 먹겠더라
# 20                       경향식말고 이 카츠는 내 인생 돈까스임육질이 쥑여줌
# 21                                                부럽다
# 22                                  그대도 만원의 행복을 느껴보세요
# 23                                               맛있겠다
# 24                                  충분히 먹고도 남을 자산가시면서
# 25                                          와 앞에 여자네?
# 26                                        모든 상상을 소유하라
# 27                                                부럽다
# 28                                  그대도 가끔은 사치를 부려보세요
# 29                               부익부 빈익빈 억울하다 세상을 뒤엎자
#
#                                         cleansed_text
# 0          jyp가반년만에 배가올랏네 근디보니는인적자원위주로하는사업은먼ㅂㄹ걍제조업이조음
# 1   야 개보지년들아 jyp 주가 봤냐 미쳣다 지금 개잡주 오르는건 그러려니 하는데와 진...
# 2                                                  ㅠㅠ
# 3                                                  ㅠㅠ
# 4                  니들 jyp 어케 생각해? ㄹㅇ 개미 너무 많이 붙는거 같은데
# 5                                                 조용필
# 6                                                신포도야
# 7                                      난 뉴턴이 될 생각 없으야
# 8                                                제왚ㅣ!
# 9                                에코프로를 보고도 급등주를 타려하느냐
# 10                                                투자해
# 11                                       반또가 사면 나도 산다
# 12  jyp는 신 맞다 인증 캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬...
# 13                                   천만원 인생수업이면 나쁘지않아
# 14                                                  오
# 15                                                  아
# 16                                   베이비가 아장아장 걷는 jyp
# 17                간만에 기만 jyp 쵸코파이와 컵라면만 먹는게 아니란말임슴둥 !
# 18                                       어디냐? 정돈은 아닌데
# 19                            난 저런 돈가스는 냄새 심해서 못 먹겠더라
# 20                       경향식말고 이 카츠는 내 인생 돈까스임육질이 쥑여줌
# 21                                                부럽다
# 22                                  그대도 만원의 행복을 느껴보세요
# 23                                               맛있겠다
# 24                                  충분히 먹고도 남을 자산가시면서
# 25                                          와 앞에 여자네?
# 26                                        모든 상상을 소유하라
# 27                                                부럽다
# 28                                  그대도 가끔은 사치를 부려보세요
# 29                               부익부 빈익빈 억울하다 세상을 뒤엎자

# %% [markdown]
# ### 1-c-7. 불필요한 칼럼을 제거한다

# %%
# 제거할 칼럼 목록 (예시: 'lowercase_text', 'cleaned_text')
columns_to_remove = ['lowercase_text', 'filtered_text', 'reduced_punct_text', 'reduced_korean_text', 'text']

# 해당 칼럼들을 데이터프레임에서 제거
df_dropped = df.drop(columns=columns_to_remove)
df_dropped.head(30)
# Out:
#    search_keyword date_created time_created        writer  is_reply  \
# 0             JYP   2023-06-13     12:50:42            ㅇㅇ         0
# 1             JYP   2023-05-16     17:52:40    ㅇㅇ(118.34)         0
# 2             JYP   2023-05-16     17:52:48    ㅇㅇ(118.34)         1
# 3             JYP   2023-05-16     18:04:04   ㅇㅇ(203.227)         1
# 4             JYP   2023-04-17     22:00:45           설묘.         0
# 5             JYP   2023-04-17     22:01:10   ㅇㅇ(175.116)         1
# 6             JYP   2023-04-17     22:01:17          영차추종         1
# 7             JYP   2023-04-17     22:01:32          영차추종         1
# 8             JYP   2023-04-17     22:01:42          새우고래         1
# 9             JYP   2023-04-17     22:01:43  부랄턱과500개의스캠들         1
# 10            JYP   2023-04-17     22:02:37        kvanto         1
# 11            JYP   2023-04-17     22:03:23           설묘.         1
# 12            JYP   2023-04-15     18:04:36    ㅇㅇ(218.55)         0
# 13            JYP   2023-04-15     18:07:21       이더리움2.0         1
# 14            JYP   2023-04-15     18:07:39          영차추종         1
# 15            JYP   2023-04-15     18:08:26     ㅇㅇ(58.77)         1
# 16            JYP   2023-01-12     23:04:36           voo         0
# 17            JYP   2023-01-08     22:05:58           voo         0
# 18            JYP   2023-01-08     22:07:18       나스닥에인생걺         1
# 19            JYP   2023-01-08     22:08:00  부랄턱과500개의스캠들         1
# 20            JYP   2023-01-08     22:10:59           voo         1
# 21            JYP   2023-01-08     22:08:00    ㅇㅇ(223.62)         1
# 22            JYP   2023-01-08     22:11:22           voo         1
# 23            JYP   2023-01-08     22:09:20        FODERA         1
# 24            JYP   2023-01-08     22:11:38           voo         1
# 25            JYP   2023-01-08     22:13:22     모든주식을소유하라         1
# 26            JYP   2023-01-08     22:18:06           voo         1
# 27            JYP   2023-01-08     22:17:40           마바리         1
# 28            JYP   2023-01-08     22:18:23           voo         1
# 29            JYP   2023-01-08     22:19:38       찰스슈왑ETF         1
#
#              id                                      cleansed_text
# 0   10100746844         jyp가반년만에 배가올랏네 근디보니는인적자원위주로하는사업은먼ㅂㄹ걍제조업이조음
# 1   10100730087  야 개보지년들아 jyp 주가 봤냐 미쳣다 지금 개잡주 오르는건 그러려니 하는데와 진...
# 2   10100730087                                                 ㅠㅠ
# 3   10100730087                                                 ㅠㅠ
# 4   10100714904                 니들 jyp 어케 생각해? ㄹㅇ 개미 너무 많이 붙는거 같은데
# 5   10100714904                                                조용필
# 6   10100714904                                               신포도야
# 7   10100714904                                     난 뉴턴이 될 생각 없으야
# 8   10100714904                                               제왚ㅣ!
# 9   10100714904                               에코프로를 보고도 급등주를 타려하느냐
# 10  10100714904                                                투자해
# 11  10100714904                                       반또가 사면 나도 산다
# 12  10100713453  jyp는 신 맞다 인증 캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬ㅋㅋㅋ캬...
# 13  10100713453                                   천만원 인생수업이면 나쁘지않아
# 14  10100713453                                                  오
# 15  10100713453                                                  아
# 16  10100654017                                   베이비가 아장아장 걷는 jyp
# 17  10100651890                간만에 기만 jyp 쵸코파이와 컵라면만 먹는게 아니란말임슴둥 !
# 18  10100651890                                       어디냐? 정돈은 아닌데
# 19  10100651890                            난 저런 돈가스는 냄새 심해서 못 먹겠더라
# 20  10100651890                       경향식말고 이 카츠는 내 인생 돈까스임육질이 쥑여줌
# 21  10100651890                                                부럽다
# 22  10100651890                                  그대도 만원의 행복을 느껴보세요
# 23  10100651890                                               맛있겠다
# 24  10100651890                                  충분히 먹고도 남을 자산가시면서
# 25  10100651890                                          와 앞에 여자네?
# 26  10100651890                                        모든 상상을 소유하라
# 27  10100651890                                                부럽다
# 28  10100651890                                  그대도 가끔은 사치를 부려보세요
# 29  10100651890                               부익부 빈익빈 억울하다 세상을 뒤엎자

# %% [markdown]
# ### 1-c-8. 파일로 저장한다

# %%
# .csv 파일로 저장한다
df_dropped.to_csv("1_cleansed_text.csv", index=False, encoding="utf-8")

# %% [markdown]
# ## 1-d. 함수화
#
# 입력 - .csv 파일의 경로만 지정하면 모든 과정을 수행할 수 있도록 함수화한다.

# %% [markdown]
# ### 1-d-1. 함수 만들기

# %%
# 시간 측정 데코레이터
import time

def time_decorator(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        print(f"Function '{func.__name__}' executed in {end_time - start_time} seconds.")
        return result
    return wrapper

# %%
import pandas as pd
import re
from soynlp.normalizer import emoticon_normalize
    
@time_decorator
def make_cleansed_csv_file(read_file_path, text_column_name, save_file_path):
    
    # 1. 데이터 읽어오기
    print("[progress 1/8] 데이터 읽어오기")
    df = pd.read_csv(read_file_path, encoding="utf-8")

    # 2. 영어는 소문자로 변경
    print("[progress 2/8] 영어는 소문자로 변경")
    df['lowercase_text'] = df[text_column_name].str.lower()

    # 3. 한글, 영어, !? 만 남기고 전부 공백문자로 치환
    print("[progress 3/8] 한글, 영어, !? 만 남기고 전부 공백문자로 치환")
    def replace_chars(text):
        return re.sub('[^a-z가-힣ㄱ-ㅎㅏ-ㅣ!?]', ' ', text)
    df['filtered_text'] = df['lowercase_text'].apply(replace_chars)

    # 4. 연속되는 !, ? 를 최대 1개로 줄임
    print("[progress 4/8] 연속되는 !, ? 를 최대 1개로 줄임")
    def reduce_excl_quest_marks(text):
        text = re.sub('[!]+', '!', text)
        return re.sub('[?]+', '?', text)
    df['reduced_punct_text'] = df['filtered_text'].apply(reduce_excl_quest_marks)

    # 5. 연속되는 한글 자음, 모음 최대 3개로 줄이기
    print("[progress 5/8] 연속되는 한글 자음, 모음 최대 3개로 줄이기")
    def reduce_korean_text(input_text):
        normalized_text = emoticon_normalize(input_text, num_repeats=3)
        return normalized_text
    df['reduced_korean_text'] = df['reduced_punct_text'].apply(reduce_korean_text)

    # 6. 연속적인 공백 문자 최대 1개로 줄임
    print("[progress 6/8] 연속적인 공백 문자 최대 1개로 줄임")
    def reduce_spaces(text):
        # 연속되는 공백을 하나의 공백으로 치환
        return re.sub(' +', ' ', text)
    df['cleansed_text'] = df['reduced_korean_text'].apply(reduce_spaces)

    # 7. 불필요한 칼럼을 제거
    print("[progress 7/8] 불필요한 칼럼을 제거")
    columns_to_remove = [text_column_name, 'lowercase_text', 'filtered_text', 'reduced_punct_text', 'reduced_korean_text']
    df_dropped = df.drop(columns=columns_to_remove)
    df.head(3)
    
    # 8. 파일로 저장
    print("[progress 8/8] 파일로 저장")
    df_dropped.to_csv(save_file_path, index=False, encoding="utf-8")
    
    # Null값 제거하여 다시 저장 (파일로 저장해야만 null값이 나타나는 경우가 있다)
    df_saved = pd.read_csv(save_file_path, encoding="utf-8")
    df_dropped_na = df_saved.dropna().copy()
    df_dropped_na.to_csv(save_file_path, index=False, encoding="utf-8")

    print("[done]")

# %% [markdown]
# ### 1-d-2. 함수 테스트

# %%
read_file_path = "./1_id_text.csv"
text_column_name = "text"
save_file_path = "./1_cleansed_text.csv"
make_cleansed_csv_file(read_file_path, text_column_name, save_file_path)
# Out:
# [progress 1/8] 데이터 읽어오기
# [progress 2/8] 영어는 소문자로 변경
# [progress 3/8] 한글, 영어, !? 만 남기고 전부 공백문자로 치환
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 4
#       2 text_column_name = "text"
#       3 save_file_path = "./1_cleansed_text.csv"
# ----> 4 make_cleansed_csv_file(read_file_path, text_column_name, save_file_path)
#
# Cell In[31], line 7, in time_decorator.<locals>.wrapper(*args, **kwargs)
#       5 def wrapper(*args, **kwargs):
#       6     start_time = time.time()
# ----> 7     result = func(*args, **kwargs)
#       8     end_time = time.time()
#       9     print(f"Function '{func.__name__}' executed in {end_time - start_time} seconds.")
#
# Cell In[56], line 19, in make_cleansed_csv_file(read_file_path, text_column_name, save_file_path)
#      17 def replace_chars(text):
#      18     return re.sub('[^a-z가-힣ㄱ-ㅎㅏ-ㅣ!?]', ' ', text)
# ---> 19 df['filtered_text'] = df['lowercase_text'].apply(replace_chars)
#      21 # 4. 연속되는 !, ? 를 최대 1개로 줄임
#      22 print("[progress 4/8] 연속되는 !, ? 를 최대 1개로 줄임")
#
# File ~\.conda\envs\brnn\lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\.conda\envs\brnn\lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~\.conda\envs\brnn\lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\.conda\envs\brnn\lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[56], line 18, in make_cleansed_csv_file.<locals>.replace_chars(text)
#      17 def replace_chars(text):
# ---> 18     return re.sub('[^a-z가-힣ㄱ-ㅎㅏ-ㅣ!?]', ' ', text)
#
# KeyboardInterrupt:
